# %%
from __future__ import print_function 
import os, sys, h5py
import numpy as np
from six.moves import cPickle
from collections import OrderedDict

import tensorflow as tf
sys.path.append('..')
from tfomics import layers, utils, init, learn, explore
from tfomics import neuralnetwork as nn
from tfomics.build_network import *

# import models
from model_zoo import fourthplace_connectomics_model
from model_zoo import simple_connectomics_model
from model_zoo import simple_connectomics_model2
from model_zoo import residual_connectomics_model
from model_zoo import residual_connectomics_model2

# %% [markdown]
# # load data

# %%
filename = 'processed_dataset.hdf5'
data_path = '/home/peter/Code/tensorflow/data'
filepath = os.path.join(data_path,filename)

group_name = ['processed_data']
dataset = h5py.File(filepath,'r')
# %time dtf = np.array(dataset['/'+group_name[0]+'/dtf'])
ltf = np.array(dataset['/'+group_name[0]+'/ltf'])
dtf_crossval = np.array(dataset['/'+group_name[0]+'/dtf_crossval'])
ltf_crossval = np.array(dataset['/'+group_name[0]+'/ltf_crossval'])

X_train = dtf
y_train = ltf
X_valid = dtf_crossval
y_valid = ltf_crossval
# Out:
# CPU times: user 460 ms, sys: 1.19 s, total: 1.65 s
# Wall time: 1.65 s

# %% [markdown]
# # Simple connectomics model

# %%
# get shapes
num_data, height, width, dim = X_train.shape
input_shape=[None, height, width, dim]
num_labels = y_train.shape[1]  

# load model
net, placeholders, optimization = simple_connectomics_model.model(input_shape, num_labels)

# build neural network class
nnmodel = nn.NeuralNet(net, [placeholders['inputs']])
nnmodel.inspect_layers()

# set output file paths
resultspath = utils.make_directory('../results', 'tf-test')
output_name = '1d_version'
filepath = os.path.join(resultspath, output_name)

# compile neural trainer
nntrainer = nn.NeuralTrainer(nnmodel, placeholders, optimization, save='best', filepath=filepath)
# Out:
# ----------------------------------------------------------------------------
# Network architecture:
# ----------------------------------------------------------------------------
# layer1: input
# (?, 3, 330, 1)
# layer2: conv1
# (?, 2, 326, 18)
# layer3: conv1_batch
# (?, 2, 326, 18)
# layer4: conv1_active
# (?, 2, 326, 18)
# layer5: conv2
# (?, 1, 322, 40)
# layer6: conv2_batch
# (?, 1, 322, 40)
# layer7: conv2_active
# (?, 1, 322, 40)
# layer8: conv2_pool
# (?, 1, 32, 40)
# layer9: conv3
# (?, 1, 32, 15)
# layer10: conv3_batch
# (?, 1, 32, 15)
# layer11: conv3_active
# (?, 1, 32, 15)
# layer12: dense1
# (?, 100)
# layer13: dense1_bias
# (?, 100)
# layer14: dense1_active
# (?, 100)
# layer15: dense1_dropout
# (?, 100)
# layer16: dense2
# (?, 2)
# layer17: dense2_bias
# (?, 2)
# layer18: dense2_active
# (?, 2)
# layer19: output
# (?, 2)
# ----------------------------------------------------------------------------

# %%
X = {'inputs': X_train, 'targets': y_train, 'keep_prob': 0.8, 'is_training': True}
X2 = {'inputs': X_valid, 'targets': y_valid, 'keep_prob': 1, 'is_training': False}
data = {'train': X, 'valid': X2}

sess = tf.Session()
sess.run(tf.initialize_all_variables())
learn.train_minibatch(sess, nntrainer, data, batch_size=100, num_epochs=20, 
                    patience=5, verbose=1, shuffle=True)
sess.close()

sess = tf.Session()
sess.run(tf.initialize_all_variables())
nntrainer.set_best_parameters(sess)
learn.train_minibatch(sess, nntrainer, data, batch_size=500, num_epochs=20, 
                    patience=5, verbose=1, shuffle=True)
sess.close()

sess = tf.Session()
sess.run(tf.initialize_all_variables())
nntrainer.set_best_parameters(sess)
learn.train_minibatch(sess, nntrainer, data, batch_size=1000, num_epochs=20, 
                    patience=5, verbose=1, shuffle=True)
sess.close()


sess = tf.Session()
sess.run(tf.initialize_all_variables())
nntrainer.set_best_parameters(sess)
learn.train_minibatch(sess, nntrainer, data, batch_size=1500, num_epochs=20, 
                    patience=5, verbose=1, shuffle=True)
sess.close()


sess = tf.Session()
sess.run(tf.initialize_all_variables())
nntrainer.set_best_parameters(sess)
learn.train_minibatch(sess, nntrainer, data, batch_size=2000, num_epochs=20, 
                    patience=5, verbose=1, shuffle=True)
sess.close()
# Out:
# Epoch 1 out of 20
# [==============================] 100.0% -- time=0s -- loss=0.38387 -- accuracy=85.08%
#   valid loss:		0.35917
#   valid accuracy:	0.85797+/-0.00001
#   valid auc-roc:	0.91762+/-0.00002
#   valid auc-pr:		0.91121+/-0.00550
# lower cross-validation found
# saving model to:  ../results/tf-test/1d_version_best.ckpt
# Epoch 2 out of 20
# [==============================] 100.0% -- time=0s -- loss=0.36120 -- accuracy=85.88%
#   valid loss:		0.35581
#   valid accuracy:	0.86015+/-0.00001
#   valid auc-roc:	0.92013+/-0.00000
#   valid auc-pr:		0.91446+/-0.00482
# lower cross-validation found
# saving model to:  ../results/tf-test/1d_version_best.ckpt
# Epoch 3 out of 20
# [==============================] 100.0% -- time=0s -- loss=0.35532 -- accuracy=86.09%
#   valid loss:		0.35182
#   valid accuracy:	0.86146+/-0.00001
#   valid auc-roc:	0.92232+/-0.00000
#   valid auc-pr:		0.91709+/-0.00422
# lower cross-validation found
# saving model to:  ../results/tf-test/1d_version_best.ckpt
# Epoch 4 out of 20
# [==============================] 100.0% -- time=0s -- loss=0.35176 -- accuracy=86.19%
#   valid loss:		0.35459
#   valid accuracy:	0.85849+/-0.00001
#   valid auc-roc:	0.92253+/-0.00000
#   valid auc-pr:		0.91749+/-0.00403
# Epoch 5 out of 20
# [==============================] 100.0% -- time=0s -- loss=0.34884 -- accuracy=86.31%
#   valid loss:		0.34761
#   valid accuracy:	0.86302+/-0.00000
#   valid auc-roc:	0.92417+/-0.00000
#   valid auc-pr:		0.91930+/-0.00360
# lower cross-validation found
# saving model to:  ../results/tf-test/1d_version_best.ckpt
# Epoch 6 out of 20
# [==============================] 100.0% -- time=0s -- loss=0.34709 -- accuracy=86.36%
#   valid loss:		0.34632
#   valid accuracy:	0.86335+/-0.00001
#   valid auc-roc:	0.92484+/-0.00000
#   valid auc-pr:		0.92004+/-0.00374
# lower cross-validation found
# saving model to:  ../results/tf-test/1d_version_best.ckpt
# Epoch 7 out of 20
# [==============================] 100.0% -- time=0s -- loss=0.34559 -- accuracy=86.41%
#   valid loss:		0.34702
#   valid accuracy:	0.86318+/-0.00000
#   valid auc-roc:	0.92492+/-0.00000
#   valid auc-pr:		0.92036+/-0.00361
# Epoch 8 out of 20
# [==============================] 100.0% -- time=0s -- loss=0.34419 -- accuracy=86.45%
#   valid loss:		0.34445
#   valid accuracy:	0.86366+/-0.00000
#   valid auc-roc:	0.92555+/-0.00000
#   valid auc-pr:		0.92103+/-0.00319
# lower cross-validation found
# saving model to:  ../results/tf-test/1d_version_best.ckpt
# Epoch 9 out of 20
# [==============================] 100.0% -- time=0s -- loss=0.34294 -- accuracy=86.49%
#   valid loss:		0.34922
#   valid accuracy:	0.86240+/-0.00000
#   valid auc-roc:	0.92522+/-0.00000
#   valid auc-pr:		0.92071+/-0.00306
# Epoch 10 out of 20
# [==============================] 100.0% -- time=0s -- loss=0.34192 -- accuracy=86.53%
#   valid loss:		0.34436
#   valid accuracy:	0.86421+/-0.00000
#   valid auc-roc:	0.92605+/-0.00000
#   valid auc-pr:		0.92153+/-0.00315
# lower cross-validation found
# saving model to:  ../results/tf-test/1d_version_best.ckpt
# Epoch 11 out of 20
# [==============================] 100.0% -- time=0s -- loss=0.34083 -- accuracy=86.59%
#   valid loss:		0.34585
#   valid accuracy:	0.86355+/-0.00000
#   valid auc-roc:	0.92540+/-0.00000
#   valid auc-pr:		0.92093+/-0.00306
# Epoch 12 out of 20
# [==============================] 100.0% -- time=0s -- loss=0.33967 -- accuracy=86.60%
#   valid loss:		0.34716
#   valid accuracy:	0.86378+/-0.00000
#   valid auc-roc:	0.92568+/-0.00000
#   valid auc-pr:		0.92121+/-0.00319
# Epoch 13 out of 20
# [==============================] 100.0% -- time=0s -- loss=0.33901 -- accuracy=86.63%
#   valid loss:		0.34509
#   valid accuracy:	0.86384+/-0.00000
#   valid auc-roc:	0.92599+/-0.00000
#   valid auc-pr:		0.92161+/-0.00278
# Epoch 14 out of 20
# [==============================] 100.0% -- time=0s -- loss=0.33797 -- accuracy=86.67%
#   valid loss:		0.34652
#   valid accuracy:	0.86305+/-0.00000
#   valid auc-roc:	0.92615+/-0.00000
#   valid auc-pr:		0.92181+/-0.00285
# Epoch 15 out of 20
# [==============================] 100.0% -- time=0s -- loss=0.33703 -- accuracy=86.70%
#   valid loss:		0.34609
#   valid accuracy:	0.86426+/-0.00000
#   valid auc-roc:	0.92622+/-0.00000
#   valid auc-pr:		0.92190+/-0.00284
# Epoch 16 out of 20
# [==============================] 100.0% -- time=0s -- loss=0.33629 -- accuracy=86.71%
#   valid loss:		0.34743
#   valid accuracy:	0.86317+/-0.00000
#   valid auc-roc:	0.92612+/-0.00000
#   valid auc-pr:		0.92189+/-0.00292
# Patience ran out... Early stopping.
# Epoch 1 out of 20
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-5-aeafa21319b2> in <module>()
#       9
#      10 learn.train_minibatch(sess, nntrainer, data, batch_size=500, num_epochs=20,
# ---> 11                     patience=5, verbose=1, shuffle=True)
#      12
#      13 learn.train_minibatch(sess, nntrainer, data, batch_size=1500, num_epochs=20,
#
# /home/peter/Code/tensorflow/tfomics/tfomics/learn.pyc in train_minibatch(sess, nntrainer, data, batch_size, num_epochs, patience, verbose, shuffle)
#      24                                                                                         batch_size=batch_size,
#      25                                                                                         verbose=verbose,
# ---> 26 											shuffle=shuffle)
#      27                 nntrainer.add_loss(train_loss, 'train')
#      28
#
# /home/peter/Code/tensorflow/tfomics/tfomics/neuralnetwork.pyc in train_epoch(self, sess, feed_X, batch_size, verbose, shuffle)
#     134                 for i in range(num_batches):
#     135                         feed_dict = batch_generator.next_minibatch(feed_X)
# --> 136                         results = sess.run([self.train_step, self.loss, self.predictions], feed_dict=feed_dict)
#     137                         value += self.train_metric(results[2], feed_dict[self.targets])
#     138                         performance.add_loss(results[1])
#
# /home/peter/tensorflow/_python_build/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     715     try:
#     716       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 717                          run_metadata_ptr)
#     718       if run_metadata:
#     719         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/peter/tensorflow/_python_build/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     913     if final_fetches or final_targets:
#     914       results = self._do_run(handle, final_targets, final_fetches,
# --> 915                              feed_dict_string, options, run_metadata)
#     916     else:
#     917       results = []
#
# /home/peter/tensorflow/_python_build/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#     963     if handle is None:
#     964       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# --> 965                            target_list, options, run_metadata)
#     966     else:
#     967       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /home/peter/tensorflow/_python_build/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#     983         except KeyError:
#     984           pass
# --> 985       raise type(e)(node_def, op, message)
#     986
#     987   def _extend_graph(self):
#
# ResourceExhaustedError: OOM when allocating tensor with shape[500,40,1,322]
# 	 [[Node: gradients/MaxPool_grad/MaxPoolGrad = MaxPoolGrad[T=DT_FLOAT, data_format="NHWC", ksize=[1, 1, 10, 1], padding="VALID", strides=[1, 1, 10, 1], _device="/job:localhost/replica:0/task:0/gpu:0"](Relu_1, MaxPool, gradients/Conv2D_2_grad/tuple/control_dependency)]]
#
# Caused by op u'gradients/MaxPool_grad/MaxPoolGrad', defined at:
#   File "/home/peter/anaconda2/lib/python2.7/runpy.py", line 174, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "/home/peter/anaconda2/lib/python2.7/runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "/home/peter/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py", line 3, in <module>
#     app.launch_new_instance()
#   File "/home/peter/anaconda2/lib/python2.7/site-packages/traitlets/config/application.py", line 653, in launch_instance
#     app.start()
#   File "/home/peter/anaconda2/lib/python2.7/site-packages/ipykernel/kernelapp.py", line 474, in start
#     ioloop.IOLoop.instance().start()
#   File "/home/peter/anaconda2/lib/python2.7/site-packages/zmq/eventloop/ioloop.py", line 162, in start
#     super(ZMQIOLoop, self).start()
#   File "/home/peter/anaconda2/lib/python2.7/site-packages/tornado/ioloop.py", line 887, in start
#     handler_func(fd_obj, events)
#   File "/home/peter/anaconda2/lib/python2.7/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/peter/anaconda2/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/home/peter/anaconda2/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/peter/anaconda2/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/peter/anaconda2/lib/python2.7/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/peter/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 276, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/peter/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 228, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/peter/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 390, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/peter/anaconda2/lib/python2.7/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/peter/anaconda2/lib/python2.7/site-packages/ipykernel/zmqshell.py", line 501, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/peter/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2717, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/peter/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2821, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/peter/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2881, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-152e519e2073>", line 19, in <module>
#     nntrainer = nn.NeuralTrainer(nnmodel, placeholders, optimization, save='best', filepath=filepath)
#   File "../tfomics/neuralnetwork.py", line 115, in __init__
#     self.train_step = self.updates.minimize(self.loss, var_list=trainable_params)
#   File "/home/peter/tensorflow/_python_build/tensorflow/python/training/optimizer.py", line 196, in minimize
#     grad_loss=grad_loss)
#   File "/home/peter/tensorflow/_python_build/tensorflow/python/training/optimizer.py", line 253, in compute_gradients
#     colocate_gradients_with_ops=colocate_gradients_with_ops)
#   File "/home/peter/tensorflow/_python_build/tensorflow/python/ops/gradients.py", line 469, in gradients
#     in_grads = _AsList(grad_fn(op, *out_grads))
#   File "/home/peter/tensorflow/_python_build/tensorflow/python/ops/nn_grad.py", line 361, in _MaxPoolGrad
#     data_format=op.get_attr("data_format"))
#   File "/home/peter/tensorflow/_python_build/tensorflow/python/ops/gen_nn_ops.py", line 1539, in _max_pool_grad
#     data_format=data_format, name=name)
#   File "/home/peter/tensorflow/_python_build/tensorflow/python/framework/op_def_library.py", line 749, in apply_op
#     op_def=op_def)
#   File "/home/peter/tensorflow/_python_build/tensorflow/python/framework/ops.py", line 2380, in create_op
#     original_op=self._default_original_op, op_def=op_def)
#   File "/home/peter/tensorflow/_python_build/tensorflow/python/framework/ops.py", line 1298, in __init__
#     self._traceback = _extract_stack()
#
# ...which was originally created as op u'MaxPool', defined at:
#   File "/home/peter/anaconda2/lib/python2.7/runpy.py", line 174, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
# [elided 18 identical lines from previous traceback]
#   File "/home/peter/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2881, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-152e519e2073>", line 7, in <module>
#     net, placeholders, optimization = simple_connectomics_model.model(input_shape, num_labels)
#   File "../model_zoo/simple_connectomics_model.py", line 64, in model
#     net = build_network(model_layers)
#   File "../tfomics/build_network.py", line 15, in build_network
#     network, lastlayer = build_layers(model_layers)
#   File "../tfomics/build_network.py", line 79, in build_layers
#     network[newlayer] = layers.MaxPool2DLayer(network[lastlayer], pool_size=model_layer['pool_size'])
#   File "../tfomics/layers/pool.py", line 68, in __init__
#     **kwargs)
#   File "/home/peter/tensorflow/_python_build/tensorflow/python/ops/nn_ops.py", line 850, in max_pool
#     name=name)
#   File "/home/peter/tensorflow/_python_build/tensorflow/python/ops/gen_nn_ops.py", line 1440, in _max_pool
#     data_format=data_format, name=name)
#   File "/home/peter/tensorflow/_python_build/tensorflow/python/framework/op_def_library.py", line 749, in apply_op
#     op_def=op_def)
#
# ResourceExhaustedError (see above for traceback): OOM when allocating tensor with shape[500,40,1,322]
# 	 [[Node: gradients/MaxPool_grad/MaxPoolGrad = MaxPoolGrad[T=DT_FLOAT, data_format="NHWC", ksize=[1, 1, 10, 1], padding="VALID", strides=[1, 1, 10, 1], _device="/job:localhost/replica:0/task:0/gpu:0"](Relu_1, MaxPool, gradients/Conv2D_2_grad/tuple/control_dependency)]]

# %% [markdown]
# # Simple connectomics model

# %%
# get shapes
num_data, height, width, dim = X_train.shape
input_shape=[None, height, width, dim]
num_labels = y_train.shape[1]  

# load model
net, placeholders, optimization = simple_connectomics_model2.model(input_shape, num_labels)

# build neural network class
nnmodel = nn.NeuralNet(net, [placeholders['inputs']])
nnmodel.inspect_layers()

# set output file paths
resultspath = utils.make_directory('../results', 'tf-test')
output_name = '1d_version2'
filepath = os.path.join(resultspath, output_name)

# compile neural trainer
nntrainer = nn.NeuralTrainer(nnmodel, placeholders, optimization, save='best', filepath=filepath)

# %%
# run session
sess = tf.Session()

# initialize variables
sess.run(tf.initialize_all_variables())

# %%
X = {'inputs': X_train, 'targets': y_train, 'keep_prob': 0.8, 'is_training': True}
X2 = {'inputs': X_valid, 'targets': y_valid, 'keep_prob': 1, 'is_training': False}
data = {'train': X, 'valid': X2}

sess = tf.Session()
sess.run(tf.initialize_all_variables())
learn.train_minibatch(sess, nntrainer, data, batch_size=100, num_epochs=20, 
                    patience=5, verbose=1, shuffle=True)
sess.close()

sess = tf.Session()
sess.run(tf.initialize_all_variables())
nntrainer.set_best_parameters(sess)
learn.train_minibatch(sess, nntrainer, data, batch_size=500, num_epochs=20, 
                    patience=5, verbose=1, shuffle=True)
sess.close()

sess = tf.Session()
sess.run(tf.initialize_all_variables())
nntrainer.set_best_parameters(sess)
learn.train_minibatch(sess, nntrainer, data, batch_size=1000, num_epochs=20, 
                    patience=5, verbose=1, shuffle=True)
sess.close()


sess = tf.Session()
sess.run(tf.initialize_all_variables())
nntrainer.set_best_parameters(sess)
learn.train_minibatch(sess, nntrainer, data, batch_size=1500, num_epochs=20, 
                    patience=5, verbose=1, shuffle=True)
sess.close()


sess = tf.Session()
sess.run(tf.initialize_all_variables())
nntrainer.set_best_parameters(sess)
learn.train_minibatch(sess, nntrainer, data, batch_size=2000, num_epochs=20, 
                    patience=5, verbose=1, shuffle=True)
sess.close()

# %% [markdown]
# # residual model

# %%
# get shapes
num_data, height, width, dim = X_train.shape
input_shape=[None, height, width, dim]
num_labels = y_train.shape[1]  

# load model
net, placeholders, optimization = residual_connectomics_model.model(input_shape, num_labels)

# build neural network class
nnmodel = nn.NeuralNet(net, [placeholders['inputs']])

# set output file paths
resultspath = utils.make_directory('../results', 'tf-test')
output_name = '1d_version_residual'
filepath = os.path.join(resultspath, output_name)

# compile neural trainer
nntrainer = nn.NeuralTrainer(nnmodel, placeholders, optimization, save='best', filepath=filepath)

# %%
X = {'inputs': X_train, 'targets': y_train, 'keep_prob': 0.8, 'is_training': True}
X2 = {'inputs': X_valid, 'targets': y_valid, 'keep_prob': 1, 'is_training': False}
data = {'train': X, 'valid': X2}

sess = tf.Session()
sess.run(tf.initialize_all_variables())
learn.train_minibatch(sess, nntrainer, data, batch_size=100, num_epochs=20, 
                    patience=5, verbose=1, shuffle=True)
sess.close()

sess = tf.Session()
sess.run(tf.initialize_all_variables())
nntrainer.set_best_parameters(sess)
learn.train_minibatch(sess, nntrainer, data, batch_size=500, num_epochs=20, 
                    patience=5, verbose=1, shuffle=True)
sess.close()

sess = tf.Session()
sess.run(tf.initialize_all_variables())
nntrainer.set_best_parameters(sess)
learn.train_minibatch(sess, nntrainer, data, batch_size=1000, num_epochs=20, 
                    patience=5, verbose=1, shuffle=True)
sess.close()


sess = tf.Session()
sess.run(tf.initialize_all_variables())
nntrainer.set_best_parameters(sess)
learn.train_minibatch(sess, nntrainer, data, batch_size=1500, num_epochs=20, 
                    patience=5, verbose=1, shuffle=True)
sess.close()


sess = tf.Session()
sess.run(tf.initialize_all_variables())
nntrainer.set_best_parameters(sess)
learn.train_minibatch(sess, nntrainer, data, batch_size=2000, num_epochs=20, 
                    patience=5, verbose=1, shuffle=True)
sess.close()

# %% [markdown]
# # residual model 2

# %%
# get shapes
num_data, height, width, dim = X_train.shape
input_shape=[None, height, width, dim]
num_labels = y_train.shape[1]  

# load model
net, placeholders, optimization = residual_connectomics_model2.model(input_shape, num_labels)

# build neural network class
nnmodel = nn.NeuralNet(net, [placeholders['inputs']])

# set output file paths
resultspath = utils.make_directory('../results', 'tf-test')
output_name = '1d_version_residual2'
filepath = os.path.join(resultspath, output_name)

# compile neural trainer
nntrainer = nn.NeuralTrainer(nnmodel, placeholders, optimization, save='best', filepath=filepath)

# %%
X = {'inputs': X_train, 'targets': y_train, 'keep_prob': 0.8, 'is_training': True}
X2 = {'inputs': X_valid, 'targets': y_valid, 'keep_prob': 1, 'is_training': False}
data = {'train': X, 'valid': X2}

sess = tf.Session()
sess.run(tf.initialize_all_variables())
learn.train_minibatch(sess, nntrainer, data, batch_size=100, num_epochs=20, 
                    patience=5, verbose=1, shuffle=True)
sess.close()

sess = tf.Session()
sess.run(tf.initialize_all_variables())
nntrainer.set_best_parameters(sess)
learn.train_minibatch(sess, nntrainer, data, batch_size=500, num_epochs=20, 
                    patience=5, verbose=1, shuffle=True)
sess.close()

sess = tf.Session()
sess.run(tf.initialize_all_variables())
nntrainer.set_best_parameters(sess)
learn.train_minibatch(sess, nntrainer, data, batch_size=1000, num_epochs=20, 
                    patience=5, verbose=1, shuffle=True)
sess.close()


sess = tf.Session()
sess.run(tf.initialize_all_variables())
nntrainer.set_best_parameters(sess)
learn.train_minibatch(sess, nntrainer, data, batch_size=1500, num_epochs=20, 
                    patience=5, verbose=1, shuffle=True)
sess.close()


sess = tf.Session()
sess.run(tf.initialize_all_variables())
nntrainer.set_best_parameters(sess)
learn.train_minibatch(sess, nntrainer, data, batch_size=2000, num_epochs=20, 
                    patience=5, verbose=1, shuffle=True)
sess.close()
