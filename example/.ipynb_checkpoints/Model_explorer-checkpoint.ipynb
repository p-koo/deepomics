# %%
from __future__ import print_function 
import os, sys, time
import numpy as np
from six.moves import cPickle
from collections import OrderedDict

import tensorflow as tf
from tfomics import layers, utils, init, learn, explore
from tfomics import neuralnetwork as nn
from tfomics.build_network import *
from tfomics.models import simple_genome_model_explore

# %%
def load_data(filepath):
    # load training set
    print("loading data from: " + filepath)
    f = open(filepath, 'rb')
    print("loading train data")
    train = cPickle.load(f)
    print("loading cross-validation data")
    cross_validation = cPickle.load(f)
    print("loading test data")
    test = cPickle.load(f)
    f.close()

    X_train = train[0].transpose((0,2,1))
    y_train = train[1]
    X_valid = cross_validation[0].transpose((0,2,1))
    y_valid = cross_validation[1]
    X_test = test[0].transpose((0,2,1))
    y_test = test[1]
    
    X_train = X_train.reshape(X_train.shape + (1,)) 
    X_train = X_train.transpose([0,1,3,2]).astype(np.float32)
    y_train = y_train.astype(np.int32)

    X_valid = X_valid.reshape(X_valid.shape + (1,)) 
    X_valid = X_valid.transpose([0,1,3,2]).astype(np.float32)
    y_valid = y_valid.astype(np.int32)


    X_test = X_test.reshape(X_test.shape + (1,)) 
    X_test = X_test.transpose([0,1,3,2]).astype(np.float32)
    y_test = y_test.astype(np.int32)

    return X_train, y_train, X_valid, y_valid, X_test, y_test


# load data
filename = 'Localized_N=100000_S=200_M=50_G=20_data.pickle'
data_path = '.'
filepath = os.path.join(data_path,filename)
X_train, y_train, X_valid, y_valid, X_test, y_test = load_data(filepath)

# get shapes
num_data, seq_length, _, dim = X_train.shape
input_shape=[None, seq_length, 1, dim]
num_labels = y_train.shape[1]   # number of labels (output units)
# Out:
# loading data from: ./Localized_N=100000_S=200_M=50_G=20_data.pickle
# loading train data
# loading cross-validation data
# loading test data

# %%
model_layers, placeholders, optimization = simple_genome_model_explore.model(input_shape, num_labels)

# %%
# build neural optimizer 
optimizer = explore.NeuralOptimizer(model_layers, placeholders, optimization, filepath='test')

# %%
# optimize model parameters
train = {'inputs': X_train, 'targets': y_train, 'keep_prob': 0.8, 'is_training': True}
valid = {'inputs': X_valid, 'targets': y_valid, 'keep_prob': 1, 'is_training': False}        
optimizer.optimize(train, valid, num_trials=20, num_epochs=10, batch_size=128, verbose=0)
# Out:
# ---------------------------------------------------------
# Running baseline model
#
# Model layers:
# name: input
# name: conv1
# pool_size: 20
# filter_size: 19
# num_filters: 20
# name: dense1
# num_units: 20
#
# Optimization:
# learning_rate: 0.001
# l2: 1e-06
#
#     loss = 0.0488322605458
#     took 20.7668869495 seconds
#
# ---------------------------------------------------------
# trial 1 out of 20
# ---------------------------------------------------------
#
# Model layers:
# name: input
# name: conv1
# pool_size: 44
# filter_size: 6
# num_filters: 21
# name: dense1
# num_units: 20
#
# Optimization:
# learning_rate: 0.000224200193947
# l2: 7.5991753454e-05
#
# Results:
# loss = 0.0992584112337
# took 21.0445659161 seconds
#
# ---------------------------------------------------------
# trial 2 out of 20
# ---------------------------------------------------------
#
# Model layers:
# name: input
# name: conv1
# pool_size: 8
# filter_size: 6
# num_filters: 24
# name: dense1
# num_units: 20
#
# Optimization:
# learning_rate: 0.00180252858863
# l2: 2.08657069878e-08
#
# Results:
# loss = 0.0270653039185
# took 22.4998018742 seconds
# Lower loss found. Updating parameters
#
# ---------------------------------------------------------
# trial 3 out of 20
# ---------------------------------------------------------
#
# Model layers:
# name: input
# name: conv1
# pool_size: 20
# filter_size: 16
# num_filters: 20
# name: dense1
# num_units: 20
#
# Optimization:
# learning_rate: 0.0286311508583
# l2: 1.03397641344e-07
#
# Results:
# loss = 0.0493104385559
# took 20.4101560116 seconds
#
# ---------------------------------------------------------
# trial 4 out of 20
# ---------------------------------------------------------
#
# Model layers:
# name: input
# name: conv1
# pool_size: 12
# filter_size: 12
# num_filters: 36
# name: dense1
# num_units: 20
#
# Optimization:
# learning_rate: 0.000544296356015
# l2: 2.03784865084e-05
#
# Results:
# loss = 0.0340625238684
# took 28.9656739235 seconds
#
# ---------------------------------------------------------
# trial 5 out of 20
# ---------------------------------------------------------
#
# Model layers:
# name: input
# name: conv1
# pool_size: 4
# filter_size: 6
# num_filters: 5
# name: dense1
# num_units: 20
#
# Optimization:
# learning_rate: 0.00051141708695
# l2: 1.95095559848e-05
#
# Results:
# loss = 0.0397996828434
# took 13.9259469509 seconds
#
# ---------------------------------------------------------
# trial 6 out of 20
# ---------------------------------------------------------
#
# Model layers:
# name: input
# name: conv1
# pool_size: 32
# filter_size: 8
# num_filters: 21
# name: dense1
# num_units: 20
#
# Optimization:
# learning_rate: 0.0154174500871
# l2: 3.07016188026e-08
#
# Results:
# loss = 0.0772414378254
# took 22.9264960289 seconds
#
# ---------------------------------------------------------
# trial 7 out of 20
# ---------------------------------------------------------
#
# Model layers:
# name: input
# name: conv1
# pool_size: 4
# filter_size: 14
# num_filters: 16
# name: dense1
# num_units: 20
#
# Optimization:
# learning_rate: 0.00521966424999
# l2: 1.56494018584e-05
#
# Results:
# loss = 0.020703271797
# took 21.150274992 seconds
# Lower loss found. Updating parameters
#
# ---------------------------------------------------------
# trial 8 out of 20
# ---------------------------------------------------------
#
# Model layers:
# name: input
# name: conv1
# pool_size: 4
# filter_size: 12
# num_filters: 24
# name: dense1
# num_units: 20
#
# Optimization:
# learning_rate: 0.00230513364714
# l2: 4.45571019691e-06
#
# Results:
# loss = 0.0180193165365
# took 26.6124839783 seconds
# Lower loss found. Updating parameters
#
# ---------------------------------------------------------
# trial 9 out of 20
# ---------------------------------------------------------
#
# Model layers:
# name: input
# name: conv1
# pool_size: 4
# filter_size: 6
# num_filters: 55
# name: dense1
# num_units: 20
#
# Optimization:
# learning_rate: 0.00172986089754
# l2: 2.29123703037e-05
#
# Results:
# loss = 0.111505465803
# took 41.4799118042 seconds
#
# ---------------------------------------------------------
# trial 10 out of 20
# ---------------------------------------------------------
#
# Model layers:
# name: input
# name: conv1
# pool_size: 8
# filter_size: 10
# num_filters: 11
# name: dense1
# num_units: 20
#
# Optimization:
# learning_rate: 0.0130915141416
# l2: 2.97348076681e-07
#
# Results:
# loss = 0.037179907405
# took 19.2553350925 seconds
#
# ---------------------------------------------------------
# trial 11 out of 20
# ---------------------------------------------------------
#
# Model layers:
# name: input
# name: conv1
# pool_size: 8
# filter_size: 16
# num_filters: 27
# name: dense1
# num_units: 20
#
# Optimization:
# learning_rate: 0.00184403185965
# l2: 3.71863142398e-06
#
# Results:
# loss = 0.0245249108254
# took 28.7802438736 seconds
#
# ---------------------------------------------------------
# trial 12 out of 20
# ---------------------------------------------------------
#
# Model layers:
# name: input
# name: conv1
# pool_size: 4
# filter_size: 24
# num_filters: 33
# name: dense1
# num_units: 20
#
# Optimization:
# learning_rate: 0.0196284725189
# l2: 2.21092460403e-08
#
# Results:
# loss = 0.0214907295797
# took 33.7850542068 seconds
#
# ---------------------------------------------------------
# trial 13 out of 20
# ---------------------------------------------------------
#
# Model layers:
# name: input
# name: conv1
# pool_size: 20
# filter_size: 24
# num_filters: 64
# name: dense1
# num_units: 20
#
# Optimization:
# learning_rate: 0.00822289176497
# l2: 7.43353384516e-06
#
# Results:
# loss = 0.0318870079877
# took 44.1074631214 seconds
#
# ---------------------------------------------------------
# trial 14 out of 20
# ---------------------------------------------------------
#
# Model layers:
# name: input
# name: conv1
# pool_size: 20
# filter_size: 10
# num_filters: 20
# name: dense1
# num_units: 20
#
# Optimization:
# learning_rate: 0.00714140091916
# l2: 0.00168947230206
#
# Results:
# loss = 0.07881902354
# took 23.6678869724 seconds
#
# ---------------------------------------------------------
# trial 15 out of 20
# ---------------------------------------------------------
#
# Model layers:
# name: input
# name: conv1
# pool_size: 16
# filter_size: 26
# num_filters: 30
# name: dense1
# num_units: 20
#
# Optimization:
# learning_rate: 0.000106643118905
# l2: 0.000286345564194
#
# Results:
# loss = 0.0407187781786
# took 32.800082922 seconds
#
# ---------------------------------------------------------
# trial 16 out of 20
# ---------------------------------------------------------
#
# Model layers:
# name: input
# name: conv1
# pool_size: 24
# filter_size: 18
# num_filters: 32
# name: dense1
# num_units: 20
#
# Optimization:
# learning_rate: 0.0711504226579
# l2: 1.71223857005e-08
#
# Results:
# loss = 0.0489791383872
# took 31.6053600311 seconds
#
# ---------------------------------------------------------
# trial 17 out of 20
# ---------------------------------------------------------
#
# Model layers:
# name: input
# name: conv1
# pool_size: 8
# filter_size: 16
# num_filters: 8
# name: dense1
# num_units: 20
#
# Optimization:
# learning_rate: 0.0131247336214
# l2: 1.87552826213e-05
#
# Results:
# loss = 0.0467386824726
# took 20.2677378654 seconds
#
# ---------------------------------------------------------
# trial 18 out of 20
# ---------------------------------------------------------
#
# Model layers:
# name: input
# name: conv1
# pool_size: 4
# filter_size: 20
# num_filters: 44
# name: dense1
# num_units: 20
#
# Optimization:
# learning_rate: 0.0103232165636
# l2: 0.00130270197992
#
# Results:
# loss = 0.0338733951261
# took 40.1211509705 seconds
#
# ---------------------------------------------------------
# trial 19 out of 20
# ---------------------------------------------------------
#
# Model layers:
# name: input
# name: conv1
# pool_size: 12
# filter_size: 16
# num_filters: 26
# name: dense1
# num_units: 20
#
# Optimization:
# learning_rate: 0.000480846205261
# l2: 3.49172446628e-06
#
# Results:
# loss = 0.0324277561158
# took 30.9122340679 seconds
#
# ---------------------------------------------------------
# trial 20 out of 20
# ---------------------------------------------------------
#
# Model layers:
# name: input
# name: conv1
# pool_size: 4
# filter_size: 14
# num_filters: 40
# name: dense1
# num_units: 20
#
# Optimization:
# learning_rate: 0.0105463427392
# l2: 0.0013907800092
#
# Results:
# loss = 0.0306886222245
# took 37.48407197 seconds
#
# ---------------------------------------------------------

# %%
# save optimal model
optimizer.print_optimal_model()
# Out:
# Model layers:
# name: input
# name: conv1
# pool_size: 4
# filter_size: 12
# num_filters: 24
# name: dense1
# num_units: 20
#
# Optimization:
# learning_rate: 0.00230513364714
# l2: 4.45571019691e-06
