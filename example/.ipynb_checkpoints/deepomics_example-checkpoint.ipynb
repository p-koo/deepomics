# %%
from __future__ import print_function 
import os, sys, h5py
import numpy as np
from six.moves import cPickle
from collections import OrderedDict

sys.path.append('/home/peter/Code/deepomics')
from neuralnetwork import NeuralNet, NeuralTrainer
import train as fit 
import visualize, utils

from lasagne import layers, nonlinearities, updates, objectives, init 
from lasagne.layers import get_output, get_output_shape, get_all_params
import theano.tensor as T
import theano
np.random.seed(247) # for reproducibility

# %%
filename = 'processed_dataset.hdf5'
data_path = '/home/peter/Code/tensorflow/data'
file_path = os.path.join(data_path, filename)
group_name = ['processed_data']
dataset = h5py.File(file_path,'r')
# %time dtf = np.array(dataset['/'+group_name[0]+'/dtf'])
ltf = np.array(dataset['/'+group_name[0]+'/ltf'])
dtf_crossval = np.array(dataset['/'+group_name[0]+'/dtf_crossval'])
ltf_crossval = np.array(dataset['/'+group_name[0]+'/ltf_crossval'])

train = (dtf.transpose([0,3,1,2]), ltf)
valid = (dtf_crossval.transpose([0,3,1,2]), ltf_crossval)
# Out:
# CPU times: user 296 ms, sys: 596 ms, total: 892 ms
# Wall time: 888 ms

# %% [markdown]
# # original model

# %%
def build_model(shape, num_labels):

    # get model
    input_var = T.tensor4('inputs')
    target_var = T.dmatrix('targets')

    net = {}
    net['input'] = layers.InputLayer(input_var=input_var, shape=shape)
    net['conv1'] = layers.Conv2DLayer(net['input'], num_filters=18, filter_size=(2, 5), stride=(1, 1),    # 1000
                                        W=init.HeNormal(), b=init.Constant(0.1), 
                                      nonlinearity=nonlinearities.tanh, pad='valid')

    net['conv2'] = layers.Conv2DLayer(net['conv1'], num_filters=40, filter_size=(2, 5), stride=(1, 1), # 18
                                        W=init.HeNormal(), b=init.Constant(0.1), 
                                      nonlinearity=nonlinearities.tanh, pad='valid')
    net['conv2_pool'] = layers.MaxPool2DLayer(net['conv2'], pool_size=(1, 10), stride=(1, 10)) # 25

    net['conv3'] = layers.Conv2DLayer(net['conv2_pool'], num_filters=15, filter_size=(1, 1), stride=(1, 1), # 18
                                        W=init.HeNormal(), b=init.Constant(0.1), 
                                      nonlinearity=nonlinearities.tanh, pad='valid')

    net['dense1'] = layers.DenseLayer(net['conv3'], num_units=100, W=init.HeNormal(), 
                                     b=init.Constant(), nonlinearity=nonlinearities.rectify)
    
    net['output'] = layers.DenseLayer(net['dense1'], num_units=num_labels, W=init.HeNormal(), 
                                     b=init.Constant(), nonlinearity=nonlinearities.sigmoid)
    
    # optimization parameters
    optimization = {"objective": "binary",
                    "optimizer": "sgd",
                    "learning_rate": 0.001, 
                    "l2": 1e-6
                    }

    return net, input_var, target_var, optimization

# build network
shape = (None, train[0].shape[1], train[0].shape[2], train[0].shape[3])
num_labels = train[1].shape[1]
net, input_var, target_var, optimization = build_model(shape, num_labels)

# build neural network class
nnmodel = NeuralNet(net, input_var, target_var)
#nnmodel.inspect_layers()

# set output file paths
resultspath = utils.make_directory('../results', 'test')
output_name = 'original_model'
filepath = os.path.join(resultspath, output_name)
savepath = utils.make_directory(resultspath, output_name)
nntrainer = NeuralTrainer(nnmodel, optimization, save='best', filepath=filepath)
# Out:
# compiling model

# %%
learning_rate_schedule = {  0: 0.001,
                            2: 0.1,
                            5: 0.01,
                            15: 0.001,
                            25: 0.0001
                            }
data={'train': train, 'valid': valid}
fit.train_variable_learning_rate(nntrainer, data, learning_rate_schedule, 
                                batch_size=128, num_epochs=500, patience=10, verbose=1)
# Out:
# Epoch 1 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.39365 -- accuracy=84.26%
#   valid loss:		0.36746
#   valid accuracy:	0.85600+/-0.00016
#   valid auc-roc:	0.91164+/-0.00001
#   valid auc-pr:		0.90280+/-0.00685
# saving model parameters to: ../results/test/original_model_best.pickle
# Epoch 2 out of 500
# [===========                   ] 37.4% -- time=26s -- loss=0.37136 -- accuracy=85.49%

# %%
# train model
fit.train_minibatch(nntrainer, data={'train': train, 'valid': valid}, 
                              batch_size=1000, num_epochs=500, patience=10, verbose=1)
# Out:
# Epoch 1 out of 500
# [======                        ] 19.4% -- time=21s -- loss=0.71487 -- accuracy=49.97%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-a503fb987062> in <module>()
#       1 # train model
#       2 fit.train_minibatch(nntrainer, data={'train': train, 'valid': valid},
# ----> 3                               batch_size=1000, num_epochs=500, patience=10, verbose=1)
#
# /home/peter/Code/deepomics/train.py in train_minibatch(nntrainer, data, batch_size, num_epochs, patience, verbose, shuffle)
#      28
#      29                 # training set
# ---> 30                 train_loss = nntrainer.train_step(data['train'], batch_size, verbose, shuffle)
#      31                 nntrainer.add_loss(train_loss, 'train')
#      32
#
# /home/peter/Code/deepomics/neuralnetwork.pyc in train_step(self, train, batch_size, verbose, shuffle)
#     221                 for i in range(num_batches):
#     222                         X, y = next(batches)
# --> 223                         loss, prediction = self.train_fun(X, y)
#     224                         value += self.train_metric(prediction, y)
#     225                         performance.add_loss(loss)
#
# /home/peter/Theano/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     864         try:
#     865             outputs =\
# --> 866                 self.fn() if output_subset is None else\
#     867                 self.fn(output_subset=output_subset)
#     868         except Exception:
#
# /home/peter/Theano/theano/gof/op.pyc in rval(p, i, o, n)
#     863         if params is graph.NoParams:
#     864             # default arguments are stored in the closure of `rval`
# --> 865             def rval(p=p, i=node_input_storage, o=node_output_storage, n=node):
#     866                 r = p(n, [x[0] for x in i], o)
#     867                 for o in node.outputs:
#
# KeyboardInterrupt:

# %%
# train model
fit.train_minibatch(nntrainer, data={'train': train, 'valid': valid}, 
                              batch_size=100, num_epochs=500, patience=10, verbose=1)
# Out:
# Epoch 1 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.38128 -- accuracy=85.06%
#   valid loss:		0.36378
#   valid accuracy:	0.85684+/-0.00011
#   valid auc-roc:	0.91449+/-0.00001
#   valid auc-pr:		0.90742+/-0.00783
# saving model parameters to: ../results/test/original_model_best.pickle
# Epoch 2 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.36305 -- accuracy=85.74%
#   valid loss:		0.36262
#   valid accuracy:	0.85725+/-0.00020
#   valid auc-roc:	0.91755+/-0.00002
#   valid auc-pr:		0.91158+/-0.00707
# saving model parameters to: ../results/test/original_model_best.pickle
# Epoch 3 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35763 -- accuracy=85.96%
#   valid loss:		0.35319
#   valid accuracy:	0.86071+/-0.00006
#   valid auc-roc:	0.91986+/-0.00001
#   valid auc-pr:		0.91424+/-0.00624
# saving model parameters to: ../results/test/original_model_best.pickle
# Epoch 4 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35420 -- accuracy=86.06%
#   valid loss:		0.35481
#   valid accuracy:	0.86034+/-0.00002
#   valid auc-roc:	0.92065+/-0.00000
#   valid auc-pr:		0.91521+/-0.00631
# Epoch 5 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35188 -- accuracy=86.14%
#   valid loss:		0.34972
#   valid accuracy:	0.86159+/-0.00002
#   valid auc-roc:	0.92171+/-0.00000
#   valid auc-pr:		0.91654+/-0.00563
# saving model parameters to: ../results/test/original_model_best.pickle
# Epoch 6 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34997 -- accuracy=86.21%
#   valid loss:		0.35062
#   valid accuracy:	0.86142+/-0.00004
#   valid auc-roc:	0.92231+/-0.00003
#   valid auc-pr:		0.91729+/-0.00525
# Epoch 7 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34832 -- accuracy=86.24%
#   valid loss:		0.34820
#   valid accuracy:	0.86268+/-0.00005
#   valid auc-roc:	0.92236+/-0.00000
#   valid auc-pr:		0.91722+/-0.00555
# saving model parameters to: ../results/test/original_model_best.pickle
# Epoch 8 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34732 -- accuracy=86.29%
#   valid loss:		0.34762
#   valid accuracy:	0.86284+/-0.00001
#   valid auc-roc:	0.92262+/-0.00001
#   valid auc-pr:		0.91760+/-0.00489
# saving model parameters to: ../results/test/original_model_best.pickle
# Epoch 9 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34621 -- accuracy=86.31%
#   valid loss:		0.34792
#   valid accuracy:	0.86300+/-0.00001
#   valid auc-roc:	0.92304+/-0.00000
#   valid auc-pr:		0.91808+/-0.00512
# Epoch 10 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34534 -- accuracy=86.38%
#   valid loss:		0.34694
#   valid accuracy:	0.86257+/-0.00000
#   valid auc-roc:	0.92301+/-0.00000
#   valid auc-pr:		0.91801+/-0.00502
# saving model parameters to: ../results/test/original_model_best.pickle
# Epoch 11 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34423 -- accuracy=86.41%
#   valid loss:		0.34740
#   valid accuracy:	0.86234+/-0.00000
#   valid auc-roc:	0.92267+/-0.00000
#   valid auc-pr:		0.91765+/-0.00483
# Epoch 12 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34347 -- accuracy=86.42%
#   valid loss:		0.34876
#   valid accuracy:	0.86271+/-0.00000
#   valid auc-roc:	0.92287+/-0.00000
#   valid auc-pr:		0.91766+/-0.00484
# Epoch 13 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34255 -- accuracy=86.46%
#   valid loss:		0.35763
#   valid accuracy:	0.86245+/-0.00000
#   valid auc-roc:	0.92288+/-0.00000
#   valid auc-pr:		0.91794+/-0.00502
# Epoch 14 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34204 -- accuracy=86.49%
#   valid loss:		0.34851
#   valid accuracy:	0.86258+/-0.00000
#   valid auc-roc:	0.92281+/-0.00000
#   valid auc-pr:		0.91784+/-0.00437
# Epoch 15 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34132 -- accuracy=86.50%
#   valid loss:		0.34629
#   valid accuracy:	0.86335+/-0.00000
#   valid auc-roc:	0.92362+/-0.00000
#   valid auc-pr:		0.91874+/-0.00457
# saving model parameters to: ../results/test/original_model_best.pickle
# Epoch 16 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34064 -- accuracy=86.52%
#   valid loss:		0.34623
#   valid accuracy:	0.86267+/-0.00000
#   valid auc-roc:	0.92366+/-0.00000
#   valid auc-pr:		0.91870+/-0.00443
# saving model parameters to: ../results/test/original_model_best.pickle
# Epoch 17 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34022 -- accuracy=86.55%
#   valid loss:		0.34830
#   valid accuracy:	0.86216+/-0.00000
#   valid auc-roc:	0.92318+/-0.00000
#   valid auc-pr:		0.91821+/-0.00415
# Epoch 18 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33958 -- accuracy=86.58%
#   valid loss:		0.35362
#   valid accuracy:	0.85835+/-0.00000
#   valid auc-roc:	0.92351+/-0.00000
#   valid auc-pr:		0.91866+/-0.00391
# Epoch 19 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33920 -- accuracy=86.58%
#   valid loss:		0.34733
#   valid accuracy:	0.86239+/-0.00000
#   valid auc-roc:	0.92304+/-0.00000
#   valid auc-pr:		0.91804+/-0.00436
# Epoch 20 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33866 -- accuracy=86.60%
#   valid loss:		0.34798
#   valid accuracy:	0.86085+/-0.00000
#   valid auc-roc:	0.92393+/-0.00000
#   valid auc-pr:		0.91912+/-0.00398
# Epoch 21 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33827 -- accuracy=86.63%
#   valid loss:		0.34575
#   valid accuracy:	0.86295+/-0.00000
#   valid auc-roc:	0.92357+/-0.00000
#   valid auc-pr:		0.91860+/-0.00405
# saving model parameters to: ../results/test/original_model_best.pickle
# Epoch 22 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33805 -- accuracy=86.63%
#   valid loss:		0.34606
#   valid accuracy:	0.86258+/-0.00000
#   valid auc-roc:	0.92368+/-0.00000
#   valid auc-pr:		0.91850+/-0.00381
# Epoch 23 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33739 -- accuracy=86.63%
#   valid loss:		0.34651
#   valid accuracy:	0.86300+/-0.00000
#   valid auc-roc:	0.92382+/-0.00000
#   valid auc-pr:		0.91897+/-0.00402
# Epoch 24 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33711 -- accuracy=86.66%
#   valid loss:		0.34893
#   valid accuracy:	0.86301+/-0.00000
#   valid auc-roc:	0.92335+/-0.00000
#   valid auc-pr:		0.91824+/-0.00431
# Epoch 25 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33692 -- accuracy=86.68%
#   valid loss:		0.35183
#   valid accuracy:	0.86295+/-0.00000
#   valid auc-roc:	0.92370+/-0.00000
#   valid auc-pr:		0.91856+/-0.00422
# Epoch 26 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33649 -- accuracy=86.69%
#   valid loss:		0.34699
#   valid accuracy:	0.86147+/-0.00000
#   valid auc-roc:	0.92407+/-0.00000
#   valid auc-pr:		0.91912+/-0.00413
# Epoch 27 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33625 -- accuracy=86.70%
#   valid loss:		0.34736
#   valid accuracy:	0.86337+/-0.00000
#   valid auc-roc:	0.92371+/-0.00000
#   valid auc-pr:		0.91860+/-0.00410
# Epoch 28 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33599 -- accuracy=86.69%
#   valid loss:		0.34985
#   valid accuracy:	0.86205+/-0.00000
#   valid auc-roc:	0.92321+/-0.00000
#   valid auc-pr:		0.91804+/-0.00401
# Epoch 29 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33538 -- accuracy=86.73%
#   valid loss:		0.35125
#   valid accuracy:	0.86045+/-0.00000
#   valid auc-roc:	0.92335+/-0.00000
#   valid auc-pr:		0.91821+/-0.00403
# Epoch 30 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33515 -- accuracy=86.74%
#   valid loss:		0.34587
#   valid accuracy:	0.86271+/-0.00000
#   valid auc-roc:	0.92398+/-0.00000
#   valid auc-pr:		0.91893+/-0.00386
# Epoch 31 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33489 -- accuracy=86.74%
#   valid loss:		0.34806
#   valid accuracy:	0.86306+/-0.00000
#   valid auc-roc:	0.92376+/-0.00000
#   valid auc-pr:		0.91847+/-0.00401
# Epoch 32 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33475 -- accuracy=86.74%
#   valid loss:		0.34751
#   valid accuracy:	0.86304+/-0.00000
#   valid auc-roc:	0.92371+/-0.00000
#   valid auc-pr:		0.91859+/-0.00363
# Patience ran out... Early stopping.
# <neuralnetwork.NeuralTrainer instance at 0x7f46bf8f7248>

# %%
nntrainer.set_best_parameters()

# test model
nntrainer.test_model(valid, batch_size=100, name="test")
# Out:
#   test  loss:		0.34575
#   test  accuracy:	0.86295+/-0.00000
#   test  auc-roc:	0.92357+/-0.00000
#   test  auc-pr:		0.91860+/-0.00405
# 0.34574883391341721

# %% [markdown]
# # original model w/ batch norm and dropout and relu

# %%
def build_model(shape, num_labels):

    # get model
    input_var = T.tensor4('inputs')
    target_var = T.dmatrix('targets')

    net = {}
    net['input'] = layers.InputLayer(input_var=input_var, shape=shape)
    net['conv1'] = layers.Conv2DLayer(net['input'], num_filters=18, filter_size=(2, 5), stride=(1, 1),    # 1000
                                        W=init.HeNormal(), b=None, nonlinearity=None, pad='valid')
    net['conv1_norm'] = layers.BatchNormLayer(net['conv1'])
    net['conv1_active'] = layers.NonlinearityLayer(net['conv1_norm'], nonlinearity=nonlinearities.rectify)
    net['conv1_dropout'] = layers.DropoutLayer(net['conv1_active'], p=0.1)

    net['conv2'] = layers.Conv2DLayer(net['conv1_dropout'], num_filters=40, filter_size=(2, 5), stride=(1, 1), # 18
                                        W=init.HeNormal(), b=None, nonlinearity=None, pad='valid')
    net['conv2_norm'] = layers.BatchNormLayer(net['conv2'])
    net['conv2_active'] = layers.NonlinearityLayer(net['conv2_norm'], nonlinearity=nonlinearities.rectify)
    net['conv2_pool'] = layers.MaxPool2DLayer(net['conv2_active'], pool_size=(1, 10), stride=(1, 10)) # 25
    net['conv2_dropout'] = layers.DropoutLayer(net['conv2_pool'], p=0.1)

    net['conv3'] = layers.Conv2DLayer(net['conv2_dropout'], num_filters=15, filter_size=(1, 1), stride=(1, 1), # 18
                                        W=init.HeNormal(), b=None, nonlinearity=None, pad='valid')
    net['conv3_norm'] = layers.BatchNormLayer(net['conv3'])
    net['conv3_active'] = layers.NonlinearityLayer(net['conv3_norm'], nonlinearity=nonlinearities.rectify)
    net['conv3_dropout'] = layers.DropoutLayer(net['conv3_active'], p=0.1)

    net['dense1'] = layers.DenseLayer(net['conv3_dropout'], num_units=100, W=init.HeNormal(), 
                                     b=init.Constant(), nonlinearity=None)
    net['dense1_active'] = layers.NonlinearityLayer(net['dense1'], nonlinearity=nonlinearities.rectify)
    net['dense1_dropout'] = layers.DropoutLayer(net['dense1_active'], p=0.5)
    
    net['dense2'] = layers.DenseLayer(net['dense1_dropout'], num_units=num_labels, W=init.HeNormal(), 
                                     b=init.Constant(), nonlinearity=None)
    net['output'] = layers.NonlinearityLayer(net['dense2'], nonlinearity=nonlinearities.sigmoid)
    
    # optimization parameters
    optimization = {"objective": "binary",
                    "optimizer": "adam",
                    "learning_rate": 0.0003, 
                    "l2": 1e-6
                    }

    return net, input_var, target_var, optimization

# build network
shape = (None, train[0].shape[1], train[0].shape[2], train[0].shape[3])
num_labels = train[1].shape[1]
net, input_var, target_var, optimization = build_model(shape, num_labels)

# build neural network class
nnmodel = NeuralNet(net, input_var, target_var)
#nnmodel.inspect_layers()

# set output file paths
resultspath = utils.make_directory('../results', 'test')
output_name = 'original_model_bells'
filepath = os.path.join(resultspath, output_name)
savepath = utils.make_directory(resultspath, output_name)
nntrainer = NeuralTrainer(nnmodel, optimization, save='best', filepath=filepath)
# Out:
# making directory: ../results/test/original_model_bells
# compiling model

# %%
# train model
fit.train_minibatch(nntrainer, data={'train': train, 'valid': valid}, 
                              batch_size=100, num_epochs=500, patience=10, verbose=1)
# Out:
# Epoch 1 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.39857 -- accuracy=84.39%
#   valid loss:		0.36279
#   valid accuracy:	0.85643+/-0.00001
#   valid auc-roc:	0.91483+/-0.00000
#   valid auc-pr:		0.90779+/-0.00631
# saving model parameters to: ../results/test/original_model_bells_best.pickle
# Epoch 2 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.37279 -- accuracy=85.46%
#   valid loss:		0.35463
#   valid accuracy:	0.85852+/-0.00005
#   valid auc-roc:	0.91906+/-0.00000
#   valid auc-pr:		0.91306+/-0.00617
# saving model parameters to: ../results/test/original_model_bells_best.pickle
# Epoch 3 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.36605 -- accuracy=85.70%
#   valid loss:		0.35071
#   valid accuracy:	0.86054+/-0.00004
#   valid auc-roc:	0.92112+/-0.00001
#   valid auc-pr:		0.91543+/-0.00576
# saving model parameters to: ../results/test/original_model_bells_best.pickle
# Epoch 4 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.36133 -- accuracy=85.90%
#   valid loss:		0.34831
#   valid accuracy:	0.86197+/-0.00001
#   valid auc-roc:	0.92286+/-0.00000
#   valid auc-pr:		0.91769+/-0.00491
# saving model parameters to: ../results/test/original_model_bells_best.pickle
# Epoch 5 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35867 -- accuracy=86.01%
#   valid loss:		0.34609
#   valid accuracy:	0.86249+/-0.00001
#   valid auc-roc:	0.92387+/-0.00000
#   valid auc-pr:		0.91883+/-0.00485
# saving model parameters to: ../results/test/original_model_bells_best.pickle
# Epoch 6 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35705 -- accuracy=86.08%
#   valid loss:		0.34673
#   valid accuracy:	0.86289+/-0.00001
#   valid auc-roc:	0.92470+/-0.00000
#   valid auc-pr:		0.91991+/-0.00426
# Epoch 7 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35534 -- accuracy=86.14%
#   valid loss:		0.34336
#   valid accuracy:	0.86376+/-0.00001
#   valid auc-roc:	0.92520+/-0.00000
#   valid auc-pr:		0.92053+/-0.00417
# saving model parameters to: ../results/test/original_model_bells_best.pickle
# Epoch 8 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35447 -- accuracy=86.20%
#   valid loss:		0.34266
#   valid accuracy:	0.86381+/-0.00000
#   valid auc-roc:	0.92546+/-0.00000
#   valid auc-pr:		0.92078+/-0.00414
# saving model parameters to: ../results/test/original_model_bells_best.pickle
# Epoch 9 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35341 -- accuracy=86.19%
#   valid loss:		0.34418
#   valid accuracy:	0.86350+/-0.00000
#   valid auc-roc:	0.92530+/-0.00000
#   valid auc-pr:		0.92082+/-0.00394
# Epoch 10 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35251 -- accuracy=86.24%
#   valid loss:		0.34109
#   valid accuracy:	0.86420+/-0.00000
#   valid auc-roc:	0.92626+/-0.00000
#   valid auc-pr:		0.92171+/-0.00373
# saving model parameters to: ../results/test/original_model_bells_best.pickle
# Epoch 11 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35200 -- accuracy=86.25%
#   valid loss:		0.34136
#   valid accuracy:	0.86433+/-0.00000
#   valid auc-roc:	0.92623+/-0.00000
#   valid auc-pr:		0.92168+/-0.00350
# Epoch 12 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35150 -- accuracy=86.25%
#   valid loss:		0.34138
#   valid accuracy:	0.86444+/-0.00000
#   valid auc-roc:	0.92675+/-0.00000
#   valid auc-pr:		0.92232+/-0.00346
# Epoch 13 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35085 -- accuracy=86.28%
#   valid loss:		0.34133
#   valid accuracy:	0.86435+/-0.00000
#   valid auc-roc:	0.92683+/-0.00000
#   valid auc-pr:		0.92243+/-0.00328
# Epoch 14 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35064 -- accuracy=86.30%
#   valid loss:		0.33978
#   valid accuracy:	0.86412+/-0.00000
#   valid auc-roc:	0.92690+/-0.00000
#   valid auc-pr:		0.92250+/-0.00348
# saving model parameters to: ../results/test/original_model_bells_best.pickle
# Epoch 15 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35012 -- accuracy=86.31%
#   valid loss:		0.34053
#   valid accuracy:	0.86458+/-0.00000
#   valid auc-roc:	0.92717+/-0.00000
#   valid auc-pr:		0.92287+/-0.00325
# Epoch 16 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35001 -- accuracy=86.31%
#   valid loss:		0.34130
#   valid accuracy:	0.86486+/-0.00000
#   valid auc-roc:	0.92725+/-0.00000
#   valid auc-pr:		0.92294+/-0.00304
# Epoch 17 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34966 -- accuracy=86.31%
#   valid loss:		0.33888
#   valid accuracy:	0.86479+/-0.00000
#   valid auc-roc:	0.92736+/-0.00000
#   valid auc-pr:		0.92313+/-0.00322
# saving model parameters to: ../results/test/original_model_bells_best.pickle
# Epoch 18 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34921 -- accuracy=86.34%
#   valid loss:		0.34088
#   valid accuracy:	0.86481+/-0.00000
#   valid auc-roc:	0.92733+/-0.00000
#   valid auc-pr:		0.92313+/-0.00284
# Epoch 19 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34897 -- accuracy=86.35%
#   valid loss:		0.34015
#   valid accuracy:	0.86491+/-0.00000
#   valid auc-roc:	0.92756+/-0.00000
#   valid auc-pr:		0.92344+/-0.00291
# Epoch 20 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34871 -- accuracy=86.35%
#   valid loss:		0.34006
#   valid accuracy:	0.86501+/-0.00000
#   valid auc-roc:	0.92786+/-0.00000
#   valid auc-pr:		0.92370+/-0.00279
# Epoch 21 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34844 -- accuracy=86.37%
#   valid loss:		0.34021
#   valid accuracy:	0.86527+/-0.00000
#   valid auc-roc:	0.92781+/-0.00000
#   valid auc-pr:		0.92367+/-0.00277
# Epoch 22 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34809 -- accuracy=86.38%
#   valid loss:		0.33974
#   valid accuracy:	0.86465+/-0.00000
#   valid auc-roc:	0.92781+/-0.00000
#   valid auc-pr:		0.92374+/-0.00282
# Epoch 23 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34812 -- accuracy=86.36%
#   valid loss:		0.34021
#   valid accuracy:	0.86520+/-0.00000
#   valid auc-roc:	0.92782+/-0.00000
#   valid auc-pr:		0.92378+/-0.00272
# Epoch 24 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34796 -- accuracy=86.36%
#   valid loss:		0.34196
#   valid accuracy:	0.86441+/-0.00000
#   valid auc-roc:	0.92784+/-0.00000
#   valid auc-pr:		0.92361+/-0.00295
# Epoch 25 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34767 -- accuracy=86.39%
#   valid loss:		0.34007
#   valid accuracy:	0.86496+/-0.00000
#   valid auc-roc:	0.92772+/-0.00000
#   valid auc-pr:		0.92373+/-0.00278
# Epoch 26 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34774 -- accuracy=86.40%
#   valid loss:		0.33846
#   valid accuracy:	0.86530+/-0.00000
#   valid auc-roc:	0.92797+/-0.00000
#   valid auc-pr:		0.92398+/-0.00265
# saving model parameters to: ../results/test/original_model_bells_best.pickle
# Epoch 27 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34779 -- accuracy=86.39%
#   valid loss:		0.33781
#   valid accuracy:	0.86560+/-0.00000
#   valid auc-roc:	0.92816+/-0.00000
#   valid auc-pr:		0.92415+/-0.00267
# saving model parameters to: ../results/test/original_model_bells_best.pickle
# Epoch 28 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34778 -- accuracy=86.36%
#   valid loss:		0.33939
#   valid accuracy:	0.86565+/-0.00000
#   valid auc-roc:	0.92842+/-0.00000
#   valid auc-pr:		0.92431+/-0.00269
# Epoch 29 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34711 -- accuracy=86.42%
#   valid loss:		0.33966
#   valid accuracy:	0.86536+/-0.00000
#   valid auc-roc:	0.92820+/-0.00000
#   valid auc-pr:		0.92414+/-0.00278
# Epoch 30 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34717 -- accuracy=86.40%
#   valid loss:		0.33783
#   valid accuracy:	0.86508+/-0.00000
#   valid auc-roc:	0.92831+/-0.00000
#   valid auc-pr:		0.92421+/-0.00244
# Epoch 31 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34723 -- accuracy=86.40%
#   valid loss:		0.34054
#   valid accuracy:	0.86540+/-0.00000
#   valid auc-roc:	0.92824+/-0.00000
#   valid auc-pr:		0.92417+/-0.00236
# Epoch 32 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34670 -- accuracy=86.41%
#   valid loss:		0.33764
#   valid accuracy:	0.86555+/-0.00000
#   valid auc-roc:	0.92859+/-0.00000
#   valid auc-pr:		0.92449+/-0.00244
# saving model parameters to: ../results/test/original_model_bells_best.pickle
# Epoch 33 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34652 -- accuracy=86.41%
#   valid loss:		0.33892
#   valid accuracy:	0.86529+/-0.00000
#   valid auc-roc:	0.92852+/-0.00000
#   valid auc-pr:		0.92448+/-0.00252
# Epoch 34 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34669 -- accuracy=86.42%
#   valid loss:		0.33961
#   valid accuracy:	0.86523+/-0.00000
#   valid auc-roc:	0.92862+/-0.00000
#   valid auc-pr:		0.92446+/-0.00273
# Epoch 35 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34657 -- accuracy=86.40%
#   valid loss:		0.33763
#   valid accuracy:	0.86573+/-0.00000
#   valid auc-roc:	0.92886+/-0.00000
#   valid auc-pr:		0.92489+/-0.00240
# saving model parameters to: ../results/test/original_model_bells_best.pickle
# Epoch 36 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34650 -- accuracy=86.41%
#   valid loss:		0.34017
#   valid accuracy:	0.86530+/-0.00000
#   valid auc-roc:	0.92874+/-0.00000
#   valid auc-pr:		0.92478+/-0.00235
# Epoch 37 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34659 -- accuracy=86.43%
#   valid loss:		0.33650
#   valid accuracy:	0.86547+/-0.00000
#   valid auc-roc:	0.92858+/-0.00000
#   valid auc-pr:		0.92458+/-0.00249
# saving model parameters to: ../results/test/original_model_bells_best.pickle
# Epoch 38 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34606 -- accuracy=86.45%
#   valid loss:		0.33889
#   valid accuracy:	0.86485+/-0.00000
#   valid auc-roc:	0.92835+/-0.00000
#   valid auc-pr:		0.92444+/-0.00252
# Epoch 39 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34581 -- accuracy=86.44%
#   valid loss:		0.33641
#   valid accuracy:	0.86573+/-0.00000
#   valid auc-roc:	0.92891+/-0.00000
#   valid auc-pr:		0.92496+/-0.00236
# saving model parameters to: ../results/test/original_model_bells_best.pickle
# Epoch 40 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34578 -- accuracy=86.42%
#   valid loss:		0.33697
#   valid accuracy:	0.86586+/-0.00000
#   valid auc-roc:	0.92885+/-0.00000
#   valid auc-pr:		0.92474+/-0.00266
# Epoch 41 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34608 -- accuracy=86.44%
#   valid loss:		0.33606
#   valid accuracy:	0.86591+/-0.00000
#   valid auc-roc:	0.92893+/-0.00000
#   valid auc-pr:		0.92501+/-0.00241
# saving model parameters to: ../results/test/original_model_bells_best.pickle
# Epoch 42 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34575 -- accuracy=86.45%
#   valid loss:		0.33653
#   valid accuracy:	0.86577+/-0.00000
#   valid auc-roc:	0.92895+/-0.00000
#   valid auc-pr:		0.92507+/-0.00234
# Epoch 43 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34547 -- accuracy=86.43%
#   valid loss:		0.33638
#   valid accuracy:	0.86615+/-0.00000
#   valid auc-roc:	0.92898+/-0.00000
#   valid auc-pr:		0.92498+/-0.00253
# Epoch 44 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34568 -- accuracy=86.45%
#   valid loss:		0.33581
#   valid accuracy:	0.86602+/-0.00000
#   valid auc-roc:	0.92901+/-0.00000
#   valid auc-pr:		0.92502+/-0.00241
# saving model parameters to: ../results/test/original_model_bells_best.pickle
# Epoch 45 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34530 -- accuracy=86.43%
#   valid loss:		0.33664
#   valid accuracy:	0.86571+/-0.00000
#   valid auc-roc:	0.92919+/-0.00000
#   valid auc-pr:		0.92536+/-0.00234
# Epoch 46 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34535 -- accuracy=86.44%
#   valid loss:		0.33766
#   valid accuracy:	0.86570+/-0.00000
#   valid auc-roc:	0.92899+/-0.00000
#   valid auc-pr:		0.92508+/-0.00237
# Epoch 47 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34507 -- accuracy=86.48%
#   valid loss:		0.33517
#   valid accuracy:	0.86602+/-0.00000
#   valid auc-roc:	0.92924+/-0.00000
#   valid auc-pr:		0.92533+/-0.00241
# saving model parameters to: ../results/test/original_model_bells_best.pickle
# Epoch 48 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34499 -- accuracy=86.45%
#   valid loss:		0.33714
#   valid accuracy:	0.86546+/-0.00000
#   valid auc-roc:	0.92910+/-0.00000
#   valid auc-pr:		0.92515+/-0.00242
# Epoch 49 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34501 -- accuracy=86.46%
#   valid loss:		0.33627
#   valid accuracy:	0.86587+/-0.00000
#   valid auc-roc:	0.92929+/-0.00000
#   valid auc-pr:		0.92535+/-0.00250
# Epoch 50 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34484 -- accuracy=86.46%
#   valid loss:		0.33683
#   valid accuracy:	0.86555+/-0.00000
#   valid auc-roc:	0.92920+/-0.00000
#   valid auc-pr:		0.92542+/-0.00241
# Epoch 51 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34469 -- accuracy=86.50%
#   valid loss:		0.33702
#   valid accuracy:	0.86595+/-0.00000
#   valid auc-roc:	0.92934+/-0.00000
#   valid auc-pr:		0.92550+/-0.00237
# Epoch 52 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34484 -- accuracy=86.45%
#   valid loss:		0.33724
#   valid accuracy:	0.86605+/-0.00000
#   valid auc-roc:	0.92935+/-0.00000
#   valid auc-pr:		0.92559+/-0.00241
# Epoch 53 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34483 -- accuracy=86.46%
#   valid loss:		0.33620
#   valid accuracy:	0.86626+/-0.00000
#   valid auc-roc:	0.92940+/-0.00000
#   valid auc-pr:		0.92549+/-0.00252
# Epoch 54 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34454 -- accuracy=86.49%
#   valid loss:		0.33572
#   valid accuracy:	0.86619+/-0.00000
#   valid auc-roc:	0.92920+/-0.00000
#   valid auc-pr:		0.92549+/-0.00244
# Epoch 55 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34474 -- accuracy=86.50%
#   valid loss:		0.33690
#   valid accuracy:	0.86598+/-0.00000
#   valid auc-roc:	0.92919+/-0.00000
#   valid auc-pr:		0.92545+/-0.00251
# Epoch 56 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34454 -- accuracy=86.48%
#   valid loss:		0.33567
#   valid accuracy:	0.86614+/-0.00000
#   valid auc-roc:	0.92948+/-0.00000
#   valid auc-pr:		0.92572+/-0.00246
# Epoch 57 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34453 -- accuracy=86.49%
#   valid loss:		0.33593
#   valid accuracy:	0.86634+/-0.00000
#   valid auc-roc:	0.92926+/-0.00000
#   valid auc-pr:		0.92548+/-0.00245
# Epoch 58 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34427 -- accuracy=86.48%
#   valid loss:		0.33610
#   valid accuracy:	0.86623+/-0.00000
#   valid auc-roc:	0.92959+/-0.00000
#   valid auc-pr:		0.92576+/-0.00239
# Patience ran out... Early stopping.
# <neuralnetwork.NeuralTrainer instance at 0x7f46ae07e5f0>

# %%
nntrainer.set_best_parameters()

# test model
nntrainer.test_model(valid, batch_size=100, name="test")
# Out:
#   test  loss:		0.33517
#   test  accuracy:	0.86602+/-0.00000
#   test  auc-roc:	0.92924+/-0.00000
#   test  auc-pr:		0.92533+/-0.00241
# 0.33517453034373335

# %% [markdown]
# # modified network (wider + batch norm + dropout + prelu)

# %%
def build_model(shape, num_labels):

    # get model
    input_var = T.tensor4('inputs')
    target_var = T.dmatrix('targets')

    net = {}
    net['input'] = layers.InputLayer(input_var=input_var, shape=shape)
    net['conv1'] = layers.Conv2DLayer(net['input'], num_filters=32, filter_size=(2, 5), stride=(1, 1),    # 1000
                                        W=init.HeNormal(), b=None, nonlinearity=None, pad='valid')
    net['conv1_norm'] = layers.BatchNormLayer(net['conv1'])
    net['conv1_active'] = layers.ParametricRectifierLayer(net['conv1_norm'], alpha=init.Constant(0.25))
    net['conv1_dropout'] = layers.DropoutLayer(net['conv1_active'], p=0.1)

    net['conv2'] = layers.Conv2DLayer(net['conv1_dropout'], num_filters=64, filter_size=(2, 5), stride=(1, 1), # 18
                                        W=init.HeNormal(), b=None, nonlinearity=None, pad='valid')
    net['conv2_norm'] = layers.BatchNormLayer(net['conv2'])
    net['conv2_active'] = layers.ParametricRectifierLayer(net['conv2_norm'], alpha=init.Constant(0.25))
    net['conv2_pool'] = layers.MaxPool2DLayer(net['conv2_active'], pool_size=(1, 10), stride=(1, 10)) # 25
    net['conv2_dropout'] = layers.DropoutLayer(net['conv2_pool'], p=0.1)

    net['conv3'] = layers.Conv2DLayer(net['conv2_dropout'], num_filters=128, filter_size=(1, 1), stride=(1, 1), # 18
                                        W=init.HeNormal(), b=None, nonlinearity=None, pad='valid')
    net['conv3_norm'] = layers.BatchNormLayer(net['conv3'])
    net['conv3_active'] = layers.ParametricRectifierLayer(net['conv3_norm'], alpha=init.Constant(0.25))
    net['conv3_dropout'] = layers.DropoutLayer(net['conv3_active'], p=0.1)

    net['dense1'] = layers.DenseLayer(net['conv3_dropout'], num_units=256, W=init.HeNormal(), 
                                     b=None, nonlinearity=None)
    net['dense1_norm'] = layers.BatchNormLayer(net['dense1'])
    net['dense1_active'] = layers.ParametricRectifierLayer(net['dense1_norm'], alpha=init.Constant(0.25))
    net['dense1_dropout'] = layers.DropoutLayer(net['dense1_active'], p=0.5)
    
    net['dense2'] = layers.DenseLayer(net['dense1_dropout'], num_units=num_labels, W=init.HeNormal(), 
                                     b=init.Constant(), nonlinearity=None)
    net['output'] = layers.NonlinearityLayer(net['dense2'], nonlinearity=nonlinearities.sigmoid)
    
    # optimization parameters
    optimization = {"objective": "binary",
                    "optimizer": "adam",
                    "learning_rate": 0.0003, 
                    "l2": 1e-6
                    }

    return net, input_var, target_var, optimization

# build network
shape = (None, train[0].shape[1], train[0].shape[2], train[0].shape[3])
num_labels = train[1].shape[1]
net, input_var, target_var, optimization = build_model(shape, num_labels)

# build neural network class
nnmodel = NeuralNet(net, input_var, target_var)
#nnmodel.inspect_layers()

# set output file paths
resultspath = utils.make_directory('../results', 'test')
output_name = 'original_model_bells_whistles'
filepath = os.path.join(resultspath, output_name)
savepath = utils.make_directory(resultspath, output_name)
nntrainer = NeuralTrainer(nnmodel, optimization, save='best', filepath=filepath)
# Out:
# making directory: ../results/test/original_model_bells_whistles
# compiling model

# %%
# train model
fit.train_minibatch(nntrainer, data={'train': train, 'valid': valid}, 
                              batch_size=100, num_epochs=500, patience=10, verbose=1)
# Out:
# Epoch 1 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.38633 -- accuracy=84.97%
#   valid loss:		0.36572
#   valid accuracy:	0.85575+/-0.00002
#   valid auc-roc:	0.91478+/-0.00000
#   valid auc-pr:		0.90758+/-0.00656
# saving model parameters to: ../results/test/original_model_bells_whistles_best.pickle
# Epoch 2 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.36715 -- accuracy=85.65%
#   valid loss:		0.35507
#   valid accuracy:	0.85976+/-0.00001
#   valid auc-roc:	0.91964+/-0.00000
#   valid auc-pr:		0.91364+/-0.00498
# saving model parameters to: ../results/test/original_model_bells_whistles_best.pickle
# Epoch 3 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.36066 -- accuracy=85.88%
#   valid loss:		0.34957
#   valid accuracy:	0.86153+/-0.00001
#   valid auc-roc:	0.92239+/-0.00000
#   valid auc-pr:		0.91721+/-0.00443
# saving model parameters to: ../results/test/original_model_bells_whistles_best.pickle
# Epoch 4 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35629 -- accuracy=86.08%
#   valid loss:		0.34416
#   valid accuracy:	0.86287+/-0.00000
#   valid auc-roc:	0.92445+/-0.00000
#   valid auc-pr:		0.91975+/-0.00418
# saving model parameters to: ../results/test/original_model_bells_whistles_best.pickle
# Epoch 5 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35308 -- accuracy=86.18%
#   valid loss:		0.34343
#   valid accuracy:	0.86378+/-0.00000
#   valid auc-roc:	0.92560+/-0.00000
#   valid auc-pr:		0.92126+/-0.00347
# saving model parameters to: ../results/test/original_model_bells_whistles_best.pickle
# Epoch 6 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35089 -- accuracy=86.27%
#   valid loss:		0.34320
#   valid accuracy:	0.86372+/-0.00000
#   valid auc-roc:	0.92629+/-0.00000
#   valid auc-pr:		0.92190+/-0.00350
# saving model parameters to: ../results/test/original_model_bells_whistles_best.pickle
# Epoch 7 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34841 -- accuracy=86.35%
#   valid loss:		0.34212
#   valid accuracy:	0.86478+/-0.00000
#   valid auc-roc:	0.92736+/-0.00000
#   valid auc-pr:		0.92316+/-0.00305
# saving model parameters to: ../results/test/original_model_bells_whistles_best.pickle
# Epoch 8 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34661 -- accuracy=86.43%
#   valid loss:		0.34293
#   valid accuracy:	0.86425+/-0.00000
#   valid auc-roc:	0.92798+/-0.00000
#   valid auc-pr:		0.92400+/-0.00287
# Epoch 9 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34512 -- accuracy=86.47%
#   valid loss:		0.33762
#   valid accuracy:	0.86550+/-0.00000
#   valid auc-roc:	0.92855+/-0.00000
#   valid auc-pr:		0.92462+/-0.00264
# saving model parameters to: ../results/test/original_model_bells_whistles_best.pickle
# Epoch 10 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34435 -- accuracy=86.51%
#   valid loss:		0.33706
#   valid accuracy:	0.86583+/-0.00000
#   valid auc-roc:	0.92853+/-0.00000
#   valid auc-pr:		0.92466+/-0.00252
# saving model parameters to: ../results/test/original_model_bells_whistles_best.pickle
# Epoch 11 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34310 -- accuracy=86.53%
#   valid loss:		0.33612
#   valid accuracy:	0.86586+/-0.00000
#   valid auc-roc:	0.92919+/-0.00000
#   valid auc-pr:		0.92550+/-0.00206
# saving model parameters to: ../results/test/original_model_bells_whistles_best.pickle
# Epoch 12 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34238 -- accuracy=86.55%
#   valid loss:		0.33661
#   valid accuracy:	0.86604+/-0.00000
#   valid auc-roc:	0.92916+/-0.00000
#   valid auc-pr:		0.92540+/-0.00212
# Epoch 13 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34169 -- accuracy=86.60%
#   valid loss:		0.33532
#   valid accuracy:	0.86629+/-0.00000
#   valid auc-roc:	0.92933+/-0.00000
#   valid auc-pr:		0.92575+/-0.00208
# saving model parameters to: ../results/test/original_model_bells_whistles_best.pickle
# Epoch 14 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34080 -- accuracy=86.64%
#   valid loss:		0.33608
#   valid accuracy:	0.86573+/-0.00000
#   valid auc-roc:	0.92968+/-0.00000
#   valid auc-pr:		0.92624+/-0.00197
# Epoch 15 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34013 -- accuracy=86.64%
#   valid loss:		0.33709
#   valid accuracy:	0.86652+/-0.00000
#   valid auc-roc:	0.92959+/-0.00000
#   valid auc-pr:		0.92599+/-0.00193
# Epoch 16 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33920 -- accuracy=86.71%
#   valid loss:		0.33790
#   valid accuracy:	0.86603+/-0.00000
#   valid auc-roc:	0.92997+/-0.00000
#   valid auc-pr:		0.92648+/-0.00179
# Epoch 17 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33874 -- accuracy=86.74%
#   valid loss:		0.33522
#   valid accuracy:	0.86657+/-0.00000
#   valid auc-roc:	0.92941+/-0.00000
#   valid auc-pr:		0.92584+/-0.00203
# saving model parameters to: ../results/test/original_model_bells_whistles_best.pickle
# Epoch 18 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33832 -- accuracy=86.73%
#   valid loss:		0.33565
#   valid accuracy:	0.86555+/-0.00000
#   valid auc-roc:	0.93041+/-0.00000
#   valid auc-pr:		0.92702+/-0.00164
# Epoch 19 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33754 -- accuracy=86.76%
#   valid loss:		0.33492
#   valid accuracy:	0.86661+/-0.00000
#   valid auc-roc:	0.92991+/-0.00000
#   valid auc-pr:		0.92636+/-0.00181
# saving model parameters to: ../results/test/original_model_bells_whistles_best.pickle
# Epoch 20 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33697 -- accuracy=86.79%
#   valid loss:		0.33414
#   valid accuracy:	0.86652+/-0.00000
#   valid auc-roc:	0.93030+/-0.00000
#   valid auc-pr:		0.92686+/-0.00171
# saving model parameters to: ../results/test/original_model_bells_whistles_best.pickle
# Epoch 21 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33623 -- accuracy=86.82%
#   valid loss:		0.33560
#   valid accuracy:	0.86641+/-0.00000
#   valid auc-roc:	0.93031+/-0.00000
#   valid auc-pr:		0.92682+/-0.00143
# Epoch 22 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33587 -- accuracy=86.82%
#   valid loss:		0.33428
#   valid accuracy:	0.86668+/-0.00000
#   valid auc-roc:	0.93033+/-0.00000
#   valid auc-pr:		0.92691+/-0.00155
# Epoch 23 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33499 -- accuracy=86.86%
#   valid loss:		0.33361
#   valid accuracy:	0.86661+/-0.00000
#   valid auc-roc:	0.93047+/-0.00000
#   valid auc-pr:		0.92707+/-0.00149
# saving model parameters to: ../results/test/original_model_bells_whistles_best.pickle
# Epoch 24 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33471 -- accuracy=86.88%
#   valid loss:		0.33408
#   valid accuracy:	0.86620+/-0.00000
#   valid auc-roc:	0.93023+/-0.00000
#   valid auc-pr:		0.92678+/-0.00128
# Epoch 25 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33436 -- accuracy=86.90%
#   valid loss:		0.33428
#   valid accuracy:	0.86605+/-0.00000
#   valid auc-roc:	0.93053+/-0.00000
#   valid auc-pr:		0.92722+/-0.00152
# Epoch 26 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33391 -- accuracy=86.93%
#   valid loss:		0.33364
#   valid accuracy:	0.86658+/-0.00000
#   valid auc-roc:	0.93016+/-0.00000
#   valid auc-pr:		0.92686+/-0.00159
# Epoch 27 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33322 -- accuracy=86.97%
#   valid loss:		0.33343
#   valid accuracy:	0.86680+/-0.00000
#   valid auc-roc:	0.93031+/-0.00000
#   valid auc-pr:		0.92697+/-0.00143
# saving model parameters to: ../results/test/original_model_bells_whistles_best.pickle
# Epoch 28 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33254 -- accuracy=86.96%
#   valid loss:		0.33386
#   valid accuracy:	0.86634+/-0.00000
#   valid auc-roc:	0.93019+/-0.00000
#   valid auc-pr:		0.92675+/-0.00143
# Epoch 29 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33217 -- accuracy=87.02%
#   valid loss:		0.33606
#   valid accuracy:	0.86618+/-0.00000
#   valid auc-roc:	0.92995+/-0.00000
#   valid auc-pr:		0.92665+/-0.00170
# Epoch 30 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33186 -- accuracy=87.01%
#   valid loss:		0.33328
#   valid accuracy:	0.86652+/-0.00000
#   valid auc-roc:	0.93061+/-0.00000
#   valid auc-pr:		0.92739+/-0.00127
# saving model parameters to: ../results/test/original_model_bells_whistles_best.pickle
# Epoch 31 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33151 -- accuracy=87.04%
#   valid loss:		0.33650
#   valid accuracy:	0.86574+/-0.00000
#   valid auc-roc:	0.93033+/-0.00000
#   valid auc-pr:		0.92696+/-0.00133
# Epoch 32 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33100 -- accuracy=87.07%
#   valid loss:		0.33437
#   valid accuracy:	0.86637+/-0.00000
#   valid auc-roc:	0.93041+/-0.00000
#   valid auc-pr:		0.92703+/-0.00140
# Epoch 33 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33022 -- accuracy=87.11%
#   valid loss:		0.33473
#   valid accuracy:	0.86632+/-0.00000
#   valid auc-roc:	0.93020+/-0.00000
#   valid auc-pr:		0.92685+/-0.00134
# Epoch 34 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33007 -- accuracy=87.10%
#   valid loss:		0.33773
#   valid accuracy:	0.86454+/-0.00000
#   valid auc-roc:	0.93010+/-0.00000
#   valid auc-pr:		0.92678+/-0.00124
# Epoch 35 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.32952 -- accuracy=87.11%
#   valid loss:		0.33524
#   valid accuracy:	0.86610+/-0.00000
#   valid auc-roc:	0.93035+/-0.00000
#   valid auc-pr:		0.92703+/-0.00134
# Epoch 36 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.32884 -- accuracy=87.17%
#   valid loss:		0.33647
#   valid accuracy:	0.86593+/-0.00000
#   valid auc-roc:	0.93001+/-0.00000
#   valid auc-pr:		0.92667+/-0.00138
# Epoch 37 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.32833 -- accuracy=87.20%
#   valid loss:		0.33531
#   valid accuracy:	0.86591+/-0.00000
#   valid auc-roc:	0.92992+/-0.00000
#   valid auc-pr:		0.92651+/-0.00136
# Epoch 38 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.32774 -- accuracy=87.21%
#   valid loss:		0.33698
#   valid accuracy:	0.86528+/-0.00000
#   valid auc-roc:	0.92981+/-0.00000
#   valid auc-pr:		0.92639+/-0.00137
# Epoch 39 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.32727 -- accuracy=87.24%
#   valid loss:		0.33443
#   valid accuracy:	0.86641+/-0.00000
#   valid auc-roc:	0.92993+/-0.00000
#   valid auc-pr:		0.92652+/-0.00138
# Epoch 40 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.32672 -- accuracy=87.26%
#   valid loss:		0.33699
#   valid accuracy:	0.86619+/-0.00000
#   valid auc-roc:	0.93002+/-0.00000
#   valid auc-pr:		0.92664+/-0.00144
# Epoch 41 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.32677 -- accuracy=87.28%
#   valid loss:		0.33632
#   valid accuracy:	0.86498+/-0.00000
#   valid auc-roc:	0.92969+/-0.00000
#   valid auc-pr:		0.92627+/-0.00124
# Patience ran out... Early stopping.
# <neuralnetwork.NeuralTrainer instance at 0x7f46bb98c2d8>

# %%
nntrainer.set_best_parameters()

# test model
nntrainer.test_model(valid, batch_size=100, name="test")
# Out:
#   test  loss:		0.33328
#   test  accuracy:	0.86652+/-0.00000
#   test  auc-roc:	0.93061+/-0.00000
#   test  auc-pr:		0.92739+/-0.00127
# 0.3332783075661091

# %% [markdown]
# # 1D architecture

# %%
def build_model(shape, num_labels):

    # get model
    input_var = T.tensor4('inputs')
    target_var = T.dmatrix('targets')

    net = {}
    net['input'] = layers.InputLayer(input_var=input_var, shape=shape)
    net['conv1'] = layers.Conv2DLayer(net['input'], num_filters=32, filter_size=(3, 6), stride=(1, 1),    # 330
                                        W=init.HeNormal(), b=None, nonlinearity=None, pad='valid')
    net['conv1_norm'] = layers.BatchNormLayer(net['conv1'])
    net['conv1_active'] = layers.ParametricRectifierLayer(net['conv1_norm'], alpha=init.Constant(0.25))
    net['conv1_pool'] = layers.MaxPool2DLayer(net['conv1_active'], pool_size=(1, 5), stride=(1, 5)) # 65
    net['conv1_dropout'] = layers.DropoutLayer(net['conv1_pool'], p=0.1)

    net['conv2'] = layers.Conv2DLayer(net['conv1_dropout'], num_filters=64, filter_size=(1, 6), stride=(1, 1), # 60
                                        W=init.HeNormal(), b=None, nonlinearity=None, pad='valid')
    net['conv2_norm'] = layers.BatchNormLayer(net['conv2'])
    net['conv2_active'] = layers.ParametricRectifierLayer(net['conv2_norm'], alpha=init.Constant(0.25))
    net['conv2_pool'] = layers.MaxPool2DLayer(net['conv2_active'], pool_size=(1, 5), stride=(1, 5)) # 12
    net['conv2_dropout'] = layers.DropoutLayer(net['conv2_pool'], p=0.1)

    net['conv3'] = layers.Conv2DLayer(net['conv2_dropout'], num_filters=128, filter_size=(1, 4), stride=(1, 1), # 8
                                        W=init.HeNormal(), b=None, nonlinearity=None, pad='valid')
    net['conv3_norm'] = layers.BatchNormLayer(net['conv3'])
    net['conv3_active'] = layers.ParametricRectifierLayer(net['conv3_norm'], alpha=init.Constant(0.25))
    net['conv3_pool'] = layers.MaxPool2DLayer(net['conv3_active'], pool_size=(1, 3), stride=(1, 3)) # 25
    net['conv3_dropout'] = layers.DropoutLayer(net['conv3_pool'], p=0.1)
    
    net['dense1'] = layers.DenseLayer(net['conv3_dropout'], num_units=256, W=init.HeNormal(), 
                                     b=init.Constant(0.1), nonlinearity=None)
    net['dense1_active'] = layers.ParametricRectifierLayer(net['dense1'], alpha=init.Constant(0.25))
    net['dense1_dropout'] = layers.DropoutLayer(net['dense1_active'], p=0.3)
    
    net['dense2'] = layers.DenseLayer(net['dense1_dropout'], num_units=num_labels, W=init.HeNormal(), 
                                     b=init.Constant(), nonlinearity=None)
    net['output'] = layers.NonlinearityLayer(net['dense2'], nonlinearity=nonlinearities.sigmoid)
    
    # optimization parameters
    optimization = {"objective": "binary",
                    "optimizer": "adam",
                    "learning_rate": 0.0003, 
                    "l2": 1e-6
                    }

    return net, input_var, target_var, optimization

# build network
shape = (None, train[0].shape[1], train[0].shape[2], train[0].shape[3])
num_labels = train[1].shape[1]
net, input_var, target_var, optimization = build_model(shape, num_labels)

# build neural network class
nnmodel = NeuralNet(net, input_var, target_var)
#nnmodel.inspect_layers()

# set output file paths
resultspath = utils.make_directory('../results', 'test')
output_name = '1d_version'
filepath = os.path.join(resultspath, output_name)
savepath = utils.make_directory(resultspath, output_name)
nntrainer = NeuralTrainer(nnmodel, optimization, save='best', filepath=filepath)
# Out:
# making directory: ../results/test/1d_version
# compiling model

# %%
# train model
fit.train_minibatch(nntrainer, data={'train': train, 'valid': valid}, 
                              batch_size=100, num_epochs=500, patience=10, verbose=1)
# Out:
# Epoch 1 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.40147 -- accuracy=84.37%
#   valid loss:		0.37892
#   valid accuracy:	0.85196+/-0.00007
#   valid auc-roc:	0.90785+/-0.00000
#   valid auc-pr:		0.89887+/-0.00923
# saving model parameters to: ../results/test/1d_version_best.pickle
# Epoch 2 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.37666 -- accuracy=85.37%
#   valid loss:		0.36710
#   valid accuracy:	0.85686+/-0.00005
#   valid auc-roc:	0.91342+/-0.00000
#   valid auc-pr:		0.90614+/-0.00795
# saving model parameters to: ../results/test/1d_version_best.pickle
# Epoch 3 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.36937 -- accuracy=85.60%
#   valid loss:		0.36464
#   valid accuracy:	0.85817+/-0.00000
#   valid auc-roc:	0.91527+/-0.00000
#   valid auc-pr:		0.90877+/-0.00711
# saving model parameters to: ../results/test/1d_version_best.pickle
# Epoch 4 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.36458 -- accuracy=85.75%
#   valid loss:		0.36341
#   valid accuracy:	0.85742+/-0.00001
#   valid auc-roc:	0.91765+/-0.00001
#   valid auc-pr:		0.91151+/-0.00628
# saving model parameters to: ../results/test/1d_version_best.pickle
# Epoch 5 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.36163 -- accuracy=85.83%
#   valid loss:		0.35687
#   valid accuracy:	0.85922+/-0.00000
#   valid auc-roc:	0.91838+/-0.00000
#   valid auc-pr:		0.91251+/-0.00589
# saving model parameters to: ../results/test/1d_version_best.pickle
# Epoch 6 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35893 -- accuracy=85.93%
#   valid loss:		0.35546
#   valid accuracy:	0.86006+/-0.00001
#   valid auc-roc:	0.91959+/-0.00000
#   valid auc-pr:		0.91405+/-0.00564
# saving model parameters to: ../results/test/1d_version_best.pickle
# Epoch 7 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35696 -- accuracy=85.99%
#   valid loss:		0.36301
#   valid accuracy:	0.85859+/-0.00002
#   valid auc-roc:	0.92057+/-0.00001
#   valid auc-pr:		0.91511+/-0.00527
# Epoch 8 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35520 -- accuracy=86.05%
#   valid loss:		0.35666
#   valid accuracy:	0.86029+/-0.00001
#   valid auc-roc:	0.92077+/-0.00000
#   valid auc-pr:		0.91538+/-0.00502
# Epoch 9 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35375 -- accuracy=86.09%
#   valid loss:		0.35390
#   valid accuracy:	0.86105+/-0.00001
#   valid auc-roc:	0.92170+/-0.00000
#   valid auc-pr:		0.91649+/-0.00463
# saving model parameters to: ../results/test/1d_version_best.pickle
# Epoch 10 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35252 -- accuracy=86.12%
#   valid loss:		0.35410
#   valid accuracy:	0.86008+/-0.00000
#   valid auc-roc:	0.92131+/-0.00000
#   valid auc-pr:		0.91604+/-0.00473
# Epoch 11 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35127 -- accuracy=86.18%
#   valid loss:		0.34887
#   valid accuracy:	0.86173+/-0.00000
#   valid auc-roc:	0.92220+/-0.00000
#   valid auc-pr:		0.91700+/-0.00447
# saving model parameters to: ../results/test/1d_version_best.pickle
# Epoch 12 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35028 -- accuracy=86.17%
#   valid loss:		0.34939
#   valid accuracy:	0.86149+/-0.00000
#   valid auc-roc:	0.92251+/-0.00000
#   valid auc-pr:		0.91746+/-0.00435
# Epoch 13 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34886 -- accuracy=86.22%
#   valid loss:		0.35036
#   valid accuracy:	0.86155+/-0.00000
#   valid auc-roc:	0.92242+/-0.00000
#   valid auc-pr:		0.91731+/-0.00425
# Epoch 14 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34825 -- accuracy=86.25%
#   valid loss:		0.34827
#   valid accuracy:	0.86216+/-0.00000
#   valid auc-roc:	0.92282+/-0.00000
#   valid auc-pr:		0.91789+/-0.00424
# saving model parameters to: ../results/test/1d_version_best.pickle
# Epoch 15 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34730 -- accuracy=86.28%
#   valid loss:		0.34839
#   valid accuracy:	0.86235+/-0.00000
#   valid auc-roc:	0.92283+/-0.00000
#   valid auc-pr:		0.91778+/-0.00418
# Epoch 16 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34648 -- accuracy=86.30%
#   valid loss:		0.34650
#   valid accuracy:	0.86253+/-0.00000
#   valid auc-roc:	0.92320+/-0.00000
#   valid auc-pr:		0.91835+/-0.00439
# saving model parameters to: ../results/test/1d_version_best.pickle
# Epoch 17 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34548 -- accuracy=86.34%
#   valid loss:		0.34578
#   valid accuracy:	0.86218+/-0.00000
#   valid auc-roc:	0.92361+/-0.00000
#   valid auc-pr:		0.91885+/-0.00424
# saving model parameters to: ../results/test/1d_version_best.pickle
# Epoch 18 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34462 -- accuracy=86.37%
#   valid loss:		0.34784
#   valid accuracy:	0.86278+/-0.00000
#   valid auc-roc:	0.92359+/-0.00000
#   valid auc-pr:		0.91880+/-0.00428
# Epoch 19 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34411 -- accuracy=86.38%
#   valid loss:		0.34801
#   valid accuracy:	0.86191+/-0.00000
#   valid auc-roc:	0.92397+/-0.00000
#   valid auc-pr:		0.91913+/-0.00401
# Epoch 20 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34322 -- accuracy=86.43%
#   valid loss:		0.34837
#   valid accuracy:	0.86271+/-0.00000
#   valid auc-roc:	0.92371+/-0.00000
#   valid auc-pr:		0.91899+/-0.00427
# Epoch 21 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34271 -- accuracy=86.45%
#   valid loss:		0.34527
#   valid accuracy:	0.86319+/-0.00000
#   valid auc-roc:	0.92421+/-0.00000
#   valid auc-pr:		0.91952+/-0.00424
# saving model parameters to: ../results/test/1d_version_best.pickle
# Epoch 22 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34198 -- accuracy=86.47%
#   valid loss:		0.34798
#   valid accuracy:	0.86244+/-0.00000
#   valid auc-roc:	0.92374+/-0.00000
#   valid auc-pr:		0.91898+/-0.00401
# Epoch 23 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34153 -- accuracy=86.48%
#   valid loss:		0.34979
#   valid accuracy:	0.86121+/-0.00000
#   valid auc-roc:	0.92348+/-0.00000
#   valid auc-pr:		0.91871+/-0.00378
# Epoch 24 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34119 -- accuracy=86.47%
#   valid loss:		0.34948
#   valid accuracy:	0.86161+/-0.00000
#   valid auc-roc:	0.92400+/-0.00000
#   valid auc-pr:		0.91928+/-0.00365
# Epoch 25 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34052 -- accuracy=86.54%
#   valid loss:		0.34645
#   valid accuracy:	0.86275+/-0.00000
#   valid auc-roc:	0.92393+/-0.00000
#   valid auc-pr:		0.91917+/-0.00401
# Epoch 26 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34024 -- accuracy=86.50%
#   valid loss:		0.34615
#   valid accuracy:	0.86285+/-0.00000
#   valid auc-roc:	0.92401+/-0.00000
#   valid auc-pr:		0.91924+/-0.00426
# Epoch 27 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34013 -- accuracy=86.50%
#   valid loss:		0.34465
#   valid accuracy:	0.86312+/-0.00000
#   valid auc-roc:	0.92459+/-0.00000
#   valid auc-pr:		0.91986+/-0.00385
# saving model parameters to: ../results/test/1d_version_best.pickle
# Epoch 28 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33935 -- accuracy=86.55%
#   valid loss:		0.34618
#   valid accuracy:	0.86261+/-0.00000
#   valid auc-roc:	0.92429+/-0.00000
#   valid auc-pr:		0.91959+/-0.00391
# Epoch 29 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33955 -- accuracy=86.54%
#   valid loss:		0.34418
#   valid accuracy:	0.86303+/-0.00000
#   valid auc-roc:	0.92433+/-0.00000
#   valid auc-pr:		0.91963+/-0.00392
# saving model parameters to: ../results/test/1d_version_best.pickle
# Epoch 30 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33875 -- accuracy=86.59%
#   valid loss:		0.34634
#   valid accuracy:	0.86216+/-0.00000
#   valid auc-roc:	0.92449+/-0.00000
#   valid auc-pr:		0.91992+/-0.00377
# Epoch 31 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33865 -- accuracy=86.58%
#   valid loss:		0.34710
#   valid accuracy:	0.86171+/-0.00000
#   valid auc-roc:	0.92434+/-0.00000
#   valid auc-pr:		0.91953+/-0.00367
# Epoch 32 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33814 -- accuracy=86.58%
#   valid loss:		0.34650
#   valid accuracy:	0.86290+/-0.00000
#   valid auc-roc:	0.92431+/-0.00000
#   valid auc-pr:		0.91957+/-0.00354
# Epoch 33 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33804 -- accuracy=86.61%
#   valid loss:		0.34389
#   valid accuracy:	0.86331+/-0.00000
#   valid auc-roc:	0.92477+/-0.00000
#   valid auc-pr:		0.92022+/-0.00369
# saving model parameters to: ../results/test/1d_version_best.pickle
# Epoch 34 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33762 -- accuracy=86.58%
#   valid loss:		0.34665
#   valid accuracy:	0.86238+/-0.00000
#   valid auc-roc:	0.92434+/-0.00000
#   valid auc-pr:		0.91967+/-0.00378
# Epoch 35 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33750 -- accuracy=86.61%
#   valid loss:		0.34470
#   valid accuracy:	0.86293+/-0.00000
#   valid auc-roc:	0.92448+/-0.00000
#   valid auc-pr:		0.91977+/-0.00365
# Epoch 36 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33709 -- accuracy=86.61%
#   valid loss:		0.34498
#   valid accuracy:	0.86288+/-0.00000
#   valid auc-roc:	0.92441+/-0.00000
#   valid auc-pr:		0.91973+/-0.00385
# Epoch 37 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33701 -- accuracy=86.61%
#   valid loss:		0.34600
#   valid accuracy:	0.86273+/-0.00000
#   valid auc-roc:	0.92416+/-0.00000
#   valid auc-pr:		0.91949+/-0.00402
# Epoch 38 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33676 -- accuracy=86.63%
#   valid loss:		0.34775
#   valid accuracy:	0.86229+/-0.00000
#   valid auc-roc:	0.92397+/-0.00000
#   valid auc-pr:		0.91921+/-0.00359
# Epoch 39 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33648 -- accuracy=86.63%
#   valid loss:		0.34771
#   valid accuracy:	0.86290+/-0.00000
#   valid auc-roc:	0.92430+/-0.00000
#   valid auc-pr:		0.91962+/-0.00390
# Epoch 40 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33610 -- accuracy=86.66%
#   valid loss:		0.34627
#   valid accuracy:	0.86248+/-0.00000
#   valid auc-roc:	0.92450+/-0.00000
#   valid auc-pr:		0.91978+/-0.00365
# Epoch 41 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33617 -- accuracy=86.66%
#   valid loss:		0.34673
#   valid accuracy:	0.86324+/-0.00000
#   valid auc-roc:	0.92417+/-0.00000
#   valid auc-pr:		0.91954+/-0.00372
# Epoch 42 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33578 -- accuracy=86.67%
#   valid loss:		0.34760
#   valid accuracy:	0.86280+/-0.00000
#   valid auc-roc:	0.92406+/-0.00000
#   valid auc-pr:		0.91939+/-0.00355
# Epoch 43 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33594 -- accuracy=86.66%
#   valid loss:		0.34660
#   valid accuracy:	0.86272+/-0.00000
#   valid auc-roc:	0.92434+/-0.00000
#   valid auc-pr:		0.91961+/-0.00355
# Epoch 44 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33551 -- accuracy=86.66%
#   valid loss:		0.34761
#   valid accuracy:	0.86231+/-0.00000
#   valid auc-roc:	0.92405+/-0.00000
#   valid auc-pr:		0.91915+/-0.00338
# Patience ran out... Early stopping.
# <neuralnetwork.NeuralTrainer instance at 0x7f4696804b48>

# %%
nntrainer.set_best_parameters()

# test model
nntrainer.test_model(valid, batch_size=100, name="test")
# Out:
#   test  loss:		0.34389
#   test  accuracy:	0.86331+/-0.00000
#   test  auc-roc:	0.92477+/-0.00000
#   test  auc-pr:		0.92022+/-0.00369
# 0.34388726719256413

# %% [markdown]
# # normal residual model

# %%
def build_model(shape, num_labels):
    def residual_block(net, last_layer, name, filter_size, nonlinearity=nonlinearities.rectify):
        # original residual unit
        shape = layers.get_output_shape(net[last_layer])
        num_filters = shape[1]

        net[name+'_1resid'] = layers.Conv2DLayer(net[last_layer], num_filters=num_filters, filter_size=filter_size, stride=(1, 1),    # 1000
                         W=init.HeNormal(), b=None, nonlinearity=None, pad='same')
        net[name+'_1resid_norm'] = layers.BatchNormLayer(net[name+'_1resid'])
        net[name+'_1resid_active'] = layers.NonlinearityLayer(net[name+'_1resid_norm'], nonlinearity=nonlinearity)

        net[name+'_1resid_dropout'] = layers.DropoutLayer(net[name+'_1resid_active'], p=0.1)

        # bottleneck residual layer
        net[name+'_2resid'] = layers.Conv2DLayer(net[name+'_1resid_dropout'], num_filters=num_filters, filter_size=filter_size, stride=(1, 1),    # 1000
                         W=init.HeNormal(), b=None, nonlinearity=None, pad='same')
        net[name+'_2resid_norm'] = layers.BatchNormLayer(net[name+'_2resid'])

        # combine input with residuals
        net[name+'_residual'] = layers.ElemwiseSumLayer([net[last_layer], net[name+'_2resid_norm']])
        net[name+'_resid'] = layers.NonlinearityLayer(net[name+'_residual'], nonlinearity=nonlinearity)

        return net

    # get model
    input_var = T.tensor4('inputs')
    target_var = T.dmatrix('targets')

    net = {}
    net['input'] = layers.InputLayer(input_var=input_var, shape=shape)
    net['conv1'] = layers.Conv2DLayer(net['input'], num_filters=18, filter_size=(2, 5), stride=(1, 1),    # 1000
                                        W=init.HeNormal(), b=None, nonlinearity=None, pad='valid')
    net['conv1_norm'] = layers.BatchNormLayer(net['conv1'])
    net['conv1_active'] = layers.NonlinearityLayer(net['conv1_norm'], nonlinearity=nonlinearities.rectify)
    net['conv1_dropout1'] = layers.DropoutLayer(net['conv1_active'], p=0.1)
    net = residual_block(net, 'conv1_dropout1', 'conv1_2', filter_size=(1,5), nonlinearity=nonlinearities.rectify)
    net['conv1_dropout'] = layers.DropoutLayer(net['conv1_2_resid'], p=0.1)

    net['conv2'] = layers.Conv2DLayer(net['conv1_dropout'], num_filters=40, filter_size=(2, 5), stride=(1, 1), # 18
                                        W=init.HeNormal(), b=None, nonlinearity=None, pad='valid')
    net['conv2_norm'] = layers.BatchNormLayer(net['conv2'])
    net['conv2_active'] = layers.NonlinearityLayer(net['conv2_norm'], nonlinearity=nonlinearities.rectify)
    net['conv2_dropout1'] = layers.DropoutLayer(net['conv2_active'], p=0.1)
    net = residual_block(net, 'conv2_dropout1', 'conv2_2', filter_size=(1,5), nonlinearity=nonlinearities.rectify)
    net['conv2_pool'] = layers.MaxPool2DLayer(net['conv2_2_resid'], pool_size=(1, 10), stride=(1, 10)) # 25
    net['conv2_dropout'] = layers.DropoutLayer(net['conv2_pool'], p=0.1)

    net['conv3'] = layers.Conv2DLayer(net['conv2_dropout'], num_filters=15, filter_size=(1, 1), stride=(1, 1), # 18
                                        W=init.HeNormal(), b=None, nonlinearity=None, pad='valid')
    net['conv3_norm'] = layers.BatchNormLayer(net['conv3'])
    net['conv3_active'] = layers.NonlinearityLayer(net['conv3_norm'], nonlinearity=nonlinearities.rectify)
    net['conv3_dropout'] = layers.DropoutLayer(net['conv3_active'], p=0.1)

    net['dense1'] = layers.DenseLayer(net['conv3_dropout'], num_units=100, W=init.HeNormal(), 
                                     b=init.Constant(), nonlinearity=None)
    net['dense1_active'] = layers.NonlinearityLayer(net['dense1'], nonlinearity=nonlinearities.rectify)
    net['dense1_dropout'] = layers.DropoutLayer(net['dense1_active'], p=0.3)
    
    net['dense2'] = layers.DenseLayer(net['dense1_dropout'], num_units=num_labels, W=init.HeNormal(), 
                                     b=init.Constant(), nonlinearity=None)
    net['output'] = layers.NonlinearityLayer(net['dense2'], nonlinearity=nonlinearities.sigmoid)
    
    # optimization parameters
    optimization = {"objective": "binary",
                    "optimizer": "adam",
                    "learning_rate": 0.0003, 
                    "l2": 1e-6
                    }

    return net, input_var, target_var, optimization

# build network
shape = (None, train[0].shape[1], train[0].shape[2], train[0].shape[3])
num_labels = train[1].shape[1]
net, input_var, target_var, optimization = build_model(shape, num_labels)

# build neural network class
nnmodel = NeuralNet(net, input_var, target_var)
#nnmodel.inspect_layers()

# set output file paths
resultspath = utils.make_directory('../results', 'test')
output_name = 'original_model_residual'
filepath = os.path.join(resultspath, output_name)
savepath = utils.make_directory(resultspath, output_name)
nntrainer = NeuralTrainer(nnmodel, optimization, save='best', filepath=filepath)
# Out:
# making directory: ../results/test/original_model_residual
# compiling model

# %%
# train model
fit.train_minibatch(nntrainer, data={'train': train, 'valid': valid}, 
                              batch_size=100, num_epochs=500, patience=10, verbose=1)
# Out:
# Epoch 1 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.38921 -- accuracy=84.79%
#   valid loss:		0.36033
#   valid accuracy:	0.85841+/-0.00002
#   valid auc-roc:	0.91725+/-0.00004
#   valid auc-pr:		0.91052+/-0.00657
# saving model parameters to: ../results/test/original_model_residual_best.pickle
# Epoch 2 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.36590 -- accuracy=85.73%
#   valid loss:		0.35725
#   valid accuracy:	0.85978+/-0.00001
#   valid auc-roc:	0.92117+/-0.00000
#   valid auc-pr:		0.91562+/-0.00532
# saving model parameters to: ../results/test/original_model_residual_best.pickle
# Epoch 3 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.36047 -- accuracy=85.94%
#   valid loss:		0.34987
#   valid accuracy:	0.86270+/-0.00001
#   valid auc-roc:	0.92364+/-0.00000
#   valid auc-pr:		0.91855+/-0.00502
# saving model parameters to: ../results/test/original_model_residual_best.pickle
# Epoch 4 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35699 -- accuracy=86.07%
#   valid loss:		0.34791
#   valid accuracy:	0.86287+/-0.00002
#   valid auc-roc:	0.92494+/-0.00000
#   valid auc-pr:		0.92012+/-0.00454
# saving model parameters to: ../results/test/original_model_residual_best.pickle
# Epoch 5 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35469 -- accuracy=86.10%
#   valid loss:		0.34542
#   valid accuracy:	0.86411+/-0.00001
#   valid auc-roc:	0.92543+/-0.00000
#   valid auc-pr:		0.92061+/-0.00455
# saving model parameters to: ../results/test/original_model_residual_best.pickle
# Epoch 6 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35230 -- accuracy=86.20%
#   valid loss:		0.34466
#   valid accuracy:	0.86446+/-0.00002
#   valid auc-roc:	0.92611+/-0.00001
#   valid auc-pr:		0.92156+/-0.00440
# saving model parameters to: ../results/test/original_model_residual_best.pickle
# Epoch 7 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35050 -- accuracy=86.26%
#   valid loss:		0.34444
#   valid accuracy:	0.86463+/-0.00001
#   valid auc-roc:	0.92732+/-0.00000
#   valid auc-pr:		0.92308+/-0.00356
# saving model parameters to: ../results/test/original_model_residual_best.pickle
# Epoch 8 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34959 -- accuracy=86.30%
#   valid loss:		0.33873
#   valid accuracy:	0.86501+/-0.00000
#   valid auc-roc:	0.92772+/-0.00000
#   valid auc-pr:		0.92365+/-0.00316
# saving model parameters to: ../results/test/original_model_residual_best.pickle
# Epoch 9 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34846 -- accuracy=86.32%
#   valid loss:		0.33935
#   valid accuracy:	0.86517+/-0.00000
#   valid auc-roc:	0.92796+/-0.00000
#   valid auc-pr:		0.92393+/-0.00335
# Epoch 10 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34758 -- accuracy=86.33%
#   valid loss:		0.33889
#   valid accuracy:	0.86392+/-0.00000
#   valid auc-roc:	0.92811+/-0.00000
#   valid auc-pr:		0.92412+/-0.00321
# Epoch 11 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34692 -- accuracy=86.36%
#   valid loss:		0.34026
#   valid accuracy:	0.86526+/-0.00000
#   valid auc-roc:	0.92837+/-0.00000
#   valid auc-pr:		0.92437+/-0.00329
# Epoch 12 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34609 -- accuracy=86.42%
#   valid loss:		0.33627
#   valid accuracy:	0.86560+/-0.00000
#   valid auc-roc:	0.92876+/-0.00000
#   valid auc-pr:		0.92472+/-0.00298
# saving model parameters to: ../results/test/original_model_residual_best.pickle
# Epoch 13 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34593 -- accuracy=86.38%
#   valid loss:		0.33644
#   valid accuracy:	0.86588+/-0.00000
#   valid auc-roc:	0.92858+/-0.00000
#   valid auc-pr:		0.92449+/-0.00307
# Epoch 14 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34490 -- accuracy=86.43%
#   valid loss:		0.33539
#   valid accuracy:	0.86619+/-0.00000
#   valid auc-roc:	0.92947+/-0.00000
#   valid auc-pr:		0.92571+/-0.00253
# saving model parameters to: ../results/test/original_model_residual_best.pickle
# Epoch 15 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34505 -- accuracy=86.43%
#   valid loss:		0.33533
#   valid accuracy:	0.86624+/-0.00000
#   valid auc-roc:	0.92941+/-0.00000
#   valid auc-pr:		0.92559+/-0.00264
# saving model parameters to: ../results/test/original_model_residual_best.pickle
# Epoch 16 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34420 -- accuracy=86.48%
#   valid loss:		0.33493
#   valid accuracy:	0.86628+/-0.00000
#   valid auc-roc:	0.92966+/-0.00000
#   valid auc-pr:		0.92596+/-0.00247
# saving model parameters to: ../results/test/original_model_residual_best.pickle
# Epoch 17 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34399 -- accuracy=86.46%
#   valid loss:		0.33550
#   valid accuracy:	0.86568+/-0.00000
#   valid auc-roc:	0.92959+/-0.00000
#   valid auc-pr:		0.92586+/-0.00250
# Epoch 18 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34369 -- accuracy=86.46%
#   valid loss:		0.33529
#   valid accuracy:	0.86621+/-0.00000
#   valid auc-roc:	0.92971+/-0.00000
#   valid auc-pr:		0.92604+/-0.00236
# Epoch 19 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34339 -- accuracy=86.49%
#   valid loss:		0.33705
#   valid accuracy:	0.86648+/-0.00000
#   valid auc-roc:	0.92947+/-0.00000
#   valid auc-pr:		0.92549+/-0.00287
# Epoch 20 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34281 -- accuracy=86.50%
#   valid loss:		0.33416
#   valid accuracy:	0.86622+/-0.00000
#   valid auc-roc:	0.93045+/-0.00000
#   valid auc-pr:		0.92684+/-0.00209
# saving model parameters to: ../results/test/original_model_residual_best.pickle
# Epoch 21 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34269 -- accuracy=86.51%
#   valid loss:		0.33506
#   valid accuracy:	0.86658+/-0.00000
#   valid auc-roc:	0.93036+/-0.00000
#   valid auc-pr:		0.92678+/-0.00220
# Epoch 22 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34209 -- accuracy=86.54%
#   valid loss:		0.33315
#   valid accuracy:	0.86673+/-0.00000
#   valid auc-roc:	0.93064+/-0.00000
#   valid auc-pr:		0.92706+/-0.00205
# saving model parameters to: ../results/test/original_model_residual_best.pickle
# Epoch 23 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34215 -- accuracy=86.51%
#   valid loss:		0.33656
#   valid accuracy:	0.86667+/-0.00000
#   valid auc-roc:	0.93038+/-0.00000
#   valid auc-pr:		0.92673+/-0.00231
# Epoch 24 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34178 -- accuracy=86.55%
#   valid loss:		0.33505
#   valid accuracy:	0.86540+/-0.00000
#   valid auc-roc:	0.93036+/-0.00000
#   valid auc-pr:		0.92685+/-0.00188
# Epoch 25 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34166 -- accuracy=86.56%
#   valid loss:		0.33537
#   valid accuracy:	0.86514+/-0.00000
#   valid auc-roc:	0.93084+/-0.00000
#   valid auc-pr:		0.92738+/-0.00198
# Epoch 26 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34133 -- accuracy=86.53%
#   valid loss:		0.33471
#   valid accuracy:	0.86715+/-0.00000
#   valid auc-roc:	0.93085+/-0.00000
#   valid auc-pr:		0.92738+/-0.00193
# Epoch 27 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34112 -- accuracy=86.56%
#   valid loss:		0.33187
#   valid accuracy:	0.86731+/-0.00000
#   valid auc-roc:	0.93116+/-0.00000
#   valid auc-pr:		0.92773+/-0.00182
# saving model parameters to: ../results/test/original_model_residual_best.pickle
# Epoch 28 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34085 -- accuracy=86.55%
#   valid loss:		0.33722
#   valid accuracy:	0.86622+/-0.00000
#   valid auc-roc:	0.93078+/-0.00000
#   valid auc-pr:		0.92725+/-0.00205
# Epoch 29 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34063 -- accuracy=86.57%
#   valid loss:		0.33326
#   valid accuracy:	0.86728+/-0.00000
#   valid auc-roc:	0.93112+/-0.00000
#   valid auc-pr:		0.92763+/-0.00190
# Epoch 30 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34062 -- accuracy=86.59%
#   valid loss:		0.33144
#   valid accuracy:	0.86693+/-0.00000
#   valid auc-roc:	0.93117+/-0.00000
#   valid auc-pr:		0.92767+/-0.00183
# saving model parameters to: ../results/test/original_model_residual_best.pickle
# Epoch 31 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33991 -- accuracy=86.56%
#   valid loss:		0.33096
#   valid accuracy:	0.86739+/-0.00000
#   valid auc-roc:	0.93141+/-0.00000
#   valid auc-pr:		0.92807+/-0.00168
# saving model parameters to: ../results/test/original_model_residual_best.pickle
# Epoch 32 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33998 -- accuracy=86.59%
#   valid loss:		0.33377
#   valid accuracy:	0.86680+/-0.00000
#   valid auc-roc:	0.93137+/-0.00000
#   valid auc-pr:		0.92799+/-0.00161
# Epoch 33 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34002 -- accuracy=86.58%
#   valid loss:		0.33077
#   valid accuracy:	0.86746+/-0.00000
#   valid auc-roc:	0.93167+/-0.00000
#   valid auc-pr:		0.92838+/-0.00149
# saving model parameters to: ../results/test/original_model_residual_best.pickle
# Epoch 34 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33983 -- accuracy=86.61%
#   valid loss:		0.33308
#   valid accuracy:	0.86656+/-0.00000
#   valid auc-roc:	0.93124+/-0.00000
#   valid auc-pr:		0.92774+/-0.00192
# Epoch 35 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33999 -- accuracy=86.58%
#   valid loss:		0.33150
#   valid accuracy:	0.86780+/-0.00000
#   valid auc-roc:	0.93165+/-0.00000
#   valid auc-pr:		0.92825+/-0.00167
# Epoch 36 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33954 -- accuracy=86.61%
#   valid loss:		0.33182
#   valid accuracy:	0.86707+/-0.00000
#   valid auc-roc:	0.93143+/-0.00000
#   valid auc-pr:		0.92809+/-0.00158
# Epoch 37 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33946 -- accuracy=86.61%
#   valid loss:		0.33173
#   valid accuracy:	0.86751+/-0.00000
#   valid auc-roc:	0.93153+/-0.00000
#   valid auc-pr:		0.92806+/-0.00162
# Epoch 38 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33918 -- accuracy=86.59%
#   valid loss:		0.33149
#   valid accuracy:	0.86727+/-0.00000
#   valid auc-roc:	0.93175+/-0.00000
#   valid auc-pr:		0.92841+/-0.00143
# Epoch 39 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33919 -- accuracy=86.62%
#   valid loss:		0.33156
#   valid accuracy:	0.86742+/-0.00000
#   valid auc-roc:	0.93175+/-0.00000
#   valid auc-pr:		0.92837+/-0.00145
# Epoch 40 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33897 -- accuracy=86.62%
#   valid loss:		0.33251
#   valid accuracy:	0.86674+/-0.00000
#   valid auc-roc:	0.93197+/-0.00000
#   valid auc-pr:		0.92868+/-0.00122
# Epoch 41 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33850 -- accuracy=86.63%
#   valid loss:		0.33050
#   valid accuracy:	0.86727+/-0.00000
#   valid auc-roc:	0.93174+/-0.00000
#   valid auc-pr:		0.92836+/-0.00144
# saving model parameters to: ../results/test/original_model_residual_best.pickle
# Epoch 42 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33865 -- accuracy=86.62%
#   valid loss:		0.33093
#   valid accuracy:	0.86790+/-0.00000
#   valid auc-roc:	0.93222+/-0.00000
#   valid auc-pr:		0.92892+/-0.00118
# Epoch 43 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33867 -- accuracy=86.65%
#   valid loss:		0.33085
#   valid accuracy:	0.86812+/-0.00000
#   valid auc-roc:	0.93193+/-0.00000
#   valid auc-pr:		0.92860+/-0.00138
# Epoch 44 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33838 -- accuracy=86.63%
#   valid loss:		0.32959
#   valid accuracy:	0.86750+/-0.00000
#   valid auc-roc:	0.93216+/-0.00000
#   valid auc-pr:		0.92891+/-0.00106
# saving model parameters to: ../results/test/original_model_residual_best.pickle
# Epoch 45 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.33838 -- accuracy=86.64%
#   valid loss:		0.32855
#   valid accuracy:	0.86812+/-0.00000
#   valid auc-roc:	0.93253+/-0.00000
#   valid auc-pr:		0.92942+/-0.00115
# saving model parameters to: ../results/test/original_model_residual_best.pickle
# Epoch 46 out of 500
# [================              ] 52.9% -- time=155s -- loss=0.33915 -- accuracy=86.65%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-48-7cc1a73aae23> in <module>()
#       1 # train model
#       2 fit.train_minibatch(nntrainer, data={'train': train, 'valid': valid},
# ----> 3                               batch_size=100, num_epochs=500, patience=10, verbose=1)
#
# /home/peter/Code/deepomics/train.pyc in train_minibatch(nntrainer, data, batch_size, num_epochs, patience, verbose, shuffle)
#      28
#      29                 # training set
# ---> 30                 train_loss = nntrainer.train_step(data['train'], batch_size, verbose, shuffle)
#      31                 nntrainer.add_loss(train_loss, 'train')
#      32
#
# /home/peter/Code/deepomics/neuralnetwork.pyc in train_step(self, train, batch_size, verbose, shuffle)
#     221                 for i in range(num_batches):
#     222                         X, y = next(batches)
# --> 223                         loss, prediction = self.train_fun(X, y)
#     224                         value += self.train_metric(prediction, y)
#     225                         performance.add_loss(loss)
#
# /home/peter/Theano/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     864         try:
#     865             outputs =\
# --> 866                 self.fn() if output_subset is None else\
#     867                 self.fn(output_subset=output_subset)
#     868         except Exception:
#
# /home/peter/Theano/theano/gof/op.pyc in rval(p, i, o, n)
#     863         if params is graph.NoParams:
#     864             # default arguments are stored in the closure of `rval`
# --> 865             def rval(p=p, i=node_input_storage, o=node_output_storage, n=node):
#     866                 r = p(n, [x[0] for x in i], o)
#     867                 for o in node.outputs:
#
# KeyboardInterrupt:

# %%
nntrainer.set_best_parameters()

# test model
nntrainer.test_model(valid, batch_size=100, name="test")

# %% [markdown]
# # residual model (modified)

# %%
def build_model(shape, num_labels):
    def residual_block(net, last_layer, name, filter_size, nonlinearity=nonlinearities.rectify):
        # original residual unit
        shape = layers.get_output_shape(net[last_layer])
        num_filters = shape[1]

        net[name+'_1resid'] = layers.Conv2DLayer(net[last_layer], num_filters=num_filters, filter_size=filter_size, stride=(1, 1),    # 1000
                         W=init.HeNormal(), b=None, nonlinearity=None, pad='same')
        net[name+'_1resid_norm'] = layers.BatchNormLayer(net[name+'_1resid'])
        net[name+'_1resid_active'] = layers.NonlinearityLayer(net[name+'_1resid_norm'], nonlinearity=nonlinearity)

        net[name+'_1resid_dropout'] = layers.DropoutLayer(net[name+'_1resid_active'], p=0.1)

        # bottleneck residual layer
        net[name+'_2resid'] = layers.Conv2DLayer(net[name+'_1resid_dropout'], num_filters=num_filters, filter_size=filter_size, stride=(1, 1),    # 1000
                         W=init.HeNormal(), b=None, nonlinearity=None, pad='same')
        net[name+'_2resid_norm'] = layers.BatchNormLayer(net[name+'_2resid'])

        # combine input with residuals
        net[name+'_residual'] = layers.ElemwiseSumLayer([net[last_layer], net[name+'_2resid_norm']])
        net[name+'_resid'] = layers.NonlinearityLayer(net[name+'_residual'], nonlinearity=nonlinearity)

        return net


    # get model
    input_var = T.tensor4('inputs')
    target_var = T.dmatrix('targets')

    net = {}
    net['input'] = layers.InputLayer(input_var=input_var, shape=shape)
    net['conv1'] = layers.Conv2DLayer(net['input'], num_filters=50, filter_size=(3, 11), stride=(1, 1),    # 330
                                        W=init.HeNormal(), b=None, nonlinearity=None, pad='valid')
    net['conv1_norm'] = layers.BatchNormLayer(net['conv1'])
    net['conv1_active'] = layers.NonlinearityLayer(net['conv1_norm'], nonlinearity=nonlinearities.rectify)
    net['conv1_dropout1'] = layers.DropoutLayer(net['conv1_active'], p=0.1)
    net = residual_block(net, 'conv1_dropout1', 'conv1_2', filter_size=(1,5), nonlinearity=nonlinearities.rectify)
    net['conv1_pool'] = layers.MaxPool2DLayer(net['conv1_2_resid'], pool_size=(1, 10), stride=(1, 10)) # 32
    net['conv1_dropout'] = layers.DropoutLayer(net['conv1_pool'], p=0.1)

    net['conv2'] = layers.Conv2DLayer(net['conv1_dropout'], num_filters=100, filter_size=(1, 6), stride=(1, 1), # 27
                                        W=init.HeNormal(), b=None, nonlinearity=None, pad='valid')
    net['conv2_norm'] = layers.BatchNormLayer(net['conv2'])
    net['conv2_active'] = layers.NonlinearityLayer(net['conv2_norm'], nonlinearity=nonlinearities.rectify)
    net['conv2_dropout1'] = layers.DropoutLayer(net['conv2_active'], p=0.1)
    net = residual_block(net, 'conv2_dropout1', 'conv2_2', filter_size=(1,5), nonlinearity=nonlinearities.rectify)
    net['conv2_pool'] = layers.MaxPool2DLayer(net['conv2_2_resid'], pool_size=(1, 9), stride=(1, 9)) # 25
    net['conv2_dropout'] = layers.DropoutLayer(net['conv2_pool'], p=0.1)

    net['dense1'] = layers.DenseLayer(net['conv2_dropout'], num_units=256, W=init.HeNormal(), 
                                     b=init.Constant(), nonlinearity=None)
    net['dense1_active'] = layers.NonlinearityLayer(net['dense1'], nonlinearity=nonlinearities.rectify)
    net['dense1_dropout'] = layers.DropoutLayer(net['dense1_active'], p=0.3)
    
    net['dense2'] = layers.DenseLayer(net['dense1_dropout'], num_units=num_labels, W=init.HeNormal(), 
                                     b=init.Constant(), nonlinearity=None)
    net['output'] = layers.NonlinearityLayer(net['dense2'], nonlinearity=nonlinearities.sigmoid)
    
    # optimization parameters
    optimization = {"objective": "binary",
                    "optimizer": "adam",
                    "learning_rate": 0.0003, 
                    "l2": 1e-5
                    }

    return net, input_var, target_var, optimization

# build network
shape = (None, train[0].shape[1], train[0].shape[2], train[0].shape[3])
num_labels = train[1].shape[1]
net, input_var, target_var, optimization = build_model(shape, num_labels)

# build neural network class
nnmodel = NeuralNet(net, input_var, target_var)
#nnmodel.inspect_layers()

# set output file paths
resultspath = utils.make_directory('../results', 'test')
output_name = '1D_model_resid'
filepath = os.path.join(resultspath, output_name)
savepath = utils.make_directory(resultspath, output_name)
nntrainer = NeuralTrainer(nnmodel, optimization, save='best', filepath=filepath)

# %%
# train model
fit.train_minibatch(nntrainer, data={'train': train, 'valid': valid}, 
                              batch_size=100, num_epochs=500, patience=10, verbose=1)

# %%
nntrainer.set_best_parameters()

# test model
nntrainer.test_model(valid, batch_size=100, name="test")
