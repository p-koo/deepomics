# %%
from __future__ import print_function 
import os, sys, h5py
import numpy as np
from six.moves import cPickle
from collections import OrderedDict

sys.path.append('/home/peter/Code/deepomics')
from neuralnetwork import NeuralNet, NeuralTrainer
import train as fit 
import visualize, utils

from lasagne import layers, nonlinearities, updates, objectives, init 
from lasagne.layers import get_output, get_output_shape, get_all_params
import theano.tensor as T
import theano
np.random.seed(247) # for reproducibility
# Out:
# Using gpu device 0: GeForce GTX 980 (CNMeM is disabled, cuDNN 5105)

# %%
filename = 'processed_dataset.hdf5'
group_name = ['processed_data']
dataset = h5py.File(filename,'r')
# %time dtf = np.array(dataset['/'+group_name[0]+'/dtf'])
ltf = np.array(dataset['/'+group_name[0]+'/ltf'])
dtf_crossval = np.array(dataset['/'+group_name[0]+'/dtf_crossval'])
ltf_crossval = np.array(dataset['/'+group_name[0]+'/ltf_crossval'])

train = (dtf.transpose([0,3,1,2]), ltf)
valid = (dtf_crossval.transpose([0,3,1,2]), ltf_crossval)
# Out:
# CPU times: user 288 ms, sys: 608 ms, total: 896 ms
# Wall time: 898 ms

# %%
def build_model(shape, num_labels):
    def residual_block(net, last_layer, name, filter_size, nonlinearity=nonlinearities.rectify):
        # original residual unit
        shape = layers.get_output_shape(net[last_layer])
        num_filters = shape[1]

        net[name+'_1resid'] = layers.Conv2DLayer(net[last_layer], num_filters=num_filters, filter_size=filter_size, stride=(1, 1),    # 1000
                         W=init.HeNormal(), b=None, nonlinearity=None, pad='same')
        net[name+'_1resid_norm'] = layers.BatchNormLayer(net[name+'_1resid'])
        net[name+'_1resid_active'] = layers.NonlinearityLayer(net[name+'_1resid_norm'], nonlinearity=nonlinearity)

        net[name+'_1resid_dropout'] = layers.DropoutLayer(net[name+'_1resid_active'], p=0.1)

        # bottleneck residual layer
        net[name+'_2resid'] = layers.Conv2DLayer(net[name+'_1resid_dropout'], num_filters=num_filters, filter_size=filter_size, stride=(1, 1),    # 1000
                         W=init.HeNormal(), b=None, nonlinearity=None, pad='same')
        net[name+'_2resid_norm'] = layers.BatchNormLayer(net[name+'_2resid'])

        # combine input with residuals
        net[name+'_residual'] = layers.ElemwiseSumLayer([net[last_layer], net[name+'_2resid_norm']])
        net[name+'_resid'] = layers.NonlinearityLayer(net[name+'_residual'], nonlinearity=nonlinearity)

        return net


    # get model
    input_var = T.tensor4('inputs')
    target_var = T.dmatrix('targets')

    net = {}
    net['input'] = layers.InputLayer(input_var=input_var, shape=shape)
    net['conv1'] = layers.Conv2DLayer(net['input'], num_filters=18, filter_size=(2, 5), stride=(1, 1),    # 1000
                                        W=init.HeNormal(), b=None, nonlinearity=None, pad='valid')
    net['conv1_norm'] = layers.BatchNormLayer(net['conv1'])
    net['conv1_active'] = layers.NonlinearityLayer(net['conv1_norm'], nonlinearity=nonlinearities.rectify)
    #net['conv1_dropout1'] = layers.DropoutLayer(net['conv1_active'], p=0.1)
    #net = residual_block(net, 'conv1_dropout1', 'conv1_2', filter_size=(5,1), nonlinearity=nonlinearities.rectify)
    #net['conv1_pool'] = layers.MaxPool2DLayer(net['conv1_2_resid'], pool_size=(40, 1), stride=(40, 1), ignore_border=False) # 25
    #net['conv1_dropout'] = layers.DropoutLayer(net['conv1_pool'], p=0.1)

    net['conv2'] = layers.Conv2DLayer(net['conv1_active'], num_filters=40, filter_size=(2, 5), stride=(1, 1), # 18
                                        W=init.HeNormal(), b=None, nonlinearity=None, pad='valid')
    net['conv2_norm'] = layers.BatchNormLayer(net['conv2'])
    net['conv2_active'] = layers.NonlinearityLayer(net['conv2_norm'], nonlinearity=nonlinearities.rectify)
    #net['conv2_dropout1'] = layers.DropoutLayer(net['conv2_active'], p=0.1)
    #net = residual_block(net, 'conv2_dropout1', 'conv2_2', filter_size=(5,1), nonlinearity=nonlinearities.rectify)
    net['conv2_pool'] = layers.MaxPool2DLayer(net['conv2_active'], pool_size=(1, 10), stride=(1, 10), ignore_border=False) # 25
    #net['conv2_dropout'] = layers.DropoutLayer(net['conv2_pool'], p=0.1)

    net['conv3'] = layers.Conv2DLayer(net['conv2_pool'], num_filters=15, filter_size=(1, 1), stride=(1, 1), # 18
                                        W=init.HeNormal(), b=None, nonlinearity=None, pad='valid')
    net['conv3_norm'] = layers.BatchNormLayer(net['conv3'])
    net['conv3_active'] = layers.NonlinearityLayer(net['conv3_norm'], nonlinearity=nonlinearities.rectify)
    #net['conv3_dropout1'] = layers.DropoutLayer(net['conv3_active'], p=0.1)
    #net = residual_block(net, 'conv3_dropout1', 'conv3_2', filter_size=(5,1), nonlinearity=nonlinearities.rectify)
    #net['conv3_pool'] = layers.MaxPool2DLayer(net['conv3_2_resid'], pool_size=(6, 1), stride=(6, 1), ignore_border=False) # 25
    #net['conv3_dropout'] = layers.DropoutLayer(net['conv3_pool'], p=0.1)

    net['dense1'] = layers.DenseLayer(net['conv3_active'], num_units=100, W=init.HeNormal(), 
                                     b=init.Constant(), nonlinearity=None)
    net['dense1_active'] = layers.NonlinearityLayer(net['dense1'], nonlinearity=nonlinearities.rectify)
    net['dense1_dropout'] = layers.DropoutLayer(net['dense1_active'], p=0.5)
    
    net['dense2'] = layers.DenseLayer(net['dense1_dropout'], num_units=num_labels, W=init.HeNormal(), 
                                     b=init.Constant(), nonlinearity=None)
    net['output'] = layers.NonlinearityLayer(net['dense2'], nonlinearity=nonlinearities.sigmoid)
    
    # optimization parameters
    optimization = {"objective": "binary",
                    "optimizer": "adam",
                    "learning_rate": 0.001, 
                    "l2": 1e-5
                    }

    return net, input_var, target_var, optimization

# build network
shape = (None, train[0].shape[1], train[0].shape[2], train[0].shape[3])
num_labels = train[1].shape[1]
net, input_var, target_var, optimization = build_model(shape, num_labels)

# build neural network class
nnmodel = NeuralNet(net, input_var, target_var)
#nnmodel.inspect_layers()

# set output file paths
resultspath = utils.make_directory('../results', 'test')
output_name = 'tim_model'
filepath = os.path.join(resultspath, output_name)
savepath = utils.make_directory(resultspath, output_name)
nntrainer = NeuralTrainer(nnmodel, optimization, save='best', filepath=filepath)
# Out:
# compiling model

# %%
nnmodel.inspect_layers()
# Out:
# ----------------------------------------------------------------------------
# Network architecture:
# ----------------------------------------------------------------------------
# layer1:
# <lasagne.layers.input.InputLayer object at 0x7f2be49d7c50>
# shape:(None, 1, 3, 330)
# layer2:
# <lasagne.layers.conv.Conv2DLayer object at 0x7f2be49d7cd0>
# shape:(None, 18, 2, 326)
# parameters: W
# layer3:
# <lasagne.layers.normalization.BatchNormLayer object at 0x7f2be49d7c90>
# shape:(None, 18, 2, 326)
# parameters: beta, gamma, mean, inv_std
# layer4:
# <lasagne.layers.special.NonlinearityLayer object at 0x7f2be49dd410>
# shape:(None, 18, 2, 326)
# layer5:
# <lasagne.layers.conv.Conv2DLayer object at 0x7f2be49dd610>
# shape:(None, 40, 1, 322)
# parameters: W
# layer6:
# <lasagne.layers.normalization.BatchNormLayer object at 0x7f2be49dd5d0>
# shape:(None, 40, 1, 322)
# parameters: beta, gamma, mean, inv_std
# layer7:
# <lasagne.layers.special.NonlinearityLayer object at 0x7f2be28114d0>
# shape:(None, 40, 1, 322)
# layer8:
# <lasagne.layers.pool.MaxPool2DLayer object at 0x7f2be2265410>
# shape:(None, 40, 1, 33)
# layer9:
# <lasagne.layers.conv.Conv2DLayer object at 0x7f2be226d190>
# shape:(None, 15, 1, 33)
# parameters: W
# layer10:
# <lasagne.layers.normalization.BatchNormLayer object at 0x7f2be2265c90>
# shape:(None, 15, 1, 33)
# parameters: beta, gamma, mean, inv_std
# layer11:
# <lasagne.layers.special.NonlinearityLayer object at 0x7f2be2229210>
# shape:(None, 15, 1, 33)
# layer12:
# <lasagne.layers.dense.DenseLayer object at 0x7f2be223f2d0>
# shape:(None, 100)
# parameters: W, b
# layer13:
# <lasagne.layers.special.NonlinearityLayer object at 0x7f2be2238890>
# shape:(None, 100)
# layer14:
# <lasagne.layers.noise.DropoutLayer object at 0x7f2be2238e10>
# shape:(None, 100)
# layer15:
# <lasagne.layers.dense.DenseLayer object at 0x7f2be21fce50>
# shape:(None, 2)
# parameters: W, b
# layer16:
# <lasagne.layers.special.NonlinearityLayer object at 0x7f2be21fc750>
# shape:(None, 2)
# ----------------------------------------------------------------------------

# %%
# train model
fit.train_minibatch(nntrainer, data={'train': train, 'valid': valid}, 
                              batch_size=100, num_epochs=500, patience=10, verbose=1)
# Out:
# Epoch 1 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.37773 -- accuracy=85.48%
#   valid loss:		0.36053
#   valid accuracy:	0.85899+/-0.00002
#   valid auc-roc:	0.91821+/-0.00000
#   valid auc-pr:		0.91224+/-0.00533
# saving model parameters to: ../results/test/tim_model_best.pickle
# Epoch 2 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.36293 -- accuracy=86.05%
#   valid loss:		0.35790
#   valid accuracy:	0.86073+/-0.00000
#   valid auc-roc:	0.92275+/-0.00000
#   valid auc-pr:		0.91733+/-0.00414
# saving model parameters to: ../results/test/tim_model_best.pickle
# Epoch 3 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35903 -- accuracy=86.17%
#   valid loss:		0.34607
#   valid accuracy:	0.86241+/-0.00000
#   valid auc-roc:	0.92362+/-0.00000
#   valid auc-pr:		0.91867+/-0.00377
# saving model parameters to: ../results/test/tim_model_best.pickle
# Epoch 4 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35735 -- accuracy=86.23%
#   valid loss:		0.35154
#   valid accuracy:	0.86039+/-0.00000
#   valid auc-roc:	0.92405+/-0.00000
#   valid auc-pr:		0.91925+/-0.00332
# Epoch 5 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35577 -- accuracy=86.30%
#   valid loss:		0.35221
#   valid accuracy:	0.86242+/-0.00000
#   valid auc-roc:	0.92471+/-0.00000
#   valid auc-pr:		0.91997+/-0.00295
# Epoch 6 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35492 -- accuracy=86.32%
#   valid loss:		0.35221
#   valid accuracy:	0.86128+/-0.00000
#   valid auc-roc:	0.92520+/-0.00000
#   valid auc-pr:		0.92051+/-0.00329
# Epoch 7 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35384 -- accuracy=86.35%
#   valid loss:		0.34243
#   valid accuracy:	0.86402+/-0.00000
#   valid auc-roc:	0.92607+/-0.00000
#   valid auc-pr:		0.92157+/-0.00320
# saving model parameters to: ../results/test/tim_model_best.pickle
# Epoch 8 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35374 -- accuracy=86.37%
#   valid loss:		0.34314
#   valid accuracy:	0.86358+/-0.00000
#   valid auc-roc:	0.92573+/-0.00000
#   valid auc-pr:		0.92107+/-0.00280
# Epoch 9 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35261 -- accuracy=86.39%
#   valid loss:		0.34277
#   valid accuracy:	0.86392+/-0.00000
#   valid auc-roc:	0.92549+/-0.00000
#   valid auc-pr:		0.92088+/-0.00256
# Epoch 10 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35192 -- accuracy=86.43%
#   valid loss:		0.34473
#   valid accuracy:	0.86369+/-0.00000
#   valid auc-roc:	0.92599+/-0.00000
#   valid auc-pr:		0.92167+/-0.00293
# Epoch 11 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35174 -- accuracy=86.42%
#   valid loss:		0.34571
#   valid accuracy:	0.86363+/-0.00000
#   valid auc-roc:	0.92628+/-0.00000
#   valid auc-pr:		0.92191+/-0.00265
# Epoch 12 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35157 -- accuracy=86.44%
#   valid loss:		0.34108
#   valid accuracy:	0.86425+/-0.00000
#   valid auc-roc:	0.92656+/-0.00000
#   valid auc-pr:		0.92222+/-0.00289
# saving model parameters to: ../results/test/tim_model_best.pickle
# Epoch 13 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35103 -- accuracy=86.43%
#   valid loss:		0.34445
#   valid accuracy:	0.86338+/-0.00000
#   valid auc-roc:	0.92603+/-0.00000
#   valid auc-pr:		0.92184+/-0.00306
# Epoch 14 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35069 -- accuracy=86.45%
#   valid loss:		0.34100
#   valid accuracy:	0.86433+/-0.00000
#   valid auc-roc:	0.92632+/-0.00000
#   valid auc-pr:		0.92203+/-0.00297
# saving model parameters to: ../results/test/tim_model_best.pickle
# Epoch 15 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35039 -- accuracy=86.46%
#   valid loss:		0.34153
#   valid accuracy:	0.86405+/-0.00000
#   valid auc-roc:	0.92621+/-0.00000
#   valid auc-pr:		0.92178+/-0.00236
# Epoch 16 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35042 -- accuracy=86.49%
#   valid loss:		0.34363
#   valid accuracy:	0.86438+/-0.00000
#   valid auc-roc:	0.92638+/-0.00000
#   valid auc-pr:		0.92190+/-0.00313
# Epoch 17 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35007 -- accuracy=86.50%
#   valid loss:		0.34014
#   valid accuracy:	0.86426+/-0.00000
#   valid auc-roc:	0.92705+/-0.00000
#   valid auc-pr:		0.92294+/-0.00299
# saving model parameters to: ../results/test/tim_model_best.pickle
# Epoch 18 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34961 -- accuracy=86.50%
#   valid loss:		0.34514
#   valid accuracy:	0.86404+/-0.00000
#   valid auc-roc:	0.92701+/-0.00000
#   valid auc-pr:		0.92266+/-0.00282
# Epoch 19 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34960 -- accuracy=86.52%
#   valid loss:		0.33971
#   valid accuracy:	0.86404+/-0.00000
#   valid auc-roc:	0.92711+/-0.00000
#   valid auc-pr:		0.92300+/-0.00267
# saving model parameters to: ../results/test/tim_model_best.pickle
# Epoch 20 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34926 -- accuracy=86.50%
#   valid loss:		0.34028
#   valid accuracy:	0.86440+/-0.00000
#   valid auc-roc:	0.92743+/-0.00000
#   valid auc-pr:		0.92329+/-0.00277
# Epoch 21 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34907 -- accuracy=86.49%
#   valid loss:		0.33942
#   valid accuracy:	0.86472+/-0.00000
#   valid auc-roc:	0.92739+/-0.00000
#   valid auc-pr:		0.92318+/-0.00228
# saving model parameters to: ../results/test/tim_model_best.pickle
# Epoch 22 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34909 -- accuracy=86.51%
#   valid loss:		0.33884
#   valid accuracy:	0.86479+/-0.00000
#   valid auc-roc:	0.92780+/-0.00000
#   valid auc-pr:		0.92363+/-0.00243
# saving model parameters to: ../results/test/tim_model_best.pickle
# Epoch 23 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34850 -- accuracy=86.54%
#   valid loss:		0.33879
#   valid accuracy:	0.86477+/-0.00000
#   valid auc-roc:	0.92771+/-0.00000
#   valid auc-pr:		0.92354+/-0.00255
# saving model parameters to: ../results/test/tim_model_best.pickle
# Epoch 24 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34827 -- accuracy=86.56%
#   valid loss:		0.33711
#   valid accuracy:	0.86554+/-0.00000
#   valid auc-roc:	0.92818+/-0.00000
#   valid auc-pr:		0.92417+/-0.00242
# saving model parameters to: ../results/test/tim_model_best.pickle
# Epoch 25 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34768 -- accuracy=86.56%
#   valid loss:		0.33696
#   valid accuracy:	0.86512+/-0.00000
#   valid auc-roc:	0.92831+/-0.00000
#   valid auc-pr:		0.92439+/-0.00262
# saving model parameters to: ../results/test/tim_model_best.pickle
# Epoch 26 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34759 -- accuracy=86.56%
#   valid loss:		0.34068
#   valid accuracy:	0.86490+/-0.00000
#   valid auc-roc:	0.92712+/-0.00000
#   valid auc-pr:		0.92306+/-0.00259
# Epoch 27 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34739 -- accuracy=86.57%
#   valid loss:		0.33787
#   valid accuracy:	0.86484+/-0.00000
#   valid auc-roc:	0.92794+/-0.00000
#   valid auc-pr:		0.92403+/-0.00261
# Epoch 28 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34718 -- accuracy=86.57%
#   valid loss:		0.33712
#   valid accuracy:	0.86568+/-0.00000
#   valid auc-roc:	0.92829+/-0.00000
#   valid auc-pr:		0.92433+/-0.00223
# Epoch 29 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34698 -- accuracy=86.57%
#   valid loss:		0.33782
#   valid accuracy:	0.86512+/-0.00000
#   valid auc-roc:	0.92815+/-0.00000
#   valid auc-pr:		0.92430+/-0.00223
# Epoch 30 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34704 -- accuracy=86.55%
#   valid loss:		0.33645
#   valid accuracy:	0.86548+/-0.00000
#   valid auc-roc:	0.92848+/-0.00000
#   valid auc-pr:		0.92464+/-0.00215
# saving model parameters to: ../results/test/tim_model_best.pickle
# Epoch 31 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34695 -- accuracy=86.62%
#   valid loss:		0.33691
#   valid accuracy:	0.86557+/-0.00000
#   valid auc-roc:	0.92841+/-0.00000
#   valid auc-pr:		0.92449+/-0.00223
# Epoch 32 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34665 -- accuracy=86.61%
#   valid loss:		0.33893
#   valid accuracy:	0.86516+/-0.00000
#   valid auc-roc:	0.92819+/-0.00000
#   valid auc-pr:		0.92415+/-0.00257
# Epoch 33 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34682 -- accuracy=86.60%
#   valid loss:		0.33844
#   valid accuracy:	0.86509+/-0.00000
#   valid auc-roc:	0.92796+/-0.00000
#   valid auc-pr:		0.92389+/-0.00253
# Epoch 34 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34708 -- accuracy=86.58%
#   valid loss:		0.33602
#   valid accuracy:	0.86563+/-0.00000
#   valid auc-roc:	0.92881+/-0.00000
#   valid auc-pr:		0.92500+/-0.00210
# saving model parameters to: ../results/test/tim_model_best.pickle
# Epoch 35 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34658 -- accuracy=86.59%
#   valid loss:		0.33937
#   valid accuracy:	0.86485+/-0.00000
#   valid auc-roc:	0.92839+/-0.00000
#   valid auc-pr:		0.92440+/-0.00259
# Epoch 36 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34647 -- accuracy=86.60%
#   valid loss:		0.33839
#   valid accuracy:	0.86467+/-0.00000
#   valid auc-roc:	0.92777+/-0.00000
#   valid auc-pr:		0.92384+/-0.00267
# Epoch 37 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34629 -- accuracy=86.60%
#   valid loss:		0.33775
#   valid accuracy:	0.86542+/-0.00000
#   valid auc-roc:	0.92882+/-0.00000
#   valid auc-pr:		0.92509+/-0.00190
# Epoch 38 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34607 -- accuracy=86.62%
#   valid loss:		0.33976
#   valid accuracy:	0.86417+/-0.00000
#   valid auc-roc:	0.92846+/-0.00000
#   valid auc-pr:		0.92461+/-0.00235
# Epoch 39 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34643 -- accuracy=86.62%
#   valid loss:		0.33609
#   valid accuracy:	0.86588+/-0.00000
#   valid auc-roc:	0.92860+/-0.00000
#   valid auc-pr:		0.92477+/-0.00192
# Epoch 40 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34613 -- accuracy=86.63%
#   valid loss:		0.34563
#   valid accuracy:	0.86339+/-0.00000
#   valid auc-roc:	0.92796+/-0.00000
#   valid auc-pr:		0.92425+/-0.00213
# Epoch 41 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34595 -- accuracy=86.61%
#   valid loss:		0.33641
#   valid accuracy:	0.86608+/-0.00000
#   valid auc-roc:	0.92863+/-0.00000
#   valid auc-pr:		0.92482+/-0.00192
# Epoch 42 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34586 -- accuracy=86.63%
#   valid loss:		0.34337
#   valid accuracy:	0.86438+/-0.00000
#   valid auc-roc:	0.92842+/-0.00000
#   valid auc-pr:		0.92449+/-0.00228
# Epoch 43 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34620 -- accuracy=86.63%
#   valid loss:		0.33594
#   valid accuracy:	0.86577+/-0.00000
#   valid auc-roc:	0.92874+/-0.00000
#   valid auc-pr:		0.92493+/-0.00213
# saving model parameters to: ../results/test/tim_model_best.pickle
# Epoch 44 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34577 -- accuracy=86.64%
#   valid loss:		0.33755
#   valid accuracy:	0.86530+/-0.00000
#   valid auc-roc:	0.92825+/-0.00000
#   valid auc-pr:		0.92416+/-0.00236
# Epoch 45 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34572 -- accuracy=86.65%
#   valid loss:		0.33662
#   valid accuracy:	0.86552+/-0.00000
#   valid auc-roc:	0.92886+/-0.00000
#   valid auc-pr:		0.92515+/-0.00191
# Epoch 46 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34585 -- accuracy=86.61%
#   valid loss:		0.33868
#   valid accuracy:	0.86536+/-0.00000
#   valid auc-roc:	0.92846+/-0.00000
#   valid auc-pr:		0.92457+/-0.00225
# Epoch 47 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34570 -- accuracy=86.62%
#   valid loss:		0.33995
#   valid accuracy:	0.86555+/-0.00000
#   valid auc-roc:	0.92862+/-0.00000
#   valid auc-pr:		0.92486+/-0.00188
# Epoch 48 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34586 -- accuracy=86.64%
#   valid loss:		0.33675
#   valid accuracy:	0.86539+/-0.00000
#   valid auc-roc:	0.92863+/-0.00000
#   valid auc-pr:		0.92489+/-0.00200
# Epoch 49 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34565 -- accuracy=86.61%
#   valid loss:		0.33717
#   valid accuracy:	0.86524+/-0.00000
#   valid auc-roc:	0.92890+/-0.00000
#   valid auc-pr:		0.92511+/-0.00194
# Epoch 50 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34550 -- accuracy=86.64%
#   valid loss:		0.33809
#   valid accuracy:	0.86523+/-0.00000
#   valid auc-roc:	0.92843+/-0.00000
#   valid auc-pr:		0.92462+/-0.00199
# Epoch 51 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34567 -- accuracy=86.64%
#   valid loss:		0.34398
#   valid accuracy:	0.86509+/-0.00000
#   valid auc-roc:	0.92880+/-0.00000
#   valid auc-pr:		0.92471+/-0.00196
# Epoch 52 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34510 -- accuracy=86.63%
#   valid loss:		0.33524
#   valid accuracy:	0.86541+/-0.00000
#   valid auc-roc:	0.92924+/-0.00000
#   valid auc-pr:		0.92559+/-0.00183
# saving model parameters to: ../results/test/tim_model_best.pickle
# Epoch 53 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34549 -- accuracy=86.64%
#   valid loss:		0.33601
#   valid accuracy:	0.86539+/-0.00000
#   valid auc-roc:	0.92887+/-0.00000
#   valid auc-pr:		0.92510+/-0.00195
# Epoch 54 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34503 -- accuracy=86.66%
#   valid loss:		0.33857
#   valid accuracy:	0.86430+/-0.00000
#   valid auc-roc:	0.92896+/-0.00000
#   valid auc-pr:		0.92515+/-0.00176
# Epoch 55 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34514 -- accuracy=86.66%
#   valid loss:		0.33918
#   valid accuracy:	0.86504+/-0.00000
#   valid auc-roc:	0.92905+/-0.00000
#   valid auc-pr:		0.92536+/-0.00180
# Epoch 56 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34530 -- accuracy=86.64%
#   valid loss:		0.33922
#   valid accuracy:	0.86422+/-0.00000
#   valid auc-roc:	0.92911+/-0.00000
#   valid auc-pr:		0.92552+/-0.00164
# Epoch 57 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34502 -- accuracy=86.65%
#   valid loss:		0.33606
#   valid accuracy:	0.86595+/-0.00000
#   valid auc-roc:	0.92923+/-0.00000
#   valid auc-pr:		0.92547+/-0.00179
# Epoch 58 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34533 -- accuracy=86.65%
#   valid loss:		0.33738
#   valid accuracy:	0.86558+/-0.00000
#   valid auc-roc:	0.92908+/-0.00000
#   valid auc-pr:		0.92532+/-0.00179
# Epoch 59 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34496 -- accuracy=86.65%
#   valid loss:		0.34231
#   valid accuracy:	0.86327+/-0.00000
#   valid auc-roc:	0.92883+/-0.00000
#   valid auc-pr:		0.92505+/-0.00132
# Epoch 60 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34494 -- accuracy=86.66%
#   valid loss:		0.34450
#   valid accuracy:	0.86475+/-0.00000
#   valid auc-roc:	0.92913+/-0.00000
#   valid auc-pr:		0.92547+/-0.00151
# Epoch 61 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34501 -- accuracy=86.66%
#   valid loss:		0.33805
#   valid accuracy:	0.86571+/-0.00000
#   valid auc-roc:	0.92883+/-0.00000
#   valid auc-pr:		0.92519+/-0.00182
# Epoch 62 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34511 -- accuracy=86.67%
#   valid loss:		0.34369
#   valid accuracy:	0.86407+/-0.00000
#   valid auc-roc:	0.92938+/-0.00000
#   valid auc-pr:		0.92559+/-0.00164
# Epoch 63 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34498 -- accuracy=86.66%
#   valid loss:		0.33467
#   valid accuracy:	0.86537+/-0.00000
#   valid auc-roc:	0.92972+/-0.00000
#   valid auc-pr:		0.92586+/-0.00174
# saving model parameters to: ../results/test/tim_model_best.pickle
# Epoch 64 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34465 -- accuracy=86.66%
#   valid loss:		0.33868
#   valid accuracy:	0.86538+/-0.00000
#   valid auc-roc:	0.92885+/-0.00000
#   valid auc-pr:		0.92512+/-0.00203
# Epoch 65 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34482 -- accuracy=86.66%
#   valid loss:		0.34130
#   valid accuracy:	0.86450+/-0.00000
#   valid auc-roc:	0.92842+/-0.00000
#   valid auc-pr:		0.92466+/-0.00207
# Epoch 66 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34474 -- accuracy=86.69%
#   valid loss:		0.33980
#   valid accuracy:	0.86477+/-0.00000
#   valid auc-roc:	0.92943+/-0.00000
#   valid auc-pr:		0.92581+/-0.00173
# Epoch 67 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34462 -- accuracy=86.66%
#   valid loss:		0.33416
#   valid accuracy:	0.86634+/-0.00000
#   valid auc-roc:	0.92954+/-0.00000
#   valid auc-pr:		0.92582+/-0.00138
# saving model parameters to: ../results/test/tim_model_best.pickle
# Epoch 68 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34491 -- accuracy=86.67%
#   valid loss:		0.33777
#   valid accuracy:	0.86452+/-0.00000
#   valid auc-roc:	0.92880+/-0.00000
#   valid auc-pr:		0.92497+/-0.00160
# Epoch 69 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34457 -- accuracy=86.68%
#   valid loss:		0.33579
#   valid accuracy:	0.86592+/-0.00000
#   valid auc-roc:	0.92905+/-0.00000
#   valid auc-pr:		0.92529+/-0.00179
# Epoch 70 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34454 -- accuracy=86.69%
#   valid loss:		0.33665
#   valid accuracy:	0.86573+/-0.00000
#   valid auc-roc:	0.92923+/-0.00000
#   valid auc-pr:		0.92548+/-0.00175
# Epoch 71 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34449 -- accuracy=86.69%
#   valid loss:		0.33782
#   valid accuracy:	0.86634+/-0.00000
#   valid auc-roc:	0.92927+/-0.00000
#   valid auc-pr:		0.92542+/-0.00187
# Epoch 72 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34452 -- accuracy=86.70%
#   valid loss:		0.33672
#   valid accuracy:	0.86496+/-0.00000
#   valid auc-roc:	0.92893+/-0.00000
#   valid auc-pr:		0.92525+/-0.00193
# Epoch 73 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34463 -- accuracy=86.68%
#   valid loss:		0.34392
#   valid accuracy:	0.86326+/-0.00000
#   valid auc-roc:	0.92877+/-0.00000
#   valid auc-pr:		0.92509+/-0.00183
# Epoch 74 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34458 -- accuracy=86.70%
#   valid loss:		0.33546
#   valid accuracy:	0.86566+/-0.00000
#   valid auc-roc:	0.92896+/-0.00000
#   valid auc-pr:		0.92517+/-0.00185
# Epoch 75 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34452 -- accuracy=86.66%
#   valid loss:		0.33851
#   valid accuracy:	0.86473+/-0.00000
#   valid auc-roc:	0.92899+/-0.00000
#   valid auc-pr:		0.92532+/-0.00210
# Epoch 76 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34444 -- accuracy=86.67%
#   valid loss:		0.33806
#   valid accuracy:	0.86453+/-0.00000
#   valid auc-roc:	0.92937+/-0.00000
#   valid auc-pr:		0.92580+/-0.00174
# Epoch 77 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34466 -- accuracy=86.68%
#   valid loss:		0.34061
#   valid accuracy:	0.86397+/-0.00000
#   valid auc-roc:	0.92810+/-0.00000
#   valid auc-pr:		0.92428+/-0.00190
# Epoch 78 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34435 -- accuracy=86.68%
#   valid loss:		0.34849
#   valid accuracy:	0.86271+/-0.00000
#   valid auc-roc:	0.92903+/-0.00000
#   valid auc-pr:		0.92501+/-0.00194
# Patience ran out... Early stopping.
# <neuralnetwork.NeuralTrainer instance at 0x7f2be2c7e050>

# %%
nntrainer.set_best_parameters()

# test model
nntrainer.test_model(valid, batch_size=100, name="test")

# %%
def build_model(shape, num_labels):
    def residual_block(net, last_layer, name, filter_size, nonlinearity=nonlinearities.rectify):
        # original residual unit
        shape = layers.get_output_shape(net[last_layer])
        num_filters = shape[1]

        net[name+'_1resid'] = layers.Conv2DLayer(net[last_layer], num_filters=num_filters, filter_size=filter_size, stride=(1, 1),    # 1000
                         W=init.HeNormal(), b=None, nonlinearity=None, pad='same')
        net[name+'_1resid_norm'] = layers.BatchNormLayer(net[name+'_1resid'])
        net[name+'_1resid_active'] = layers.NonlinearityLayer(net[name+'_1resid_norm'], nonlinearity=nonlinearity)

        net[name+'_1resid_dropout'] = layers.DropoutLayer(net[name+'_1resid_active'], p=0.1)

        # bottleneck residual layer
        net[name+'_2resid'] = layers.Conv2DLayer(net[name+'_1resid_dropout'], num_filters=num_filters, filter_size=filter_size, stride=(1, 1),    # 1000
                         W=init.HeNormal(), b=None, nonlinearity=None, pad='same')
        net[name+'_2resid_norm'] = layers.BatchNormLayer(net[name+'_2resid'])

        # combine input with residuals
        net[name+'_residual'] = layers.ElemwiseSumLayer([net[last_layer], net[name+'_2resid_norm']])
        net[name+'_resid'] = layers.NonlinearityLayer(net[name+'_residual'], nonlinearity=nonlinearity)

        return net


    # get model
    input_var = T.tensor4('inputs')
    target_var = T.dmatrix('targets')

    net = {}
    net['input'] = layers.InputLayer(input_var=input_var, shape=shape)
    net['conv1'] = layers.Conv2DLayer(net['input'], num_filters=50, filter_size=(3, 11), stride=(1, 1),    # 1000
                                        W=init.HeNormal(), b=None, nonlinearity=None, pad='same')
    net['conv1_norm'] = layers.BatchNormLayer(net['conv1'])
    net['conv1_active'] = layers.NonlinearityLayer(net['conv1_norm'], nonlinearity=nonlinearities.rectify)
    net['conv1_dropout1'] = layers.DropoutLayer(net['conv1_active'], p=0.1)
    net = residual_block(net, 'conv1_dropout1', 'conv1_2', filter_size=(1,5), nonlinearity=nonlinearities.rectify)
    net['conv1_pool'] = layers.MaxPool2DLayer(net['conv1_2_resid'], pool_size=(3, 10), stride=(3, 10), ignore_border=False) # 25
    net['conv1_dropout'] = layers.DropoutLayer(net['conv1_pool'], p=0.1)

    net['conv2'] = layers.Conv2DLayer(net['conv1_dropout'], num_filters=100, filter_size=(1, 7), stride=(1, 1), # 18
                                        W=init.HeNormal(), b=None, nonlinearity=None, pad='valid')
    net['conv2_norm'] = layers.BatchNormLayer(net['conv2'])
    net['conv2_active'] = layers.NonlinearityLayer(net['conv2_norm'], nonlinearity=nonlinearities.rectify)
    net['conv2_dropout1'] = layers.DropoutLayer(net['conv2_active'], p=0.1)
    net = residual_block(net, 'conv2_dropout1', 'conv2_2', filter_size=(1,5), nonlinearity=nonlinearities.rectify)
    net['conv2_pool'] = layers.MaxPool2DLayer(net['conv2_2_resid'], pool_size=(1, 10), stride=(1, 10), ignore_border=False) # 25
    net['conv2_dropout'] = layers.DropoutLayer(net['conv2_pool'], p=0.1)

    net['dense1'] = layers.DenseLayer(net['conv2_dropout'], num_units=512, W=init.HeNormal(), 
                                     b=init.Constant(), nonlinearity=None)
    net['dense1_active'] = layers.NonlinearityLayer(net['dense1'], nonlinearity=nonlinearities.rectify)
    net['dense1_dropout'] = layers.DropoutLayer(net['dense1_active'], p=0.3)
    
    net['dense2'] = layers.DenseLayer(net['dense1_dropout'], num_units=num_labels, W=init.HeNormal(), 
                                     b=init.Constant(), nonlinearity=None)
    net['output'] = layers.NonlinearityLayer(net['dense2'], nonlinearity=nonlinearities.sigmoid)
    
    # optimization parameters
    optimization = {"objective": "binary",
                    "optimizer": "adam",
                    "learning_rate": 0.001, 
                    "l2": 1e-5
                    }

    return net, input_var, target_var, optimization

# build network
shape = (None, train[0].shape[1], train[0].shape[2], train[0].shape[3])
num_labels = train[1].shape[1]
net, input_var, target_var, optimization = build_model(shape, num_labels)

# build neural network class
nnmodel = NeuralNet(net, input_var, target_var)
#nnmodel.inspect_layers()

# set output file paths
resultspath = utils.make_directory('../results', 'test')
output_name = 'tim_model_resid'
filepath = os.path.join(resultspath, output_name)
savepath = utils.make_directory(resultspath, output_name)
nntrainer = NeuralTrainer(nnmodel, optimization, save='best', filepath=filepath)
# Out:
# making directory: ../results/test/tim_model_resid
# compiling model

# %%
# train model
fit.train_minibatch(nntrainer, data={'train': train, 'valid': valid}, 
                              batch_size=100, num_epochs=500, patience=10, verbose=1)
# Out:
# Epoch 1 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.39779 -- accuracy=85.06%
#   valid loss:		0.35745
#   valid accuracy:	0.85890+/-0.00000
#   valid auc-roc:	0.91790+/-0.00000
#   valid auc-pr:		0.91163+/-0.00570
# saving model parameters to: ../results/test/tim_model_resid_best.pickle
# Epoch 2 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.37252 -- accuracy=85.87%
#   valid loss:		0.35454
#   valid accuracy:	0.86126+/-0.00000
#   valid auc-roc:	0.92132+/-0.00000
#   valid auc-pr:		0.91583+/-0.00370
# saving model parameters to: ../results/test/tim_model_resid_best.pickle
# Epoch 3 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.36548 -- accuracy=86.12%
#   valid loss:		0.34813
#   valid accuracy:	0.86327+/-0.00000
#   valid auc-roc:	0.92404+/-0.00000
#   valid auc-pr:		0.91894+/-0.00427
# saving model parameters to: ../results/test/tim_model_resid_best.pickle
# Epoch 4 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.36227 -- accuracy=86.20%
#   valid loss:		0.34817
#   valid accuracy:	0.86272+/-0.00000
#   valid auc-roc:	0.92594+/-0.00000
#   valid auc-pr:		0.92157+/-0.00317
# Epoch 5 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.36002 -- accuracy=86.26%
#   valid loss:		0.34460
#   valid accuracy:	0.86386+/-0.00000
#   valid auc-roc:	0.92607+/-0.00000
#   valid auc-pr:		0.92148+/-0.00295
# saving model parameters to: ../results/test/tim_model_resid_best.pickle
# Epoch 6 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35873 -- accuracy=86.33%
#   valid loss:		0.33904
#   valid accuracy:	0.86494+/-0.00000
#   valid auc-roc:	0.92720+/-0.00000
#   valid auc-pr:		0.92303+/-0.00314
# saving model parameters to: ../results/test/tim_model_resid_best.pickle
# Epoch 7 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35754 -- accuracy=86.38%
#   valid loss:		0.34541
#   valid accuracy:	0.86418+/-0.00000
#   valid auc-roc:	0.92727+/-0.00000
#   valid auc-pr:		0.92331+/-0.00313
# Epoch 8 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35680 -- accuracy=86.40%
#   valid loss:		0.33596
#   valid accuracy:	0.86571+/-0.00000
#   valid auc-roc:	0.92880+/-0.00000
#   valid auc-pr:		0.92511+/-0.00243
# saving model parameters to: ../results/test/tim_model_resid_best.pickle
# Epoch 9 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35563 -- accuracy=86.40%
#   valid loss:		0.33684
#   valid accuracy:	0.86592+/-0.00000
#   valid auc-roc:	0.92901+/-0.00000
#   valid auc-pr:		0.92514+/-0.00222
# Epoch 10 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35517 -- accuracy=86.46%
#   valid loss:		0.34215
#   valid accuracy:	0.86511+/-0.00000
#   valid auc-roc:	0.92866+/-0.00000
#   valid auc-pr:		0.92477+/-0.00293
# Epoch 11 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35478 -- accuracy=86.44%
#   valid loss:		0.33587
#   valid accuracy:	0.86600+/-0.00000
#   valid auc-roc:	0.92912+/-0.00000
#   valid auc-pr:		0.92514+/-0.00246
# saving model parameters to: ../results/test/tim_model_resid_best.pickle
# Epoch 12 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35411 -- accuracy=86.51%
#   valid loss:		0.34027
#   valid accuracy:	0.86531+/-0.00000
#   valid auc-roc:	0.92893+/-0.00000
#   valid auc-pr:		0.92513+/-0.00248
# Epoch 13 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35431 -- accuracy=86.50%
#   valid loss:		0.33482
#   valid accuracy:	0.86597+/-0.00000
#   valid auc-roc:	0.92983+/-0.00000
#   valid auc-pr:		0.92623+/-0.00215
# saving model parameters to: ../results/test/tim_model_resid_best.pickle
# Epoch 14 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35398 -- accuracy=86.48%
#   valid loss:		0.33482
#   valid accuracy:	0.86623+/-0.00000
#   valid auc-roc:	0.92982+/-0.00000
#   valid auc-pr:		0.92644+/-0.00195
# Epoch 15 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35343 -- accuracy=86.49%
#   valid loss:		0.33446
#   valid accuracy:	0.86596+/-0.00000
#   valid auc-roc:	0.92987+/-0.00000
#   valid auc-pr:		0.92625+/-0.00195
# saving model parameters to: ../results/test/tim_model_resid_best.pickle
# Epoch 16 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35306 -- accuracy=86.50%
#   valid loss:		0.33245
#   valid accuracy:	0.86692+/-0.00000
#   valid auc-roc:	0.93057+/-0.00000
#   valid auc-pr:		0.92715+/-0.00158
# saving model parameters to: ../results/test/tim_model_resid_best.pickle
# Epoch 17 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35274 -- accuracy=86.52%
#   valid loss:		0.33512
#   valid accuracy:	0.86659+/-0.00000
#   valid auc-roc:	0.93015+/-0.00000
#   valid auc-pr:		0.92662+/-0.00213
# Epoch 18 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35268 -- accuracy=86.54%
#   valid loss:		0.33814
#   valid accuracy:	0.86640+/-0.00000
#   valid auc-roc:	0.93010+/-0.00000
#   valid auc-pr:		0.92657+/-0.00178
# Epoch 19 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35246 -- accuracy=86.53%
#   valid loss:		0.33308
#   valid accuracy:	0.86652+/-0.00000
#   valid auc-roc:	0.93070+/-0.00000
#   valid auc-pr:		0.92730+/-0.00165
# Epoch 20 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35240 -- accuracy=86.52%
#   valid loss:		0.33488
#   valid accuracy:	0.86717+/-0.00000
#   valid auc-roc:	0.93093+/-0.00000
#   valid auc-pr:		0.92751+/-0.00176
# Epoch 21 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35199 -- accuracy=86.53%
#   valid loss:		0.33575
#   valid accuracy:	0.86638+/-0.00000
#   valid auc-roc:	0.93035+/-0.00000
#   valid auc-pr:		0.92711+/-0.00183
# Epoch 22 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35188 -- accuracy=86.55%
#   valid loss:		0.33508
#   valid accuracy:	0.86687+/-0.00000
#   valid auc-roc:	0.93091+/-0.00000
#   valid auc-pr:		0.92768+/-0.00132
# Epoch 23 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35219 -- accuracy=86.54%
#   valid loss:		0.33545
#   valid accuracy:	0.86629+/-0.00000
#   valid auc-roc:	0.93095+/-0.00000
#   valid auc-pr:		0.92751+/-0.00161
# Epoch 24 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35152 -- accuracy=86.57%
#   valid loss:		0.33724
#   valid accuracy:	0.86665+/-0.00000
#   valid auc-roc:	0.93039+/-0.00000
#   valid auc-pr:		0.92703+/-0.00133
# Epoch 25 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35135 -- accuracy=86.58%
#   valid loss:		0.33344
#   valid accuracy:	0.86707+/-0.00000
#   valid auc-roc:	0.93041+/-0.00000
#   valid auc-pr:		0.92676+/-0.00132
# Epoch 26 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35187 -- accuracy=86.56%
#   valid loss:		0.33154
#   valid accuracy:	0.86766+/-0.00000
#   valid auc-roc:	0.93140+/-0.00000
#   valid auc-pr:		0.92806+/-0.00129
# saving model parameters to: ../results/test/tim_model_resid_best.pickle
# Epoch 27 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35110 -- accuracy=86.58%
#   valid loss:		0.33370
#   valid accuracy:	0.86616+/-0.00000
#   valid auc-roc:	0.93061+/-0.00000
#   valid auc-pr:		0.92725+/-0.00171
# Epoch 28 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35143 -- accuracy=86.59%
#   valid loss:		0.33236
#   valid accuracy:	0.86679+/-0.00000
#   valid auc-roc:	0.93083+/-0.00000
#   valid auc-pr:		0.92757+/-0.00173
# Epoch 29 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35118 -- accuracy=86.60%
#   valid loss:		0.33609
#   valid accuracy:	0.86618+/-0.00000
#   valid auc-roc:	0.93089+/-0.00000
#   valid auc-pr:		0.92739+/-0.00163
# Epoch 30 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35107 -- accuracy=86.59%
#   valid loss:		0.33212
#   valid accuracy:	0.86718+/-0.00000
#   valid auc-roc:	0.93110+/-0.00000
#   valid auc-pr:		0.92770+/-0.00184
# Epoch 31 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35088 -- accuracy=86.59%
#   valid loss:		0.33527
#   valid accuracy:	0.86590+/-0.00000
#   valid auc-roc:	0.93165+/-0.00000
#   valid auc-pr:		0.92868+/-0.00136
# Epoch 32 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35078 -- accuracy=86.61%
#   valid loss:		0.33442
#   valid accuracy:	0.86640+/-0.00000
#   valid auc-roc:	0.93014+/-0.00000
#   valid auc-pr:		0.92660+/-0.00195
# Epoch 33 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35068 -- accuracy=86.61%
#   valid loss:		0.33322
#   valid accuracy:	0.86657+/-0.00000
#   valid auc-roc:	0.93119+/-0.00000
#   valid auc-pr:		0.92789+/-0.00143
# Epoch 34 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35060 -- accuracy=86.62%
#   valid loss:		0.33412
#   valid accuracy:	0.86694+/-0.00000
#   valid auc-roc:	0.93027+/-0.00000
#   valid auc-pr:		0.92668+/-0.00212
# Epoch 35 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35046 -- accuracy=86.62%
#   valid loss:		0.33207
#   valid accuracy:	0.86712+/-0.00000
#   valid auc-roc:	0.93144+/-0.00000
#   valid auc-pr:		0.92827+/-0.00126
# Epoch 36 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35020 -- accuracy=86.65%
#   valid loss:		0.33144
#   valid accuracy:	0.86731+/-0.00000
#   valid auc-roc:	0.93100+/-0.00000
#   valid auc-pr:		0.92724+/-0.00159
# saving model parameters to: ../results/test/tim_model_resid_best.pickle
# Epoch 37 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35045 -- accuracy=86.61%
#   valid loss:		0.33736
#   valid accuracy:	0.86506+/-0.00000
#   valid auc-roc:	0.93125+/-0.00000
#   valid auc-pr:		0.92802+/-0.00117
# Epoch 38 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35077 -- accuracy=86.58%
#   valid loss:		0.33388
#   valid accuracy:	0.86764+/-0.00000
#   valid auc-roc:	0.93145+/-0.00000
#   valid auc-pr:		0.92809+/-0.00104
# Epoch 39 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35038 -- accuracy=86.61%
#   valid loss:		0.33211
#   valid accuracy:	0.86694+/-0.00000
#   valid auc-roc:	0.93099+/-0.00000
#   valid auc-pr:		0.92756+/-0.00181
# Epoch 40 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35031 -- accuracy=86.62%
#   valid loss:		0.33083
#   valid accuracy:	0.86762+/-0.00000
#   valid auc-roc:	0.93186+/-0.00000
#   valid auc-pr:		0.92861+/-0.00108
# saving model parameters to: ../results/test/tim_model_resid_best.pickle
# Epoch 41 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35007 -- accuracy=86.64%
#   valid loss:		0.33197
#   valid accuracy:	0.86673+/-0.00000
#   valid auc-roc:	0.93106+/-0.00000
#   valid auc-pr:		0.92777+/-0.00154
# Epoch 42 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34996 -- accuracy=86.63%
#   valid loss:		0.33431
#   valid accuracy:	0.86692+/-0.00000
#   valid auc-roc:	0.93141+/-0.00000
#   valid auc-pr:		0.92823+/-0.00160
# Epoch 43 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34991 -- accuracy=86.62%
#   valid loss:		0.33317
#   valid accuracy:	0.86706+/-0.00000
#   valid auc-roc:	0.93176+/-0.00000
#   valid auc-pr:		0.92867+/-0.00104
# Epoch 44 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35020 -- accuracy=86.62%
#   valid loss:		0.33249
#   valid accuracy:	0.86724+/-0.00000
#   valid auc-roc:	0.93163+/-0.00000
#   valid auc-pr:		0.92821+/-0.00137
# Epoch 45 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35009 -- accuracy=86.63%
#   valid loss:		0.33738
#   valid accuracy:	0.86560+/-0.00000
#   valid auc-roc:	0.93087+/-0.00000
#   valid auc-pr:		0.92763+/-0.00147
# Epoch 46 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34989 -- accuracy=86.64%
#   valid loss:		0.32985
#   valid accuracy:	0.86751+/-0.00000
#   valid auc-roc:	0.93217+/-0.00000
#   valid auc-pr:		0.92897+/-0.00098
# saving model parameters to: ../results/test/tim_model_resid_best.pickle
# Epoch 47 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34987 -- accuracy=86.65%
#   valid loss:		0.33419
#   valid accuracy:	0.86629+/-0.00000
#   valid auc-roc:	0.93177+/-0.00000
#   valid auc-pr:		0.92860+/-0.00113
# Epoch 48 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35026 -- accuracy=86.61%
#   valid loss:		0.33019
#   valid accuracy:	0.86754+/-0.00000
#   valid auc-roc:	0.93206+/-0.00000
#   valid auc-pr:		0.92898+/-0.00110
# Epoch 49 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.35000 -- accuracy=86.62%
#   valid loss:		0.33002
#   valid accuracy:	0.86750+/-0.00000
#   valid auc-roc:	0.93214+/-0.00000
#   valid auc-pr:		0.92890+/-0.00127
# Epoch 50 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34982 -- accuracy=86.65%
#   valid loss:		0.33563
#   valid accuracy:	0.86585+/-0.00000
#   valid auc-roc:	0.93149+/-0.00000
#   valid auc-pr:		0.92827+/-0.00096
# Epoch 51 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34987 -- accuracy=86.64%
#   valid loss:		0.33233
#   valid accuracy:	0.86681+/-0.00000
#   valid auc-roc:	0.93121+/-0.00000
#   valid auc-pr:		0.92779+/-0.00129
# Epoch 52 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34960 -- accuracy=86.65%
#   valid loss:		0.33019
#   valid accuracy:	0.86753+/-0.00000
#   valid auc-roc:	0.93202+/-0.00000
#   valid auc-pr:		0.92863+/-0.00138
# Epoch 53 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34960 -- accuracy=86.64%
#   valid loss:		0.33466
#   valid accuracy:	0.86694+/-0.00000
#   valid auc-roc:	0.93205+/-0.00000
#   valid auc-pr:		0.92883+/-0.00097
# Epoch 54 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34985 -- accuracy=86.62%
#   valid loss:		0.33202
#   valid accuracy:	0.86669+/-0.00000
#   valid auc-roc:	0.93232+/-0.00000
#   valid auc-pr:		0.92926+/-0.00098
# Epoch 55 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34953 -- accuracy=86.65%
#   valid loss:		0.33481
#   valid accuracy:	0.86693+/-0.00000
#   valid auc-roc:	0.93120+/-0.00000
#   valid auc-pr:		0.92790+/-0.00166
# Epoch 56 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34943 -- accuracy=86.63%
#   valid loss:		0.32945
#   valid accuracy:	0.86730+/-0.00000
#   valid auc-roc:	0.93247+/-0.00000
#   valid auc-pr:		0.92929+/-0.00097
# saving model parameters to: ../results/test/tim_model_resid_best.pickle
# Epoch 57 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34956 -- accuracy=86.66%
#   valid loss:		0.33297
#   valid accuracy:	0.86717+/-0.00000
#   valid auc-roc:	0.93161+/-0.00000
#   valid auc-pr:		0.92839+/-0.00101
# Epoch 58 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34964 -- accuracy=86.65%
#   valid loss:		0.33362
#   valid accuracy:	0.86582+/-0.00000
#   valid auc-roc:	0.93178+/-0.00000
#   valid auc-pr:		0.92847+/-0.00138
# Epoch 59 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34929 -- accuracy=86.65%
#   valid loss:		0.33309
#   valid accuracy:	0.86673+/-0.00000
#   valid auc-roc:	0.93188+/-0.00000
#   valid auc-pr:		0.92866+/-0.00093
# Epoch 60 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34936 -- accuracy=86.66%
#   valid loss:		0.33164
#   valid accuracy:	0.86734+/-0.00000
#   valid auc-roc:	0.93141+/-0.00000
#   valid auc-pr:		0.92803+/-0.00115
# Epoch 61 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34963 -- accuracy=86.64%
#   valid loss:		0.33151
#   valid accuracy:	0.86707+/-0.00000
#   valid auc-roc:	0.93226+/-0.00000
#   valid auc-pr:		0.92918+/-0.00072
# Epoch 62 out of 500
# [==============================] 100.0% -- time=0s -- loss=0.34940 -- accuracy=86.65%
#   valid loss:		0.33778
#   valid accuracy:	0.86533+/-0.00000
#   valid auc-roc:	0.93181+/-0.00000
#   valid auc-pr:		0.92856+/-0.00074
# Epoch 63 out of 500
# [=                             ] 2.0% -- time=457s -- loss=0.35595 -- accuracy=86.41%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-7cc1a73aae23> in <module>()
#       1 # train model
#       2 fit.train_minibatch(nntrainer, data={'train': train, 'valid': valid},
# ----> 3                               batch_size=100, num_epochs=500, patience=10, verbose=1)
#
# /home/peter/Code/deepomics/train.pyc in train_minibatch(nntrainer, data, batch_size, num_epochs, patience, verbose)
#      28
#      29                 # training set
# ---> 30                 train_loss = nntrainer.train_step(data['train'], batch_size, verbose)
#      31                 nntrainer.add_loss(train_loss, 'train')
#      32
#
# /home/peter/Code/deepomics/neuralnetwork.py in train_step(self, train, batch_size, verbose)
#     221                 for i in range(num_batches):
#     222                         X, y = next(batches)
# --> 223                         loss, prediction = self.train_fun(X, y)
#     224                         value += self.train_metric(prediction, y)
#     225                         performance.add_loss(loss)
#
# /home/peter/Theano/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     864         try:
#     865             outputs =\
# --> 866                 self.fn() if output_subset is None else\
#     867                 self.fn(output_subset=output_subset)
#     868         except Exception:
#
# /home/peter/Theano/theano/gof/op.pyc in rval(p, i, o, n)
#     863         if params is graph.NoParams:
#     864             # default arguments are stored in the closure of `rval`
# --> 865             def rval(p=p, i=node_input_storage, o=node_output_storage, n=node):
#     866                 r = p(n, [x[0] for x in i], o)
#     867                 for o in node.outputs:
#
# KeyboardInterrupt:
