# %%
from __future__ import print_function 
import os, sys, h5py
import numpy as np
from six.moves import cPickle
from collections import OrderedDict

import tensorflow as tf
sys.path.append('..')
from tfomics import neuralnetwork as nn
from tfomics import utils, fit, init, visualize, saliency
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def load_simulation(filepath):
    # setup paths for file handling

    trainmat = h5py.File(filepath, 'r')

    print("loading training data")
    X_train = np.array(trainmat['X_train']).astype(np.float32)
    y_train = np.array(trainmat['Y_train']).astype(np.float32)

    print("loading cross-validation data")
    X_valid = np.array(trainmat['X_valid']).astype(np.float32)
    y_valid = np.array(trainmat['Y_valid']).astype(np.int32)

    print("loading test data")
    X_test = np.array(trainmat['X_test']).astype(np.float32)
    y_test = np.array(trainmat['Y_test']).astype(np.int32)


    X_train = np.expand_dims(X_train, axis=3).transpose([0,2,3,1])
    X_valid = np.expand_dims(X_valid, axis=3).transpose([0,2,3,1])
    X_test = np.expand_dims(X_test, axis=3).transpose([0,2,3,1])

    return X_train, y_train, X_valid, y_valid, X_test, y_test


# load data
filename = 'Synthetic_TF_dataset_20000.h5'
data_path = '/Users/juliankimura/Desktop/representation learning/data/synthetic_TF_dataset'
filepath = os.path.join(data_path, filename)
X_train, y_train, X_valid, y_valid, X_test, y_test = load_simulation(filepath)
# Out:
# loading training data
# loading cross-validation data
# loading test data

# %%
def model(input_shape, output_shape):

    # create model
    layer1 = {'layer': 'input',
            'input_shape': input_shape
            }
    layer2 = {'layer': 'conv1d', 
            'num_filters': 32,
            'filter_size': 11,
            'norm': 'batch',
            'activation': 'relu',
            'dropout': 0.1,
            'padding': 'SAME',
            'pool_size': 50,
            }
    layer3 = {'layer': 'dense', 
            'num_units': 48,
            'norm': 'batch',
            'activation': 'relu',
            'dropout': 0.5
            }  
    layer4 = {'layer': 'dense', 
            'num_units': output_shape[1],
            'activation': 'sigmoid'
            }

    #from tfomics import build_network
    model_layers = [layer1, layer2, layer3, layer4]
    
    # optimization parameters
    optimization = {"objective": "binary",
                  "optimizer": "adam",
                  "learning_rate": 0.001, 
                  #"l2": 0,
                  # "l1": 0, 
                  }
    return model_layers, optimization


# get shapes
num_data, height, width, dim = X_train.shape
input_shape=[None, height, width, dim]
output_shape = y_train.shape

model_layers, optimization = model(input_shape, output_shape)

# %%
# set output file paths
results_path = utils.make_directory(data_path, 'results')
results_path = utils.make_directory(results_path, 'tfomics')
output_name = 'test'
filepath = os.path.join(results_path, output_name)

# build neural network class
nnmodel = nn.NeuralNet()
nnmodel.build_layers(model_layers, optimization)
nnmodel.inspect_layers()

# compile neural trainer
nntrainer = nn.NeuralTrainer(nnmodel, save='best', filepath=filepath)
# Out:
# ----------------------------------------------------------------------------
# Network architecture:
# ----------------------------------------------------------------------------
# layer1: inputs
# (?, 200, 1, 4)
# layer2: conv1d_0
# (?, 200, 1, 32)
# layer3: conv1d_0_batch
# (?, 200, 1, 32)
# layer4: conv1d_0_active
# (?, 200, 1, 32)
# layer5: conv1d_0_pool
# (?, 4, 1, 32)
# layer6: conv1d_0_dropout
# (?, 4, 1, 32)
# layer7: dense_0
# (?, 48)
# layer8: dense_0_batch
# (?, 48)
# layer9: dense_0_active
# (?, 48)
# layer10: dense_0_dropout
# (?, 48)
# layer11: dense_1
# (?, 1)
# layer12: dense_1_bias
# (?, 1)
# layer13: output
# (?, 1)
# ----------------------------------------------------------------------------

# %%
sess = utils.initialize_session(nnmodel.placeholders)

# %%
train = {'inputs': X_train, 'targets': y_train}
valid = {'inputs': X_valid, 'targets': y_valid}
test = {'inputs': X_test, 'targets': y_test}
data = {'train': train, 'valid': valid, 'test': test}
results = fit.train_minibatch(sess, nntrainer, data, batch_size=200, num_epochs=50, 
                              patience=20, verbose=2, shuffle=True, save='all')
# Out:
# Epoch 1 out of 50
# [==============================] 100.0% -- time=0s -- loss=0.83446 -- accuracy=51.32%
#   valid loss:		1.93199
#   valid accuracy:	0.51267+/-0.00000
#   valid auc-roc:	0.60830+/-0.00000
#   valid auc-pr:		0.58074+/-0.00000
#   lower cross-validation found
#   saving model to:  /Users/juliankimura/Desktop/representation learning/data/synthetic_TF_dataset/results/tfomics/test_best.ckpt
# Epoch 2 out of 50
# [==============================] 100.0% -- time=0s -- loss=0.75652 -- accuracy=53.10%
#   valid loss:		0.98863
#   valid accuracy:	0.51267+/-0.00000
#   valid auc-roc:	0.66700+/-0.00000
#   valid auc-pr:		0.64071+/-0.00000
#   lower cross-validation found
#   saving model to:  /Users/juliankimura/Desktop/representation learning/data/synthetic_TF_dataset/results/tfomics/test_best.ckpt
# Epoch 3 out of 50
# [==============================] 100.0% -- time=0s -- loss=0.71342 -- accuracy=55.23%
#   valid loss:		0.69596
#   valid accuracy:	0.53267+/-0.00000
#   valid auc-roc:	0.71862+/-0.00000
#   valid auc-pr:		0.69769+/-0.00000
#   lower cross-validation found
#   saving model to:  /Users/juliankimura/Desktop/representation learning/data/synthetic_TF_dataset/results/tfomics/test_best.ckpt
# Epoch 4 out of 50
# [==============================] 100.0% -- time=0s -- loss=0.68355 -- accuracy=58.31%
#   valid loss:		0.61886
#   valid accuracy:	0.67533+/-0.00000
#   valid auc-roc:	0.76696+/-0.00000
#   valid auc-pr:		0.74786+/-0.00000
#   lower cross-validation found
#   saving model to:  /Users/juliankimura/Desktop/representation learning/data/synthetic_TF_dataset/results/tfomics/test_best.ckpt
# Epoch 5 out of 50
# [==============================] 100.0% -- time=0s -- loss=0.65835 -- accuracy=61.06%
#   valid loss:		0.59467
#   valid accuracy:	0.72200+/-0.00000
#   valid auc-roc:	0.80224+/-0.00000
#   valid auc-pr:		0.78681+/-0.00000
#   lower cross-validation found
#   saving model to:  /Users/juliankimura/Desktop/representation learning/data/synthetic_TF_dataset/results/tfomics/test_best.ckpt
# Epoch 6 out of 50
# [==============================] 100.0% -- time=0s -- loss=0.63372 -- accuracy=64.13%
#   valid loss:		0.58645
#   valid accuracy:	0.68300+/-0.00000
#   valid auc-roc:	0.83036+/-0.00000
#   valid auc-pr:		0.81798+/-0.00000
#   lower cross-validation found
#   saving model to:  /Users/juliankimura/Desktop/representation learning/data/synthetic_TF_dataset/results/tfomics/test_best.ckpt
# Epoch 7 out of 50
# [==============================] 100.0% -- time=0s -- loss=0.60734 -- accuracy=66.53%
#   valid loss:		0.60034
#   valid accuracy:	0.64033+/-0.00000
#   valid auc-roc:	0.85145+/-0.00000
#   valid auc-pr:		0.84106+/-0.00000
# Epoch 8 out of 50
# [==============================] 100.0% -- time=0s -- loss=0.59250 -- accuracy=68.37%
#   valid loss:		0.60731
#   valid accuracy:	0.63633+/-0.00000
#   valid auc-roc:	0.86733+/-0.00000
#   valid auc-pr:		0.85746+/-0.00000
# Epoch 9 out of 50
# [==============================] 100.0% -- time=0s -- loss=0.56934 -- accuracy=70.71%
#   valid loss:		0.54855
#   valid accuracy:	0.70633+/-0.00000
#   valid auc-roc:	0.88092+/-0.00000
#   valid auc-pr:		0.87079+/-0.00000
#   lower cross-validation found
#   saving model to:  /Users/juliankimura/Desktop/representation learning/data/synthetic_TF_dataset/results/tfomics/test_best.ckpt
# Epoch 10 out of 50
# [==============================] 100.0% -- time=0s -- loss=0.54561 -- accuracy=72.47%
#   valid loss:		0.55160
#   valid accuracy:	0.70200+/-0.00000
#   valid auc-roc:	0.89267+/-0.00000
#   valid auc-pr:		0.88319+/-0.00000
# Epoch 11 out of 50
# [==============================] 100.0% -- time=0s -- loss=0.53246 -- accuracy=73.42%
#   valid loss:		0.50786
#   valid accuracy:	0.73967+/-0.00000
#   valid auc-roc:	0.90203+/-0.00000
#   valid auc-pr:		0.89244+/-0.00000
#   lower cross-validation found
#   saving model to:  /Users/juliankimura/Desktop/representation learning/data/synthetic_TF_dataset/results/tfomics/test_best.ckpt
# Epoch 12 out of 50
# [==============================] 100.0% -- time=0s -- loss=0.51095 -- accuracy=75.06%
#   valid loss:		0.46575
#   valid accuracy:	0.77667+/-0.00000
#   valid auc-roc:	0.90934+/-0.00000
#   valid auc-pr:		0.90031+/-0.00000
#   lower cross-validation found
#   saving model to:  /Users/juliankimura/Desktop/representation learning/data/synthetic_TF_dataset/results/tfomics/test_best.ckpt
# Epoch 13 out of 50
# [==============================] 100.0% -- time=0s -- loss=0.50552 -- accuracy=75.32%
#   valid loss:		0.42537
#   valid accuracy:	0.82200+/-0.00000
#   valid auc-roc:	0.91489+/-0.00000
#   valid auc-pr:		0.90558+/-0.00000
#   lower cross-validation found
#   saving model to:  /Users/juliankimura/Desktop/representation learning/data/synthetic_TF_dataset/results/tfomics/test_best.ckpt
# Epoch 14 out of 50
# [==============================] 100.0% -- time=0s -- loss=0.48733 -- accuracy=76.67%
#   valid loss:		0.40602
#   valid accuracy:	0.83600+/-0.00000
#   valid auc-roc:	0.91864+/-0.00000
#   valid auc-pr:		0.90916+/-0.00000
#   lower cross-validation found
#   saving model to:  /Users/juliankimura/Desktop/representation learning/data/synthetic_TF_dataset/results/tfomics/test_best.ckpt
# Epoch 15 out of 50
# [==============================] 100.0% -- time=0s -- loss=0.48540 -- accuracy=77.09%
#   valid loss:		0.40021
#   valid accuracy:	0.83767+/-0.00000
#   valid auc-roc:	0.92246+/-0.00000
#   valid auc-pr:		0.91405+/-0.00000
#   lower cross-validation found
#   saving model to:  /Users/juliankimura/Desktop/representation learning/data/synthetic_TF_dataset/results/tfomics/test_best.ckpt
# Epoch 16 out of 50
# [==============================] 100.0% -- time=0s -- loss=0.46354 -- accuracy=78.41%
#   valid loss:		0.39319
#   valid accuracy:	0.83900+/-0.00000
#   valid auc-roc:	0.92531+/-0.00000
#   valid auc-pr:		0.91684+/-0.00000
#   lower cross-validation found
#   saving model to:  /Users/juliankimura/Desktop/representation learning/data/synthetic_TF_dataset/results/tfomics/test_best.ckpt
# Epoch 17 out of 50
# [==============================] 100.0% -- time=0s -- loss=0.45515 -- accuracy=78.96%
#   valid loss:		0.38547
#   valid accuracy:	0.84300+/-0.00000
#   valid auc-roc:	0.92874+/-0.00000
#   valid auc-pr:		0.92032+/-0.00000
#   lower cross-validation found
#   saving model to:  /Users/juliankimura/Desktop/representation learning/data/synthetic_TF_dataset/results/tfomics/test_best.ckpt
# Epoch 18 out of 50
# [==============================] 100.0% -- time=0s -- loss=0.43873 -- accuracy=80.07%
#   valid loss:		0.39053
#   valid accuracy:	0.83500+/-0.00000
#   valid auc-roc:	0.93185+/-0.00000
#   valid auc-pr:		0.92388+/-0.00000
# Epoch 19 out of 50
# [==============================] 100.0% -- time=0s -- loss=0.43202 -- accuracy=80.49%
#   valid loss:		0.40722
#   valid accuracy:	0.81433+/-0.00000
#   valid auc-roc:	0.93403+/-0.00000
#   valid auc-pr:		0.92636+/-0.00000
# Epoch 20 out of 50
# [==============================] 100.0% -- time=0s -- loss=0.41222 -- accuracy=81.49%
#   valid loss:		0.43735
#   valid accuracy:	0.78033+/-0.00000
#   valid auc-roc:	0.93649+/-0.00000
#   valid auc-pr:		0.92918+/-0.00000
# Epoch 21 out of 50
# [==============================] 100.0% -- time=0s -- loss=0.40200 -- accuracy=81.87%
#   valid loss:		0.44692
#   valid accuracy:	0.76800+/-0.00000
#   valid auc-roc:	0.93925+/-0.00000
#   valid auc-pr:		0.93244+/-0.00000
# Epoch 22 out of 50
# [==============================] 100.0% -- time=0s -- loss=0.37685 -- accuracy=83.24%
#   valid loss:		0.46124
#   valid accuracy:	0.75367+/-0.00000
#   valid auc-roc:	0.94350+/-0.00000
#   valid auc-pr:		0.93661+/-0.00000
# Epoch 23 out of 50
# [==============================] 100.0% -- time=0s -- loss=0.35569 -- accuracy=84.41%
#   valid loss:		0.38951
#   valid accuracy:	0.81833+/-0.00000
#   valid auc-roc:	0.95025+/-0.00000
#   valid auc-pr:		0.94348+/-0.00000
# Epoch 24 out of 50
# [==============================] 100.0% -- time=0s -- loss=0.32439 -- accuracy=85.86%
#   valid loss:		0.34355
#   valid accuracy:	0.87533+/-0.00000
#   valid auc-roc:	0.95696+/-0.00000
#   valid auc-pr:		0.95130+/-0.00000
#   lower cross-validation found
#   saving model to:  /Users/juliankimura/Desktop/representation learning/data/synthetic_TF_dataset/results/tfomics/test_best.ckpt
# Epoch 25 out of 50
# [==============================] 100.0% -- time=0s -- loss=0.29603 -- accuracy=87.69%
#   valid loss:		0.34460
#   valid accuracy:	0.87633+/-0.00000
#   valid auc-roc:	0.96289+/-0.00000
#   valid auc-pr:		0.95692+/-0.00000
# Epoch 26 out of 50
# [==============================] 100.0% -- time=0s -- loss=0.27266 -- accuracy=89.04%
#   valid loss:		0.38506
#   valid accuracy:	0.82433+/-0.00000
#   valid auc-roc:	0.96750+/-0.00000
#   valid auc-pr:		0.96128+/-0.00000
# Epoch 27 out of 50
# [==============================] 100.0% -- time=0s -- loss=0.25096 -- accuracy=89.85%
#   valid loss:		0.39674
#   valid accuracy:	0.81533+/-0.00000
#   valid auc-roc:	0.97107+/-0.00000
#   valid auc-pr:		0.96490+/-0.00000
# Epoch 28 out of 50
# [==============================] 100.0% -- time=0s -- loss=0.22658 -- accuracy=91.24%
#   valid loss:		0.30609
#   valid accuracy:	0.87233+/-0.00000
#   valid auc-roc:	0.97570+/-0.00000
#   valid auc-pr:		0.96993+/-0.00000
#   lower cross-validation found
#   saving model to:  /Users/juliankimura/Desktop/representation learning/data/synthetic_TF_dataset/results/tfomics/test_best.ckpt
# Epoch 29 out of 50
# [==============================] 100.0% -- time=0s -- loss=0.21994 -- accuracy=91.11%
#   valid loss:		0.24400
#   valid accuracy:	0.91067+/-0.00000
#   valid auc-roc:	0.97830+/-0.00000
#   valid auc-pr:		0.97241+/-0.00000
#   lower cross-validation found
#   saving model to:  /Users/juliankimura/Desktop/representation learning/data/synthetic_TF_dataset/results/tfomics/test_best.ckpt
# Epoch 30 out of 50
# [==============================] 100.0% -- time=0s -- loss=0.20891 -- accuracy=91.94%
#   valid loss:		0.20370
#   valid accuracy:	0.92667+/-0.00000
#   valid auc-roc:	0.97947+/-0.00000
#   valid auc-pr:		0.97427+/-0.00000
#   lower cross-validation found
#   saving model to:  /Users/juliankimura/Desktop/representation learning/data/synthetic_TF_dataset/results/tfomics/test_best.ckpt
# Epoch 31 out of 50
# [==============================] 100.0% -- time=0s -- loss=0.19403 -- accuracy=92.31%
#   valid loss:		0.19659
#   valid accuracy:	0.92800+/-0.00000
#   valid auc-roc:	0.98066+/-0.00000
#   valid auc-pr:		0.97538+/-0.00000
#   lower cross-validation found
#   saving model to:  /Users/juliankimura/Desktop/representation learning/data/synthetic_TF_dataset/results/tfomics/test_best.ckpt
# Epoch 32 out of 50
# [==============================] 100.0% -- time=0s -- loss=0.19736 -- accuracy=92.19%
#   valid loss:		0.18484
#   valid accuracy:	0.93067+/-0.00000
#   valid auc-roc:	0.98008+/-0.00000
#   valid auc-pr:		0.97590+/-0.00000
#   lower cross-validation found
#   saving model to:  /Users/juliankimura/Desktop/representation learning/data/synthetic_TF_dataset/results/tfomics/test_best.ckpt
# Epoch 33 out of 50
# [==============================] 100.0% -- time=0s -- loss=0.19462 -- accuracy=92.44%
#   valid loss:		0.17438
#   valid accuracy:	0.93367+/-0.00000
#   valid auc-roc:	0.98278+/-0.00000
#   valid auc-pr:		0.97952+/-0.00000
#   lower cross-validation found
#   saving model to:  /Users/juliankimura/Desktop/representation learning/data/synthetic_TF_dataset/results/tfomics/test_best.ckpt
# Epoch 34 out of 50
# [==============================] 100.0% -- time=0s -- loss=0.17611 -- accuracy=93.20%
#   valid loss:		0.16585
#   valid accuracy:	0.94000+/-0.00000
#   valid auc-roc:	0.98324+/-0.00000
#   valid auc-pr:		0.98025+/-0.00000
#   lower cross-validation found
#   saving model to:  /Users/juliankimura/Desktop/representation learning/data/synthetic_TF_dataset/results/tfomics/test_best.ckpt
# Epoch 35 out of 50
# [==============================] 100.0% -- time=0s -- loss=0.17224 -- accuracy=93.26%
#   valid loss:		0.16280
#   valid accuracy:	0.93567+/-0.00000
#   valid auc-roc:	0.98467+/-0.00000
#   valid auc-pr:		0.98201+/-0.00000
#   lower cross-validation found
#   saving model to:  /Users/juliankimura/Desktop/representation learning/data/synthetic_TF_dataset/results/tfomics/test_best.ckpt
# Epoch 36 out of 50
# [==============================] 100.0% -- time=0s -- loss=0.17165 -- accuracy=93.43%
#   valid loss:		0.15503
#   valid accuracy:	0.94067+/-0.00000
#   valid auc-roc:	0.98547+/-0.00000
#   valid auc-pr:		0.98262+/-0.00000
#   lower cross-validation found
#   saving model to:  /Users/juliankimura/Desktop/representation learning/data/synthetic_TF_dataset/results/tfomics/test_best.ckpt
# Epoch 37 out of 50
# [==============================] 100.0% -- time=0s -- loss=0.17018 -- accuracy=93.54%
#   valid loss:		0.14361
#   valid accuracy:	0.94533+/-0.00000
#   valid auc-roc:	0.98713+/-0.00000
#   valid auc-pr:		0.98434+/-0.00000
#   lower cross-validation found
#   saving model to:  /Users/juliankimura/Desktop/representation learning/data/synthetic_TF_dataset/results/tfomics/test_best.ckpt
# Epoch 38 out of 50
# [==============================] 100.0% -- time=0s -- loss=0.15935 -- accuracy=93.79%
#   valid loss:		0.14001
#   valid accuracy:	0.94900+/-0.00000
#   valid auc-roc:	0.98765+/-0.00000
#   valid auc-pr:		0.98514+/-0.00000
#   lower cross-validation found
#   saving model to:  /Users/juliankimura/Desktop/representation learning/data/synthetic_TF_dataset/results/tfomics/test_best.ckpt
# Epoch 39 out of 50
# [==============================] 100.0% -- time=0s -- loss=0.16014 -- accuracy=93.83%
#   valid loss:		0.13618
#   valid accuracy:	0.94867+/-0.00000
#   valid auc-roc:	0.98832+/-0.00000
#   valid auc-pr:		0.98605+/-0.00000
#   lower cross-validation found
#   saving model to:  /Users/juliankimura/Desktop/representation learning/data/synthetic_TF_dataset/results/tfomics/test_best.ckpt
# Epoch 40 out of 50
# [==============================] 100.0% -- time=0s -- loss=0.15732 -- accuracy=93.89%
#   valid loss:		0.13432
#   valid accuracy:	0.94567+/-0.00000
#   valid auc-roc:	0.98874+/-0.00000
#   valid auc-pr:		0.98677+/-0.00000
#   lower cross-validation found
#   saving model to:  /Users/juliankimura/Desktop/representation learning/data/synthetic_TF_dataset/results/tfomics/test_best.ckpt
# Epoch 41 out of 50
# [==============================] 100.0% -- time=0s -- loss=0.14782 -- accuracy=94.36%
#   valid loss:		0.13390
#   valid accuracy:	0.95033+/-0.00000
#   valid auc-roc:	0.98855+/-0.00000
#   valid auc-pr:		0.98649+/-0.00000
#   lower cross-validation found
#   saving model to:  /Users/juliankimura/Desktop/representation learning/data/synthetic_TF_dataset/results/tfomics/test_best.ckpt
# Epoch 42 out of 50
# [==============================] 100.0% -- time=0s -- loss=0.14957 -- accuracy=94.21%
#   valid loss:		0.13458
#   valid accuracy:	0.94867+/-0.00000
#   valid auc-roc:	0.98923+/-0.00000
#   valid auc-pr:		0.98728+/-0.00000
# Epoch 43 out of 50
# [==============================] 100.0% -- time=0s -- loss=0.15010 -- accuracy=94.50%
#   valid loss:		0.13409
#   valid accuracy:	0.94833+/-0.00000
#   valid auc-roc:	0.98940+/-0.00000
#   valid auc-pr:		0.98762+/-0.00000
# Epoch 44 out of 50
# [==============================] 100.0% -- time=0s -- loss=0.14196 -- accuracy=94.59%
#   valid loss:		0.12722
#   valid accuracy:	0.94833+/-0.00000
#   valid auc-roc:	0.98964+/-0.00000
#   valid auc-pr:		0.98778+/-0.00000
#   lower cross-validation found
#   saving model to:  /Users/juliankimura/Desktop/representation learning/data/synthetic_TF_dataset/results/tfomics/test_best.ckpt
# Epoch 45 out of 50
# [==============================] 100.0% -- time=0s -- loss=0.14370 -- accuracy=94.56%
#   valid loss:		0.13230
#   valid accuracy:	0.95133+/-0.00000
#   valid auc-roc:	0.98992+/-0.00000
#   valid auc-pr:		0.98781+/-0.00000
# Epoch 46 out of 50
# [==============================] 100.0% -- time=0s -- loss=0.14372 -- accuracy=94.65%
#   valid loss:		0.12574
#   valid accuracy:	0.95100+/-0.00000
#   valid auc-roc:	0.98996+/-0.00000
#   valid auc-pr:		0.98803+/-0.00000
#   lower cross-validation found
#   saving model to:  /Users/juliankimura/Desktop/representation learning/data/synthetic_TF_dataset/results/tfomics/test_best.ckpt
# Epoch 47 out of 50
# [==============================] 100.0% -- time=0s -- loss=0.14468 -- accuracy=94.56%
#   valid loss:		0.12670
#   valid accuracy:	0.95333+/-0.00000
#   valid auc-roc:	0.98978+/-0.00000
#   valid auc-pr:		0.98812+/-0.00000
# Epoch 48 out of 50
# [==============================] 100.0% -- time=0s -- loss=0.13945 -- accuracy=94.86%
#   valid loss:		0.12797
#   valid accuracy:	0.95200+/-0.00000
#   valid auc-roc:	0.98994+/-0.00000
#   valid auc-pr:		0.98811+/-0.00000
# Epoch 49 out of 50
# [==============================] 100.0% -- time=0s -- loss=0.13676 -- accuracy=94.72%
#   valid loss:		0.12183
#   valid accuracy:	0.95300+/-0.00000
#   valid auc-roc:	0.99044+/-0.00000
#   valid auc-pr:		0.98844+/-0.00000
#   lower cross-validation found
#   saving model to:  /Users/juliankimura/Desktop/representation learning/data/synthetic_TF_dataset/results/tfomics/test_best.ckpt
# Epoch 50 out of 50
# [==============================] 100.0% -- time=0s -- loss=0.13663 -- accuracy=94.74%
#   valid loss:		0.12107
#   valid accuracy:	0.95267+/-0.00000
#   valid auc-roc:	0.99039+/-0.00000
#   valid auc-pr:		0.98814+/-0.00000
#   lower cross-validation found
#   saving model to:  /Users/juliankimura/Desktop/representation learning/data/synthetic_TF_dataset/results/tfomics/test_best.ckpt
# {'test_loss': [],
#  'test_metrics': [],
#  'train_loss': [],
#  'train_metrics': [],
#  'valid_loss': [1.9319929599761962,
#   0.98863298892974849,
#   0.69595512151718142,
#   0.61886337598164876,
#   0.59466713269551597,
#   0.58645114898681638,
#   0.60033925374348962,
#   0.60730786720911667,
#   0.54854701360066727,
#   0.55159775813420608,
#   0.50785919825236003,
#   0.4657532831033071,
#   0.42537215352058411,
#   0.40602193474769593,
#   0.40020706454912819,
#   0.3931857665379842,
#   0.38546733458836874,
#   0.39052777489026386,
#   0.40722100138664247,
#   0.43734742601712545,
#   0.446917333205541,
#   0.46124391357103983,
#   0.38950984279314677,
#   0.3435512840747833,
#   0.34459980328877765,
#   0.38505778710047406,
#   0.39674337903658546,
#   0.30609420339266458,
#   0.24400109450022381,
#   0.20369830131530761,
#   0.19658515353997549,
#   0.18483636379241944,
#   0.17438324292500815,
#   0.16584618687629699,
#   0.16279982030391693,
#   0.15502706120411555,
#   0.1436068539818128,
#   0.14000768462816873,
#   0.13618041276931764,
#   0.13431788881619772,
#   0.1339027668039004,
#   0.13458257764577866,
#   0.13408848692973455,
#   0.12721848636865615,
#   0.13229611565669377,
#   0.12574175347884495,
#   0.12670436253150305,
#   0.1279719685514768,
#   0.12182541340589523,
#   0.12107422848542532],
#  'valid_metrics': [[0.51266666666666671,
#    0.60830017130994296,
#    0.58074347382400948],
#   [0.51266666666666671, 0.66700451311864151, 0.64071183488009864],
#   [0.53266666666666662, 0.71862430822269929, 0.69769377263734134],
#   [0.67533333333333334, 0.76695732728026345, 0.74785656388297472],
#   [0.72199999999999998, 0.80223997089687782, 0.7868116648024851],
#   [0.68300000000000005, 0.83036179663748644, 0.81798364152081304],
#   [0.64033333333333331, 0.85144910778295058, 0.84105914831137307],
#   [0.63633333333333331, 0.86732507440330597, 0.85745558189398685],
#   [0.70633333333333337, 0.88092135575009023, 0.87078978662016393],
#   [0.70199999999999996, 0.89266800560003834, 0.88319457533185108],
#   [0.73966666666666669, 0.90202512190045514, 0.89243544072973091],
#   [0.77666666666666662, 0.90934226232301962, 0.90031217207831593],
#   [0.82199999999999995, 0.9148875989746309, 0.90557731744720193],
#   [0.83599999999999997, 0.91863934009204118, 0.9091582545632696],
#   [0.83766666666666667, 0.92246446163671258, 0.91405336174740037],
#   [0.83899999999999997, 0.92531473532346975, 0.91684374704034677],
#   [0.84299999999999997, 0.92874449202065679, 0.9203190115920763],
#   [0.83499999999999996, 0.93184737226913628, 0.92388168953873862],
#   [0.81433333333333335, 0.93402921697302632, 0.92636084233670357],
#   [0.78033333333333332, 0.93648946257064536, 0.929181110890138],
#   [0.76800000000000002, 0.93924545352661881, 0.93243902729059658],
#   [0.75366666666666671, 0.94349529208967886, 0.93660608470624973],
#   [0.81833333333333336, 0.95025429653519855, 0.94348439584229649],
#   [0.8753333333333333, 0.95696304650629105, 0.95129740870005575],
#   [0.8763333333333333, 0.96289262975883194, 0.95691523916121235],
#   [0.82433333333333336, 0.96750047586095245, 0.96127877939205986],
#   [0.81533333333333335, 0.97106676462583108, 0.96489572845470839],
#   [0.87233333333333329, 0.97569506830161212, 0.96993453216428682],
#   [0.91066666666666662, 0.97829985110444206, 0.97240989677053546],
#   [0.92666666666666664, 0.97947349321075394, 0.97426877931824574],
#   [0.92800000000000005, 0.98065602991430945, 0.97537987161732964],
#   [0.93066666666666664, 0.98008499677126115, 0.97589566879795031],
#   [0.93366666666666664, 0.98277872554652845, 0.97951783451865571],
#   [0.93999999999999995, 0.98324302352265192, 0.98024883622304437],
#   [0.93566666666666665, 0.98467194056985907, 0.98200742845266431],
#   [0.94066666666666665, 0.98547289905165802, 0.98261762749447468],
#   [0.94533333333333336, 0.98713263089734038, 0.9843396597248868],
#   [0.94899999999999995, 0.98765296483609932, 0.98514060322603936],
#   [0.94866666666666666, 0.98832450692800178, 0.98604683821589456],
#   [0.94566666666666666, 0.9887389951595601, 0.98676634691058196],
#   [0.95033333333333336, 0.98854687185909529, 0.98648734400725913],
#   [0.94866666666666666, 0.9892273085482417, 0.98728151316273127],
#   [0.94833333333333336, 0.98940253211394336, 0.98761972879040738],
#   [0.94833333333333336, 0.98964446515897309, 0.98777580110041052],
#   [0.95133333333333336, 0.98991530564504493, 0.98781081933843362],
#   [0.95099999999999996, 0.98996155755071247, 0.98803046879861856],
#   [0.95333333333333337, 0.98977832884749151, 0.98811830867139205],
#   [0.95199999999999996, 0.98993620794856807, 0.98811437364096699],
#   [0.95299999999999996, 0.99043875269283932, 0.98844490421618647],
#   [0.95266666666666666, 0.99038582983923895, 0.98814070384727937]]}

# %%
nntrainer.set_best_parameters(sess)

test = {'inputs': X_test, 'targets': y_test}
loss, mean_vals, std_vals = nntrainer.test_model(sess, test, batch_size=128, name='test', verbose=1)
# Out:
# loading model from:  /Users/juliankimura/Desktop/representation learning/data/synthetic_TF_dataset/results/tfomics/test_best.ckpt
#   test  loss:		0.14585
#   test  accuracy:	0.94900+/-0.00000
#   test  auc-roc:	0.98641+/-0.00000
#   test  auc-pr:		0.98382+/-0.00000

# %%
params = {'genome_model': model, 
          'input_shape': input_shape, 
          'output_shape': output_shape, 
          'model_path': filepath+'_best.ckpt',
          'optimization': optimization
         }
sal = saliency.backprop(X_test[:5], layer='output', class_index=0, params=params)
sal2 = saliency.guided_backprop(X_test[:5], layer='output', class_index=0, params=params)
# Out:
# loading model from:  /Users/juliankimura/Desktop/representation learning/data/synthetic_TF_dataset/results/tfomics/test_best.ckpt
# loading model from:  /Users/juliankimura/Desktop/representation learning/data/synthetic_TF_dataset/results/tfomics/test_best.ckpt

# %%
sal = saliency.stochastic_guided_backprop(X_test[:5], layer='output', class_index=0, params=params)
# Out:
# loading model from:  /Users/juliankimura/Desktop/representation learning/data/synthetic_TF_dataset/results/tfomics/test_best.ckpt

# %%
plt.plot(np.squeeze(sal[0][1]));
# Out:
# /Users/juliankimura/anaconda/lib/python3.5/site-packages/matplotlib/figure.py:1744: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
plt.plot(np.squeeze(sal2[1]));
# Out:
# /Users/juliankimura/anaconda/lib/python3.5/site-packages/matplotlib/figure.py:1744: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
valid = {'inputs': X_valid, 'targets': y_valid}
activations = nntrainer.get_activations(sess, valid, layer='output')
max_index = np.argsort(activations[:,0])#[::-1]

# %%
#saliency2 = nntrainer.get_average_salie
for index in max_index[:5]:
    fig, plt = visualize.plot_neg_saliency(np.squeeze(X_valid[index]).T, np.squeeze(saliency[index].T), height=50, nt_width=20, alphabet='dna', figsize=(100,2))
    fig.set_size_inches(150, 20)
    
    fig, plt = visualize.plot_neg_saliency(np.squeeze(X_valid[index]).T, np.squeeze(saliency2[index].T), height=50, nt_width=20, alphabet='dna', figsize=(100,2))
    fig.set_size_inches(150, 20)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-0fa75dc5e84c> in <module>()
# ----> 1 saliency = nntrainer.get_saliency(feed_X=valid, layer='output', method='guided')
#       2 #saliency2 = nntrainer.get_average_saliency(feed_X=valid, layer='output', method='guided', num_average=10, batch_size=200)
#       3
#       4 for index in max_index[:5]:
#       5     fig, plt = visualize.plot_neg_saliency(np.squeeze(X_valid[index]).T, np.squeeze(saliency[index].T), height=50, nt_width=20, alphabet='dna', figsize=(100,2))
#
# AttributeError: 'NeuralTrainer' object has no attribute 'get_saliency'

# %%
saliency = nntrainer.get_saliency(feed_X=valid, layer='output', method='deconv')
saliency2 = nntrainer.get_average_saliency(feed_X=valid, layer='output', method='deconv', num_average=10, batch_size=200)

for index in max_index[:5]:
    fig, plt = visualize.plot_neg_saliency(np.squeeze(X_valid[index]).T, np.squeeze(saliency[index].T), height=50, nt_width=20, alphabet='dna', figsize=(100,2))
    fig.set_size_inches(150, 20)
    
    fig, plt = visualize.plot_neg_saliency(np.squeeze(X_valid[index]).T, np.squeeze(saliency2[index].T), height=50, nt_width=20, alphabet='dna', figsize=(100,2))
    fig.set_size_inches(150, 20)

# %%
saliency = nntrainer.get_saliency(feed_X=valid, layer='output', method='backprop')
saliency2 = nntrainer.get_average_saliency(feed_X=valid, layer='output', method='backprop', num_average=10, batch_size=200)

for index in max_index[:5]:
    fig, plt = visualize.plot_neg_saliency(np.squeeze(X_valid[index]).T, np.squeeze(saliency[index].T), height=50, nt_width=20, alphabet='dna', figsize=(100,2))
    fig.set_size_inches(150, 20)
    
    fig, plt = visualize.plot_neg_saliency(np.squeeze(X_valid[index]).T, np.squeeze(saliency2[index].T), height=50, nt_width=20, alphabet='dna', figsize=(100,2))
    fig.set_size_inches(150, 20)
